# %% [markdown]
# # 1. Defining the problem
# In the realm of hiring and talent acquisition, understanding a candidate's personality
# traits is essential for determining their compatibility with a company's culture and job
# requirements. As reported by the New York Times, the psychometrics field is a $2
# billion dollar industry with over 2000 personality tests on the market currently. The
# Myers-Briggs Type Indicator (MBTI) is one of the most widely recognised framework
# for assessing personality types in the world, with more than 3.5 million assessments
# administered annually. It is used in 26 countries to assess employees, students,
# soldiers and potential marriage partners.
#
# This project aims to develop a predictive model that can accurately determine a person's MBTI based on their texts posted on social media platforms. The project aims to develop a tool for companies to quickly
# gain insight into the personalities of their potential hires to make informed candidate
# selection decisions, maximise the potential of their employees and better manage the
# culture of the firm.
#
# A successful implementation of such a classifier would demonstrate a strong linguistic
# basis for MBTI and potentially personality in general. Furthermore, the ability to
# produce an accurate text-based classifier has significant potential implications for the
# field of psychology itself, since the connection between natural language and
# personality type is non-trivial.

# %% [markdown]
# # Assembling the Dataset
# In this section, we will be doing the following:
#
# * Import necessary libraries and modules
# * Load dataset

# %% [markdown]
# ## Import necessary libraries and modules

# %%
# !pip install xgboost
# !pip install squarify
# !python -m pip uninstall -y imbalanced-learn
# !pip install scikit-learn==0.24.2
# !pip install imblearn
# Out:
# Requirement already satisfied: xgboost in /Users/suhyun/opt/anaconda3/lib/python3.9/site-packages (1.7.6)
# Requirement already satisfied: scipy in /Users/suhyun/opt/anaconda3/lib/python3.9/site-packages (from xgboost) (1.7.1)
# Requirement already satisfied: numpy in /Users/suhyun/opt/anaconda3/lib/python3.9/site-packages (from xgboost) (1.20.3)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from PIL import Image
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from wordcloud import WordCloud
from tqdm import tqdm

import nltk
from nltk.stem import WordNetLemmatizer    
from nltk.corpus import stopwords

import re
from sklearn.model_selection import train_test_split
import plotly.express as px
import warnings
import imblearn
from imblearn.over_sampling import SMOTE

from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import Sequential
from keras.models import load_model
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Bidirectional
from keras.layers import GRU
from keras.layers import SimpleRNN
from keras.layers import Embedding
from keras.preprocessing import sequence
from keras.preprocessing import text
from keras.optimizers import Adam
# outdated: from keras.preprocessing import sequence 
from keras.utils.data_utils import pad_sequences
from tensorflow.keras.preprocessing.sequence import pad_sequences

import squarify

# %% [markdown]
# ## Load Dataset

# %% [markdown]
# ### Create a dataframe

# %%
df = pd.read_csv('mbti_1.csv')
#df = pd.read_csv('mbti_1.csv', index_col=False)
df.head()
# Out:
#    type                                              posts
# 0  INFJ  'http://www.youtube.com/watch?v=qsXHcwe3krw|||...
# 1  ENTP  'I'm finding the lack of me in these posts ver...
# 2  INTP  'Good one  _____   https://www.youtube.com/wat...
# 3  INTJ  'Dear INTP,   I enjoyed our conversation the o...
# 4  ENTJ  'You're fired.|||That's another silly misconce...

# %% [markdown]
# ### Understanding the structure of the dataset
# Before we start cleaning our data, we need to first understand our raw dataset so that we can determine what to clean.

# %%
print(df.shape)
# Out:
# (8675, 2)

# %%
# display info/data types of data 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8675 entries, 0 to 8674
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   type    8675 non-null   object
#  1   posts   8675 non-null   object
# dtypes: object(2)
# memory usage: 135.7+ KB

# %% [markdown]
# From the above results, we can deduce that there are:
# * 8675 data values
# * 2 Columns - Type and Posts
# * Object datatype

# %% [markdown]
# ### Understanding the data

# %% [markdown]
# #### type (y data)

# %%
df['type']
# Out:
# 0       INFJ
# 1       ENTP
# 2       INTP
# 3       INTJ
# 4       ENTJ
#         ...
# 8670    ISFP
# 8671    ENFP
# 8672    INTP
# 8673    INFP
# 8674    INFP
# Name: type, Length: 8675, dtype: object

# %% [markdown]
# #### Uncleaned posts (x data)

# %%
df.posts[0]
# Out:
# "'http://www.youtube.com/watch?v=qsXHcwe3krw|||http://41.media.tumblr.com/tumblr_lfouy03PMA1qa1rooo1_500.jpg|||enfp and intj moments  https://www.youtube.com/watch?v=iz7lE1g4XM4  sportscenter not top ten plays  https://www.youtube.com/watch?v=uCdfze1etec  pranks|||What has been the most life-changing experience in your life?|||http://www.youtube.com/watch?v=vXZeYwwRDw8   http://www.youtube.com/watch?v=u8ejam5DP3E  On repeat for most of today.|||May the PerC Experience immerse you.|||The last thing my INFJ friend posted on his facebook before committing suicide the next day. Rest in peace~   http://vimeo.com/22842206|||Hello ENFJ7. Sorry to hear of your distress. It's only natural for a relationship to not be perfection all the time in every moment of existence. Try to figure the hard times as times of growth, as...|||84389  84390  http://wallpaperpassion.com/upload/23700/friendship-boy-and-girl-wallpaper.jpg  http://assets.dornob.com/wp-content/uploads/2010/04/round-home-design.jpg ...|||Welcome and stuff.|||http://playeressence.com/wp-content/uploads/2013/08/RED-red-the-pokemon-master-32560474-450-338.jpg  Game. Set. Match.|||Prozac, wellbrutin, at least thirty minutes of moving your legs (and I don't mean moving them while sitting in your same desk chair), weed in moderation (maybe try edibles as a healthier alternative...|||Basically come up with three items you've determined that each type (or whichever types you want to do) would more than likely use, given each types' cognitive functions and whatnot, when left by...|||All things in moderation.  Sims is indeed a video game, and a good one at that. Note: a good one at that is somewhat subjective in that I am not completely promoting the death of any given Sim...|||Dear ENFP:  What were your favorite video games growing up and what are your now, current favorite video games? :cool:|||https://www.youtube.com/watch?v=QyPqT8umzmY|||It appears to be too late. :sad:|||There's someone out there for everyone.|||Wait... I thought confidence was a good thing.|||I just cherish the time of solitude b/c i revel within my inner world more whereas most other time i'd be workin... just enjoy the me time while you can. Don't worry, people will always be around to...|||Yo entp ladies... if you're into a complimentary personality,well, hey.|||... when your main social outlet is xbox live conversations and even then you verbally fatigue quickly.|||http://www.youtube.com/watch?v=gDhy7rdfm14  I really dig the part from 1:46 to 2:50|||http://www.youtube.com/watch?v=msqXffgh7b8|||Banned because this thread requires it of me.|||Get high in backyard, roast and eat marshmellows in backyard while conversing over something intellectual, followed by massages and kisses.|||http://www.youtube.com/watch?v=Mw7eoU3BMbE|||http://www.youtube.com/watch?v=4V2uYORhQOk|||http://www.youtube.com/watch?v=SlVmgFQQ0TI|||Banned for too many b's in that sentence. How could you! Think of the B!|||Banned for watching movies in the corner with the dunces.|||Banned because Health class clearly taught you nothing about peer pressure.|||Banned for a whole host of reasons!|||http://www.youtube.com/watch?v=IRcrv41hgz4|||1) Two baby deer on left and right munching on a beetle in the middle.  2) Using their own blood, two cavemen diary today's latest happenings on their designated cave diary wall.  3) I see it as...|||a pokemon world  an infj society  everyone becomes an optimist|||49142|||http://www.youtube.com/watch?v=ZRCEq_JFeFM|||http://discovermagazine.com/2012/jul-aug/20-things-you-didnt-know-about-deserts/desert.jpg|||http://oyster.ignimgs.com/mediawiki/apis.ign.com/pokemon-silver-version/d/dd/Ditto.gif|||http://www.serebii.net/potw-dp/Scizor.jpg|||Not all artists are artists because they draw. It's the idea that counts in forming something of your own... like a signature.|||Welcome to the robot ranks, person who downed my self-esteem cuz I'm not an avid signature artist like herself. :proud:|||Banned for taking all the ro ...

# %% [markdown]
# # 2. Choosing a measure of success
#
# ## Accuracy
#
# The measure of success I have chosen to use is accuracy. Accuracy is well-suited to the specific nature of this project for several reasons.
#
# Firstly, the project involves predicting MBTI personality types. In this context, the consequences of a false positive, where the model predicts the wrong personality type, are not severe. There are no ethical implications or critical outcomes associated with such errors. False positives may result in additional work but does not carry significant adverse effects.
#
# Secondly, accuracy is an intuitive and interpretable metric for both technical and non-technical stakeholders. It provides a straightforward assessment of the model's performance by quantifying the proportion of correct predictions.
#
# Thirdly, the choice of accuracy is bolstered by the use of categorical cross-entropy as the loss function. This loss function is specifically tailored for multiclass classification tasks, aligning with our project's objective of predicting MBTI personality types.

# %% [markdown]
# # 3. Deciding on an evaluation protocol
#
# ## Iterated K-Fold Cross-Validation
#
# Considering my relatively small dataset containing 8675 data and the emphasis on achieving high model accuracy, the iterated k-Fold Cross-Validation approach would be the best evaluation protocol.
#
# Given the limited dataset size, this approach minimizes the risk of overfitting, as it repeatedly assesses the model on diverse data subsets. Iterated k-Fold Cross-Validation combines the advantages of k-Fold Cross-Validation with the robustness gained from repeated iterations. This protocol partitions the dataset into k subsets, or "folds," and iteratively uses each fold as a validation set while training the model on the remaining data. This process is repeated multiple times, shuffling the data differently in each iteration. This reduces the impact of variability introduced by the random splitting of data leading to a more reliable assessment of your model's ability to generalize to new, unseen data.

# %% [markdown]
# # 4. Preparing the data
# * Data Cleaning
# * Exploratory Data Analysis (EDA)
# * Data Preprocessing

# %% [markdown]
# ## Data Cleaning
# Data cleaning is the process of fixing or removing incorrect, corrupted, incorrectly formatted, duplicate, or incomplete data within a dataset. Cleaning our dataset ensures data accuracy, reliability and quality for effective analysis and modelling.
#
# * Case Standardisation
# * Remove Stopwords
# * Remove URLs and punctuations
# * Lemmatization

# %%
def clean_data(x):
    data_length=[]
    wnl=WordNetLemmatizer()
    cleaned_text=[]
    stop_words = set(stopwords.words('english')) # Load stop words
    mbti_types = [ "ISTJ", "ESFJ", "ISTJ","ISFP",
                  "ESTJ", "ESFP", "ENFP","ISTP",
                  "INFP", "ESTP", "INTP", "ENTP", 
                  "ENFJ", "INTJ", "ENTJ", "INFJ" ]
    mbti_types = [t.lower() for t in mbti_types]
    
    for sent in df.posts:
        
        # Case Standardisation
        sent=sent.lower()
        
        # Remove URLs
        # source: Gabriel Giraldo-Wingler https://stackoverflow.com/questions/11331982/how-to-remove-any-url-within-a-string-in-python
        sent=re.sub('(https?:\/\/)(\s)*(www\.)?(\s)*((\w|\s)+\.)*([\w\-\s]+\/)*([\w\-]+)((\?)?[\w\s]*=\s*[\w\%&]*)*',' ',sent)
        
        # Remove punctuations
        sent=re.sub('[^0-9a-z]',' ',sent)
        
        # Remove stop words
        sent = " ".join([word for word in sent.split() if word not in stop_words]) 
        
        for t in mbti_types:
            sent = re.sub(t, '', sent)
            
        # Lemmatize
        sent = wnl.lemmatize(sent) 
        
        data_length.append(len(sent.split())) #Split data, measure length of new filtered data
        
        cleaned_text.append(sent)
        
    return cleaned_text,data_length

# %%
class Lemmatizer(object):
    def __init__(self):
        self.lemmatizer = WordNetLemmatizer()

    def __call__(self, sentence):
        return [self.lemmatizer.lemmatize(word) for word in sentence.split() if len(word)>2]

# %%
df_clean = df
df_clean.posts,df_clean_length=clean_data(df)
df_clean
# Out:
#       type                                              posts
# 0     INFJ  jpg   moments sportscenter top ten plays prank...
# 1     ENTP  finding lack posts alarming sex boring positio...
# 2     INTP  good one course say know blessing curse absolu...
# 3     INTJ  dear  enjoyed conversation day esoteric gabbin...
# 4     ENTJ  fired another silly misconception approaching ...
# ...    ...                                                ...
# 8670  ISFP  ixfp always think cats fi doms reason especial...
# 8671  ENFP  thread already exists someplace else html post...
# 8672  INTP  many questions things would take purple pill p...
# 8673  INFP  conflicted right comes wanting children honest...
# 8674  INFP  long since personalitycafe although seem chang...
#
# [8675 rows x 2 columns]

# %% [markdown]
# ## EDA
# In this section, we will carry out EDA on the cleaned data to find meaningful information in our dataset that may be useful for our project.

# %% [markdown]
# #### Cleaned data

# %%
df_clean.posts[0]
# Out:
# 'jpg   moments sportscenter top ten plays pranks life changing experience life repeat today may perc experience immerse last thing  friend posted facebook committing suicide next day rest peace hello 7 sorry hear distress natural relationship perfection time every moment existence try figure hard times times growth 84389 84390 jpg jpg welcome stuff jpg game set match prozac wellbrutin least thirty minutes moving legs mean moving sitting desk chair weed moderation maybe try edibles healthier alternative basically come three items determined type whichever types want would likely use given types cognitive functions whatnot left things moderation sims indeed video game good one note good one somewhat subjective completely promoting death given sim dear  favorite video games growing current favorite video games cool appears late sad someone everyone wait thought confidence good thing cherish time solitude b c revel within inner world whereas time workin enjoy time worry people always around yo  ladies complimentary personality well hey main social outlet xbox live conversations even verbally fatigue quickly really dig part 1 46 2 50 banned thread requires get high backyard roast eat marshmellows backyard conversing something intellectual followed massages kisses banned many b sentence could think b banned watching movies corner dunces banned health class clearly taught nothing peer pressure banned whole host reasons 1 two baby deer left right munching beetle middle 2 using blood two cavemen diary today latest happenings designated cave diary wall 3 see pokemon world  society everyone becomes optimist 49142 jpg ign com pokemon silver version dd ditto gif jpg artists artists draw idea counts forming something like signature welcome robot ranks person downed self esteem cuz avid signature artist like proud banned taking room bed ya gotta learn share roaches banned much thundering grumbling kind storm yep ahh old high school music heard ages failed public speaking class years ago sort learned could better position big part failure overloading like person mentality confirmed  way gec6m move denver area start new life'

# %% [markdown]
# #### MBTI distribution in the dataset

# %%
# count data for each personality type 
df['type'].value_counts()
# Out:
# INFP    1832
# INFJ    1470
# INTP    1304
# INTJ    1091
# ENTP     685
# ENFP     675
# ISTP     337
# ISFP     271
# ENTJ     231
# ISTJ     205
# ENFJ     190
# ISFJ     166
# ESTP      89
# ESFP      48
# ESFJ      42
# ESTJ      39
# Name: type, dtype: int64

# %% [markdown]
# #### Visualise MBTI distribution

# %%
# visualise mbti type distribution in a count plot
plt.figure(figsize=(15,7))
chart = sns.countplot(x=df["type"])
chart.set(title="MBTI Type Distribution")
# Out:
# [Text(0.5, 1.0, 'MBTI Type Distribution')]

# %% [markdown]
# We can see that the dataset is disproportionate. We will have to balance the data before feeding it into our machine learning models later in the project.

# %% [markdown]
# #### 50 Most Common Words

# %%
from collections import Counter 
words = list(df["posts"].apply(lambda x: x.split()))
words = [x for y in words for x in y]
Counter(words).most_common(50)
# Out:
# [('like', 69691),
#  ('think', 49842),
#  ('people', 47882),
#  ('one', 37223),
#  ('know', 36936),
#  ('really', 35303),
#  ('would', 35027),
#  ('get', 30813),
#  ('time', 27620),
#  ('feel', 23340),
#  ('much', 23121),
#  ('well', 23088),
#  ('s', 21599),
#  ('love', 21113),
#  ('good', 20752),
#  ('things', 20490),
#  ('say', 20267),
#  ('way', 19658),
#  ('something', 19547),
#  ('want', 19380),
#  ('see', 19146),
#  ('also', 18339),
#  ('type', 17170),
#  ('even', 16923),
#  ('always', 16816),
#  ('lot', 16440),
#  ('someone', 16147),
#  ('make', 15870),
#  ('life', 15403),
#  ('could', 15297),
#  ('never', 15268),
#  ('go', 15127),
#  ('though', 14682),
#  ('thing', 14154),
#  ('find', 14150),
#  ('actually', 13234),
#  ('person', 12809),
#  ('right', 12726),
#  ('going', 12722),
#  ('first', 12674),
#  ('sure', 12647),
#  ('yes', 12410),
#  ('pretty', 12357),
#  ('friends', 12169),
#  ('need', 11569),
#  ('still', 11010),
#  ('work', 10957),
#  ('thought', 10638),
#  ('said', 10561),
#  ('many', 10389)]

# %% [markdown]
# #### Wordclouds

# %%
fig, ax = plt.subplots(len(df_clean['type'].unique()), figsize=(15, len(df_clean['type'].unique())))
plt.suptitle("Wordcloud for MBTI types")
k=0
for i in df_clean['type'].unique():
    df_4=df[df_clean['type'] == i]
    wordcloud = WordCloud(max_words=1628, relative_scaling=1, normalize_plurals=False).generate(df_4['posts'].to_string())
    plt.subplot(4,4,k+1)
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(i)
    
    ax[k].axis("off")
    k+=1

# %% [markdown]
# ## Data preprocessing
# * Split data into train and test sets
# * Label Encoding
# * One-hot encoding
# * Tokenization and padding sequences
# * Word embedding
# * Handling Imbalanced data

# %% [markdown]
# ### Split data into train and test sets
# The dataset is divided into training and testing sets in a 80:20 ratio. The training set is used for training the model and the testing set is used as a collection of data points that will help to assess the performance of the model in generalising new, unseen data

# %%
X = df['posts']
y = df['type']

X_train_lstm, X_test_lstm, y_train_lstm, y_test_lstm = train_test_split(df_clean['posts'],df_clean['type'], 
                                         test_size=0.2,
                                         random_state=0, 
                                         stratify= df.type)

# %% [markdown]
# ### Label Encoding
#
# Machine Learning cannot interpret strings on our target values. Thus, we need to convert categorical data into numerical values before they can be fitted into our machine learning models. Each category is assigned a unique integer.

# %%
# create an instance of label encoder 
labelencoder_lstm= LabelEncoder()
# Fit and transform the labels to numerical format
y_train_lstm_enc = labelencoder_lstm.fit_transform(y_train_lstm)
y_test_lstm_enc = labelencoder_lstm.transform(y_test_lstm)

# %%
import joblib

joblib.dump(labelencoder_lstm, 'labelencoder_lstm.pkl')
# Out:
# ['labelencoder_lstm.pkl']

# %% [markdown]
# ### One hot encoding
#
# The model would require categorically encoded labels where each label will be turned into a 10-element vector of zeros except for a single element. This is called one-hot encoding. The position in the vector that corresponds to the label will be encoded with a one in the (n+1)th position.

# %%
from keras.utils import to_categorical

# One-hot encode the target labels
y_train_lstm_onehot = to_categorical(y_train_lstm_enc)
y_test_lstm_onehot = to_categorical(y_test_lstm_enc)

# %% [markdown]
# ### Tokenization and Padding Sequences
# Tokenization is the process of splitting text into individual words or tokens. Padded sequences are used to make all input sequences of the same length by adding padding tokens. Both are essential for processing text data with varying lengths, as most machine learning models require fixed-length input.

# %%
from keras.preprocessing.text import Tokenizer
max_words = 2500
max_len = 40

# ensure all sequences in a list have the same length
def tokenize_pad_sequences(text):
    # initialise text tokenizer
    tokenizer = Tokenizer(num_words=max_words, filters="")
    
    # generate word indexes
    tokenizer.fit_on_texts(text)
    
    # transforms text to a sequence of integers and apply padding 
    X = tokenizer.texts_to_sequences(text)
    X = pad_sequences(X, padding='post', maxlen=max_len) #post padding  
    
    # return sequences 
    return X, tokenizer

# %%
from keras.preprocessing.text import Tokenizer
max_words = 2500
max_len = 40

X_train_lstm_pad, tokenizer = tokenize_pad_sequences(X_train_lstm)
X_test_lstm_pad = tokenizer.texts_to_sequences(X_test_lstm)
X_test_lstm_pad = pad_sequences(X_test_lstm_pad, padding='post', maxlen=max_len)

# %% [markdown]
# ### Word Embedding
#
# A word embedding is a learned representation for text where words that have the same meaning have a similar representation. It is this approach to representing words and documents that may be considered one of the key breakthroughs of deep learning on challenging natural language processing problems.
#
# We are using GloVe for this project.

# %%
import os
DATA_DIR = "data"
GLOVE_PATH = os.path.join(DATA_DIR, "glove.6B.50d.txt")


# load GloVe embedding 
embeddings_index = dict()
with open(GLOVE_PATH) as f:
    for line in f:
        values = line.split()
        word = values[0]
        coefficients = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefficients

# %%
max_words = 2500 
EMBEDDING_VECTOR_LENGTH = 50 
# create an embedding matrix 
embedding_matrix = np.zeros((max_words, EMBEDDING_VECTOR_LENGTH))
for word, index in tokenizer.word_index.items():
    if index < max_words:
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
            embedding_matrix[index] = embedding_vector

# %% [markdown]
# ### Handling Imbalanced Data
#
# To handle the imbalanced data, we will be using SMOTE to balance the class distribution.

# %%
# Instantiate the SMOTE class
smote = SMOTE(sampling_strategy='auto', random_state=0)

# Apply SMOTE to your training data
X_train_resampled, y_train_resampled = smote.fit_resample(X_train_lstm_pad, y_train_lstm_enc)

# %%
print('X_train_resampled', X_train_resampled.shape)
print('y_train_resampled', y_train_resampled.shape)
# Out:
# X_train_resampled (23456, 40)
# y_train_resampled (23456,)

# %% [markdown]
# ### Helper functions to plot accuracy and loss graphs

# %%
def plot_loss(loss, val_loss):
    plt.clf() #clear any existing figure
    epochs = range(1, len(loss)+1) #get number of epochs
    # Calculate the average loss over epochs
    avg_loss = [np.mean(loss[:i]) for i in range(1, len(loss) + 1)]
    avg_val_loss = [np.mean(val_loss[:i]) for i in range(1, len(val_loss) + 1)]
    # assign values for each axis
    plt.plot(epochs, avg_loss, 'bo', label="Loss")
    plt.plot(epochs, avg_val_loss, 'b', label="Average Validation Loss")
    #set a title of graph and labels of each axis
    plt.title("Average Training Loss & Validation Loss")
    plt.xlabel('Epochs')
    plt.ylabel('Average Loss')
    plt.legend()
    plt.show()

# %%
def plot_acc(acc, val_acc):
    plt.clf()
    epochs = range(1, len(acc)+1) #gets a number of epochs
    # Calculate the average loss over epochs
    avg_acc = [np.mean(acc[:i]) for i in range(1, len(acc) + 1)]
    avg_val_acc = [np.mean(val_acc[:i]) for i in range(1, len(val_acc) + 1)]
    
    # assign values for each axis
    plt.plot(epochs, avg_acc, 'bo', label="Accuracy")
    plt.plot(epochs, avg_val_acc, 'b', label="Average Validation Accuracy")
    #set a title of graph and labels of each axis
    plt.title("Average Training Accuracy & Validation Accuracy")
    plt.xlabel('Epochs')
    plt.ylabel('Average Accuracy')
    plt.legend()
    plt.show()

# %% [markdown]
# # 5. LSTM: Developing a model that does better than the baseline
#
# ## Baseline
#
# A baseline model serves as a starting point for comparison in machine learning tasks, representing a simple or default approach to establish a performance benchmark.
#
# As there are a total of 16 distinct labels in our dataset, the percentage of accuracy is 1/16 = 0.0625 or 6.25%.
#
# We will use this value as our baseline to aim to develop a model that produces an accuracy of greater than 0.0625 in order to achieve statistical power.

# %% [markdown]
# ## Simple LSTM Model
#
# A RNN classification model was developed for this project, specifically chosen due to its effectiveness in processing sequential data like text. RNNs process words sequentially, utilizing feedback loops to retain and process information over time. However, they face the issue of vanishing gradients, hindering learning from long sequences.
#
# To address this, specialised RNNs, LSTM and GRU, were used. LSTM excels in capturing and remembering essential features from past inputs, ensuring accurate classifications by considering both current and earlier time steps. GRUs, while also adept at retaining information, have a simpler architecture with fewer gates. However, this makes them slightly less proficient in capturing long-term dependencies compared to LSTMs. Both LSTM and GRU models were evaluated, with performance measured using accuracy scores. This approach enhances the model's ability to extract meaningful information from sequential text data, surpassing the limitations of traditional statistical classifiers like Naïve Bayes.

# %% [markdown]
# #### Building the model
# - initialise model
# - add layers to model
# - compile model

# %%
# Initialising the model 
underfit_lstm_model = Sequential()

# Defining model: add layers 
underfit_lstm_model.add(Embedding(
    max_words,
    EMBEDDING_VECTOR_LENGTH,
    input_length=max_len,
    weights=[embedding_matrix],
    trainable=True,
)) #glove embedding
underfit_lstm_model.add(LSTM(64, input_shape=(max_len, EMBEDDING_VECTOR_LENGTH))) #LSTM layer 
underfit_lstm_model.add(Dense(16, activation='softmax')) #dense layer - the last one

# Compile model
underfit_lstm_model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

print(underfit_lstm_model.summary())
# Out:
# 2023-09-01 21:11:50.492462: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 40, 50)            125000
#
#  lstm (LSTM)                 (None, 64)                29440
#
#  dense (Dense)               (None, 16)                1040
#
# =================================================================
# Total params: 155,480
# Trainable params: 155,480
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# #### Train model with Iterated K-fold Validation

# %%
import numpy as np 
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_absolute_error

K=4
num_val_samples = len(X_train_resampled)//K
num_epochs = 1

all_val_acc_1 = []
all_val_loss_1 = []

all_acc_1 = []
all_loss_1 = []
all_acc_history_1 = []
all_loss_history_1 = []

N_iterations=4
N_folds=5
        
for i in range(N_iterations):
    skf = StratifiedKFold(n_splits=N_folds, shuffle=True)
    
    for j, (train_index, val_index) in enumerate(skf.split(X_train_resampled, y_train_resampled)):
        print('processing fold', j)
        
        partial_train_data = X_train_resampled[train_index]
        val_data = X_train_resampled[val_index]
        
        partial_train_targets = y_train_resampled[train_index]
        val_targets = y_train_resampled[val_index]
        
        # One-hot encode the target labels
        partial_train_targets = to_categorical(partial_train_targets, num_classes=16)
        val_targets = to_categorical(val_targets, num_classes=16)
        
        # Train the model (in silent mode, verbose=0)
        underfit_lstm_model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
        results_1 = underfit_lstm_model.fit(partial_train_data, partial_train_targets, epochs=num_epochs, batch_size=128, verbose=0, validation_data = (val_data, val_targets))
        
        # Evaluate the model on the validation data: loss and accuracy 
        val_loss, val_acc = underfit_lstm_model.evaluate(val_data, val_targets, verbose=0)
        all_val_acc_1.append(val_acc)
        all_val_loss_1.append(val_loss)
        
        acc = results_1.history['accuracy']
        all_acc_1.append(acc)
        acc_history = results_1.history['val_accuracy']
        all_acc_history_1.append(acc_history)
        
        loss = results_1.history['loss']
        all_loss_1.append(loss)
        loss_history = results_1.history['val_loss']
        all_loss_history_1.append(loss_history)
# Out:
# processing fold 0
# processing fold 1
# processing fold 2
# processing fold 3
# processing fold 4
# processing fold 0
# processing fold 1
# processing fold 2
# processing fold 3
# processing fold 4
# processing fold 0
# processing fold 1
# processing fold 2
# processing fold 3
# processing fold 4
# processing fold 0
# processing fold 1
# processing fold 2
# processing fold 3
# processing fold 4

# %%
plot_loss(all_loss_1, all_loss_history_1)

# %%
plot_acc(all_acc_1, all_acc_history_1)

# %%
print("Average Loss:", np.mean(all_val_loss_1))
print("Average Accuracy:", np.mean(all_val_acc_1))
# Out:
# Average Loss: 2.3830607175827025
# Average Accuracy: 0.21643864922225475

# %% [markdown]
# From the graphs plotted, we can observe that there is slight underfitting as the accuracy is lower below the average validation accuracy.
#
# Despite being an underfitting model, our model has an average accuracy that is higher (21.6%) than the baseline (6.25%).
#
# Now we will develop a model that overfits.

# %% [markdown]
# # 6. LSTM: Developing a model that overfits/scaled up
# After developing a model that is able to do better than the baseline, we need to develop a model that overfits/scaled up. As the aim of this project is to create a model that stands on the line between overfitting and underfitting, we now need to cross the line to develop a model that overfits.
#
# We will be developing an overfitting model by changing the:
# 1. <b>number of LSTM and dense layers</b>
# 2. <b>batch_size</b>
# 3. <b>number of epochs</b>
#
# Using the 'relu' (Rectified Linear Unit) activation function for intermediate dense layers and 'softmax' activation for the output layer is a common practice in deep learning for classification tasks. Here's why this combination is used:
#
# Intermediate Layers ('relu' activation): The 'relu' activation function is commonly used in intermediate layers because it introduces non-linearity to the network. This non-linearity allows the model to learn complex patterns in the data. 'relu' is computationally efficient and helps mitigate the vanishing gradient problem during training. It's effective for feature extraction and can model complex relationships in the data.
#
# Output Layer ('softmax' activation): The 'softmax' activation is typically used in the output layer for multi-class classification problems. It transforms the raw output scores of the model into probability distributions over the classes. In other words, it converts the model's final layer outputs into class probabilities, where each class gets a probability score. This is useful because it allows you to interpret the model's output as class probabilities and choose the class with the highest probability as the predicted class.

# %% [markdown]
# #### Building the overfitting LSTM model
# - initialise model
# - add layers to model
# - compile model
#
# The model is first made bigger by increasing the number of dense layers and LSTM layers

# %%
max_len = 40
EMBEDDING_VECTOR_LENGTH = 50

# Initialising the model 
overfit_lstm_model = Sequential()

# Defining model: add layers 
overfit_lstm_model.add(Embedding(
    max_words,
    EMBEDDING_VECTOR_LENGTH,
    input_length=max_len,
    weights=[embedding_matrix],
    trainable=True,
)) #glove embedding
overfit_lstm_model.add(LSTM(128, input_shape=(max_len, EMBEDDING_VECTOR_LENGTH), return_sequences=True)) #LSTM layer
overfit_lstm_model.add(LSTM(64)) 
overfit_lstm_model.add(Dense(64, activation='relu')) # Additional dense layer
overfit_lstm_model.add(Dense(16, activation='softmax')) #dense layer - the last one


# Compile model
overfit_lstm_model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

print(overfit_lstm_model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 40, 50)            125000
#
#  lstm_3 (LSTM)               (None, 40, 128)           91648
#
#  lstm_4 (LSTM)               (None, 64)                49408
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 16)                1040
#
# =================================================================
# Total params: 271,256
# Trainable params: 271,256
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# #### Train model of batch_size = 128 with Iterated K-fold Validation
# The number of epochs we have used in training the neural network is very small as it takes extremely long to run the training if the number of epochs exceeds 5. In reality, the epoch number should be much higher to ensure better training.

# %%
import numpy as np 
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_absolute_error

K=4
num_val_samples = len(X_train_resampled)//K
num_epochs = 5

#new!
all_val_acc_2 = []
all_val_loss_2 = []

all_acc_2 = []
all_loss_2 = []
all_acc_history_2 = []
all_loss_history_2 = []

N_iterations=4
N_folds=5
        
for i in range(N_iterations):
    skf = StratifiedKFold(n_splits=N_folds, shuffle=True)
    
    for j, (train_index, val_index) in enumerate(skf.split(X_train_resampled, y_train_resampled)):
        print('processing fold', j)
        
        partial_train_data = X_train_resampled[train_index]
        val_data = X_train_resampled[val_index]
        
        partial_train_targets = y_train_resampled[train_index]
        val_targets = y_train_resampled[val_index]
        
        # One-hot encode the target labels
        partial_train_targets = to_categorical(partial_train_targets, num_classes=16)
        val_targets = to_categorical(val_targets, num_classes=16)
        
        # Train the model (in silent mode, verbose=0)
        overfit_lstm_model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
        results_2 = overfit_lstm_model.fit(partial_train_data, partial_train_targets, epochs=num_epochs, batch_size=128, verbose=0, validation_data = (val_data, val_targets))
        
        # Evaluate the model on the validation data: loss and accuracy 
        val_loss, val_acc = overfit_lstm_model.evaluate(val_data, val_targets, verbose=0)
        all_val_acc_2.append(val_acc)
        all_val_loss_2.append(val_loss)
        
        acc = results_2.history['accuracy']
        all_acc_2.append(acc)
        acc_history = results_2.history['val_accuracy']
        all_acc_history_2.append(acc_history)
        
        loss = results_2.history['loss']
        all_loss_2.append(loss)
        loss_history = results_2.history['val_loss']
        all_loss_history_2.append(loss_history)
# Out:
# processing fold 0
# processing fold 1
# processing fold 2
# processing fold 3
# processing fold 4
# processing fold 0
# processing fold 1
# processing fold 2
# processing fold 3
# processing fold 4
# processing fold 0
# processing fold 1
# processing fold 2
# processing fold 3
# processing fold 4
# processing fold 0
# processing fold 1
# processing fold 2
# processing fold 3
# processing fold 4

# %%
plot_loss(all_loss_2, all_loss_history_2)

# %%
plot_acc(all_acc_2, all_acc_history_2)

# %%
print("Average Loss:", np.mean(all_val_loss_2))
print("Average Accuracy:", np.mean(all_val_acc_2))
# Out:
# Average Loss: 0.9967752762138844
# Average Accuracy: 0.6761210460215807

# %% [markdown]
# #### Training the model

# %%
max_len = 40
EMBEDDING_VECTOR_LENGTH = 50

# Initialising the model 
overfit_lstm_model = Sequential()

# Defining model: add layers 
overfit_lstm_model.add(Embedding(
    max_words,
    EMBEDDING_VECTOR_LENGTH,
    input_length=max_len,
    weights=[embedding_matrix],
    trainable=True,
)) #glove embedding
overfit_lstm_model.add(LSTM(128, input_shape=(max_len, EMBEDDING_VECTOR_LENGTH), return_sequences=True)) #LSTM layer
overfit_lstm_model.add(LSTM(64)) 
overfit_lstm_model.add(Dense(64, activation='relu')) # Additional dense layer
overfit_lstm_model.add(Dense(16, activation='softmax')) #dense layer - the last one


# Compile model
overfit_lstm_model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

print(overfit_lstm_model.summary())
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_14 (Embedding)    (None, 40, 50)            125000
#
#  lstm_33 (LSTM)              (None, 40, 128)           91648
#
#  lstm_34 (LSTM)              (None, 64)                49408
#
#  dense_29 (Dense)            (None, 64)                4160
#
#  dense_30 (Dense)            (None, 16)                1040
#
# =================================================================
# Total params: 271,256
# Trainable params: 271,256
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# #### Train model of batch_size = 50 with Iterated K-fold Validation

# %%
import numpy as np 
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_absolute_error

K=4
num_val_samples = len(X_train_resampled)//K
num_epochs = 5

#new!
all_val_acc_2 = []
all_val_loss_2 = []

all_acc_2 = []
all_loss_2 = []
all_acc_history_2 = []
all_loss_history_2 = []

N_iterations=4
N_folds=5
        
for i in range(N_iterations):
    skf = StratifiedKFold(n_splits=N_folds, shuffle=True)
    
    for j, (train_index, val_index) in enumerate(skf.split(X_train_resampled, y_train_resampled)):
        print('processing fold', j)
        
        partial_train_data = X_train_resampled[train_index]
        val_data = X_train_resampled[val_index]
        
        partial_train_targets = y_train_resampled[train_index]
        val_targets = y_train_resampled[val_index]
        
        # One-hot encode the target labels
        partial_train_targets = to_categorical(partial_train_targets, num_classes=16)
        val_targets = to_categorical(val_targets, num_classes=16)
        
        # Train the model (in silent mode, verbose=0)
        overfit_lstm_model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
        results_2 = overfit_lstm_model.fit(partial_train_data, partial_train_targets, epochs=num_epochs, batch_size=50, verbose=0, validation_data = (val_data, val_targets))
        
        # Evaluate the model on the validation data: loss and accuracy 
        val_loss, val_acc = overfit_lstm_model.evaluate(val_data, val_targets, verbose=0)
        all_val_acc_2.append(val_acc)
        all_val_loss_2.append(val_loss)
        
        acc = results_2.history['accuracy']
        all_acc_2.append(acc)
        acc_history = results_2.history['val_accuracy']
        all_acc_history_2.append(acc_history)
        
        loss = results_2.history['loss']
        all_loss_2.append(loss)
        loss_history = results_2.history['val_loss']
        all_loss_history_2.append(loss_history)
# Out:
# processing fold 0
# processing fold 1
# processing fold 2
# processing fold 3
# processing fold 4
# processing fold 0
# processing fold 1
# processing fold 2
# processing fold 3
# processing fold 4
# processing fold 0
# processing fold 1
# processing fold 2
# processing fold 3
# processing fold 4
# processing fold 0
# processing fold 1
# processing fold 2
# processing fold 3
# processing fold 4

# %%
plot_loss(all_loss_2, all_loss_history_2)

# %%
plot_acc(all_acc_2, all_acc_history_2)

# %%
print("Average Loss:", np.mean(all_val_loss_2))
print("Average Accuracy:", np.mean(all_val_acc_2))
# Out:
# Average Loss: 0.8718613050878048
# Average Accuracy: 0.7233157001435757

# %% [markdown]
# #### Building the  model

# %%
max_len = 40
EMBEDDING_VECTOR_LENGTH = 50

# Initialising the model 
overfit_lstm_model = Sequential()

# Defining model: add layers 
overfit_lstm_model.add(Embedding(
    max_words,
    EMBEDDING_VECTOR_LENGTH,
    input_length=max_len,
    weights=[embedding_matrix],
    trainable=True,
)) #glove embedding
overfit_lstm_model.add(LSTM(128, input_shape=(max_len, EMBEDDING_VECTOR_LENGTH), return_sequences=True)) #LSTM layer
overfit_lstm_model.add(LSTM(64)) 
overfit_lstm_model.add(Dense(64, activation='relu')) # Additional dense layer
overfit_lstm_model.add(Dense(16, activation='softmax')) #dense layer - the last one


# Compile model
overfit_lstm_model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

print(overfit_lstm_model.summary())
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_15 (Embedding)    (None, 40, 50)            125000
#
#  lstm_35 (LSTM)              (None, 40, 128)           91648
#
#  lstm_36 (LSTM)              (None, 64)                49408
#
#  dense_31 (Dense)            (None, 64)                4160
#
#  dense_32 (Dense)            (None, 16)                1040
#
# =================================================================
# Total params: 271,256
# Trainable params: 271,256
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# #### Train model of batch_size = 10 with Iterated K-fold Validation
# The number of epochs we have used in training the neural network is very small as it takes extremely long to run the training if the number of epochs exceeds 5. In reality, the epoch number should be much higher to ensure better training.

# %%
import numpy as np 
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_absolute_error

K=4
num_val_samples = len(X_train_resampled)//K
num_epochs = 5

#new!
all_val_acc_2 = []
all_val_loss_2 = []

all_acc_2 = []
all_loss_2 = []
all_acc_history_2 = []
all_loss_history_2 = []

N_iterations=4
N_folds=5
        
for i in range(N_iterations):
    skf = StratifiedKFold(n_splits=N_folds, shuffle=True)
    
    for j, (train_index, val_index) in enumerate(skf.split(X_train_resampled, y_train_resampled)):
        print('processing fold', j)
        
        partial_train_data = X_train_resampled[train_index]
        val_data = X_train_resampled[val_index]
        
        partial_train_targets = y_train_resampled[train_index]
        val_targets = y_train_resampled[val_index]
        
        # One-hot encode the target labels
        partial_train_targets = to_categorical(partial_train_targets, num_classes=16)
        val_targets = to_categorical(val_targets, num_classes=16)
        
        # Train the model (in silent mode, verbose=0)
        overfit_lstm_model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
        results_2 = overfit_lstm_model.fit(partial_train_data, partial_train_targets, epochs=num_epochs, batch_size=10, verbose=0, validation_data = (val_data, val_targets))
        
        # Evaluate the model on the validation data: loss and accuracy 
        val_loss, val_acc = overfit_lstm_model.evaluate(val_data, val_targets, verbose=0)
        all_val_acc_2.append(val_acc)
        all_val_loss_2.append(val_loss)
        
        acc = results_2.history['accuracy']
        all_acc_2.append(acc)
        acc_history = results_2.history['val_accuracy']
        all_acc_history_2.append(acc_history)
        
        loss = results_2.history['loss']
        all_loss_2.append(loss)
        loss_history = results_2.history['val_loss']
        all_loss_history_2.append(loss_history)
# Out:
# processing fold 0
# processing fold 1
# processing fold 2
# processing fold 3
# processing fold 4
# processing fold 0
# processing fold 1
# processing fold 2
# processing fold 3
# processing fold 4
# processing fold 0
# processing fold 1
# processing fold 2
# processing fold 3
# processing fold 4
# processing fold 0
# processing fold 1
# processing fold 2
# processing fold 3
# processing fold 4

# %%
plot_loss(all_loss_2, all_loss_history_2)

# %%
plot_acc(all_acc_2, all_acc_history_2)

# %%
print("Average Loss:", np.mean(all_val_loss_2))
print("Average Accuracy:", np.mean(all_val_acc_2))
# Out:
# Average Loss: 0.6029456093907356
# Average Accuracy: 0.8255579173564911

# %% [markdown]
# From the plotted graphs, we can see the training accuracy being significantly higher than the average validation accuracy which suggests that the model is overfitting. The average accuracy of our overfitting model is 82.6% which is almost 4 times higher than our underfitting model with an accuracy of 21.6%.
#
# Now we will start regularising the hyperparamters of our overfitting model to prevent overfitting and improve the performance of the model.

# %% [markdown]
# ## Decreased num_epoch from 5 to 1 to speed up training but model was underfitting.

# %%
import numpy as np 
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_absolute_error

K=4
num_val_samples = len(X_train_resampled)//K
num_epochs = 1

#new!
all_val_acc_2 = []
all_val_loss_2 = []

all_acc_2 = []
all_loss_2 = []
all_acc_history_2 = []
all_loss_history_2 = []

N_iterations=4
N_folds=5
        
for i in range(N_iterations):
    skf = StratifiedKFold(n_splits=N_folds, shuffle=True)
    
    for j, (train_index, val_index) in enumerate(skf.split(X_train_resampled, y_train_resampled)):
        print('processing fold', j)
        
        partial_train_data = X_train_resampled[train_index]
        val_data = X_train_resampled[val_index]
        
        partial_train_targets = y_train_resampled[train_index]
        val_targets = y_train_resampled[val_index]
        
        # One-hot encode the target labels
        partial_train_targets = to_categorical(partial_train_targets, num_classes=16)
        val_targets = to_categorical(val_targets, num_classes=16)
        
        # Train the model (in silent mode, verbose=0)
        overfit_lstm_model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
        results_2 = overfit_lstm_model.fit(partial_train_data, partial_train_targets, epochs=num_epochs, batch_size=10, verbose=0, validation_data = (val_data, val_targets))
        
        # Evaluate the model on the validation data: loss and accuracy 
        val_loss, val_acc = overfit_lstm_model.evaluate(val_data, val_targets, verbose=0)
        all_val_acc_2.append(val_acc)
        all_val_loss_2.append(val_loss)
        
        acc = results_2.history['accuracy']
        all_acc_2.append(acc)
        acc_history = results_2.history['val_accuracy']
        all_acc_history_2.append(acc_history)
        
        loss = results_2.history['loss']
        all_loss_2.append(loss)
        loss_history = results_2.history['val_loss']
        all_loss_history_2.append(loss_history)
# Out:
# processing fold 0
# processing fold 1
# processing fold 2
# processing fold 3
# processing fold 4
# processing fold 0
# processing fold 1
# processing fold 2
# processing fold 3
# processing fold 4
# processing fold 0
# processing fold 1
# processing fold 2
# processing fold 3
# processing fold 4
# processing fold 0
# processing fold 1
# processing fold 2
# processing fold 3
# processing fold 4

# %%
plot_acc(all_acc_2, all_acc_history_2)

# %% [markdown]
# # LSTM: Regularizing your model and tuning your hyperparameters
# After creating a model that overfits, we need to modify the model to overcome the overfitting and increase the peformance of the model. We can do this by regularizing the model and iteratively fine tune our hyperparameters until we determine the optimal hyperparameter settings that results in the best performing machine learning model.
#
# There are many ways to regularize the model. For our project, we will be tuning:
# 1. Dropout rates
# 2. L1/L2 regularizers
#
# Batch Normalization will also be applied to accelerate training of the model.
#
# We will be testing different settings for the hyperparameters and compare the performances between them to determine the optimal setting for dropout and L1/L2 regularizers.
#
# Finally, we will add the hyperparameters with the optimal values we found earlier to our overfitting LSTM model to develop the final LSTM model.

# %% [markdown]
# ### 1. Dropout
#
# By adding dropout layers, you introduce some randomness during training, which can help prevent the model from relying too heavily on any single feature and reduce overfitting.

# %% [markdown]
# #### Build model with Dropout = 0.1

# %%
### DROP OUT = 0.1 ###

from tensorflow.keras.layers import Dropout

# Initialising the model 
lstm_model_1 = Sequential()

# Defining model: add layers 
lstm_model_1.add(Embedding(
    max_words,
    EMBEDDING_VECTOR_LENGTH,
    input_length=max_len,
    weights=[embedding_matrix],
    trainable=True,
)) #glove embedding

lstm_model_1.add(Dropout(0.1)) #dropout layer with 0.1 rate
lstm_model_1.add(LSTM(128, input_shape=(max_len, EMBEDDING_VECTOR_LENGTH), return_sequences=True))
lstm_model_1.add(LSTM(64))
lstm_model_1.add(Dense(64, activation='relu'))
lstm_model_1.add(Dropout(0.1))
lstm_model_1.add(Dense(16, activation='softmax'))

# Compile model
lstm_model_1.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

print(lstm_model_1.summary())
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_16 (Embedding)    (None, 40, 50)            125000
#
#  dropout (Dropout)           (None, 40, 50)            0
#
#  lstm_37 (LSTM)              (None, 40, 128)           91648
#
#  lstm_38 (LSTM)              (None, 64)                49408
#
#  dense_33 (Dense)            (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_34 (Dense)            (None, 16)                1040
#
# =================================================================
# Total params: 271,256
# Trainable params: 271,256
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# #### Train model with Dropout = 0.1

# %%
import numpy as np 
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_absolute_error

K=4
num_val_samples = len(X_train_resampled)//K
num_epochs = 5

#new!
all_val_acc_3 = []
all_val_loss_3 = []

all_acc_3 = []
all_loss_3 = []
all_acc_history_3 = []
all_loss_history_3 = []

N_iterations=4
N_folds=5
        
for i in range(N_iterations):
    skf = StratifiedKFold(n_splits=N_folds, shuffle=True)
    
    for j, (train_index, val_index) in enumerate(skf.split(X_train_resampled, y_train_resampled)):
        print('processing fold', j)
        
        partial_train_data = X_train_resampled[train_index]
        val_data = X_train_resampled[val_index]
        
        partial_train_targets = y_train_resampled[train_index]
        val_targets = y_train_resampled[val_index]
        
        # One-hot encode the target labels
        partial_train_targets = to_categorical(partial_train_targets, num_classes=16)
        val_targets = to_categorical(val_targets, num_classes=16)
        
        # Train the model 
        lstm_model_1.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
        results_3 = lstm_model_1.fit(partial_train_data, partial_train_targets, epochs=num_epochs, batch_size=10, verbose=2, validation_data = (val_data, val_targets))
        
        # Evaluate the model on the validation data: loss and accuracy 
        val_loss, val_acc = lstm_model_1.evaluate(val_data, val_targets, verbose=0)
        all_val_acc_3.append(val_acc)
        all_val_loss_3.append(val_loss)
        
        acc = results_3.history['accuracy']
        all_acc_3.append(acc)
        acc_history = results_3.history['val_accuracy']
        all_acc_history_3.append(acc_history)
        
        loss = results_3.history['loss']
        all_loss_3.append(loss)
        loss_history = results_3.history['val_loss']
        all_loss_history_3.append(loss_history)
# Out:
# processing fold 0
# Epoch 1/5
# 1877/1877 - 71s - loss: 1.4801 - accuracy: 0.5077 - val_loss: 1.2957 - val_accuracy: 0.5620 - 71s/epoch - 38ms/step
# Epoch 2/5
# 1877/1877 - 71s - loss: 1.3712 - accuracy: 0.5420 - val_loss: 1.3720 - val_accuracy: 0.5332 - 71s/epoch - 38ms/step
# Epoch 3/5
# 1877/1877 - 72s - loss: 1.2970 - accuracy: 0.5610 - val_loss: 1.4595 - val_accuracy: 0.5038 - 72s/epoch - 38ms/step
# Epoch 4/5
# 1877/1877 - 67s - loss: 1.2071 - accuracy: 0.5923 - val_loss: 1.5900 - val_accuracy: 0.4736 - 67s/epoch - 35ms/step
# Epoch 5/5
# 1877/1877 - 67s - loss: 1.1451 - accuracy: 0.6114 - val_loss: 1.7102 - val_accuracy: 0.4410 - 67s/epoch - 36ms/step
# processing fold 1
# Epoch 1/5
# 1877/1877 - 75s - loss: 1.3306 - accuracy: 0.5647 - val_loss: 0.8449 - val_accuracy: 0.7470 - 75s/epoch - 40ms/step
# Epoch 2/5
# 1877/1877 - 71s - loss: 1.2013 - accuracy: 0.6046 - val_loss: 0.9451 - val_accuracy: 0.6967 - 71s/epoch - 38ms/step
# Epoch 3/5
# 1877/1877 - 67s - loss: 1.1236 - accuracy: 0.6255 - val_loss: 1.0466 - val_accuracy: 0.6512 - 67s/epoch - 36ms/step
# Epoch 4/5
# 1877/1877 - 68s - loss: 1.0633 - accuracy: 0.6453 - val_loss: 1.1397 - val_accuracy: 0.6135 - 68s/epoch - 36ms/step
# Epoch 5/5
# 1877/1877 - 70s - loss: 1.0076 - accuracy: 0.6643 - val_loss: 1.2418 - val_accuracy: 0.5886 - 70s/epoch - 38ms/step
# processing fold 2
# Epoch 1/5
# 1877/1877 - 75s - loss: 1.1594 - accuracy: 0.6195 - val_loss: 0.6238 - val_accuracy: 0.8175 - 75s/epoch - 40ms/step
# Epoch 2/5
# 1877/1877 - 59s - loss: 1.0502 - accuracy: 0.6525 - val_loss: 0.7210 - val_accuracy: 0.7672 - 59s/epoch - 31ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 0.9850 - accuracy: 0.6710 - val_loss: 0.7817 - val_accuracy: 0.7410 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 63s - loss: 0.9297 - accuracy: 0.6881 - val_loss: 0.8552 - val_accuracy: 0.7161 - 63s/epoch - 33ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 0.8837 - accuracy: 0.7064 - val_loss: 0.9286 - val_accuracy: 0.6819 - 55s/epoch - 29ms/step
# processing fold 3
# Epoch 1/5
# 1877/1877 - 58s - loss: 1.0242 - accuracy: 0.6614 - val_loss: 0.4717 - val_accuracy: 0.8706 - 58s/epoch - 31ms/step
# Epoch 2/5
# 1877/1877 - 62s - loss: 0.9147 - accuracy: 0.6956 - val_loss: 0.5283 - val_accuracy: 0.8395 - 62s/epoch - 33ms/step
# Epoch 3/5
# 1877/1877 - 65s - loss: 0.8585 - accuracy: 0.7138 - val_loss: 0.6500 - val_accuracy: 0.7887 - 65s/epoch - 35ms/step
# Epoch 4/5
# 1877/1877 - 67s - loss: 0.8310 - accuracy: 0.7251 - val_loss: 0.7029 - val_accuracy: 0.7683 - 67s/epoch - 35ms/step
# Epoch 5/5
# 1877/1877 - 65s - loss: 0.7791 - accuracy: 0.7391 - val_loss: 0.7897 - val_accuracy: 0.7323 - 65s/epoch - 35ms/step
# processing fold 4
# Epoch 1/5
# 1877/1877 - 61s - loss: 0.9209 - accuracy: 0.6990 - val_loss: 0.3527 - val_accuracy: 0.9060 - 61s/epoch - 33ms/step
# Epoch 2/5
# 1877/1877 - 64s - loss: 0.8220 - accuracy: 0.7272 - val_loss: 0.4336 - val_accuracy: 0.8738 - 64s/epoch - 34ms/step
# Epoch 3/5
# 1877/1877 - 73s - loss: 0.7814 - accuracy: 0.7404 - val_loss: 0.5038 - val_accuracy: 0.8393 - 73s/epoch - 39ms/step
# Epoch 4/5
# 1877/1877 - 76s - loss: 0.7452 - accuracy: 0.7540 - val_loss: 0.5756 - val_accuracy: 0.8071 - 76s/epoch - 40ms/step
# Epoch 5/5
# 1877/1877 - 76s - loss: 0.7067 - accuracy: 0.7650 - val_loss: 0.6685 - val_accuracy: 0.7742 - 76s/epoch - 40ms/step
# processing fold 0
# Epoch 1/5
# 1877/1877 - 86s - loss: 0.7899 - accuracy: 0.7374 - val_loss: 0.4208 - val_accuracy: 0.8757 - 86s/epoch - 46ms/step
# Epoch 2/5
# 1877/1877 - 69s - loss: 0.7293 - accuracy: 0.7592 - val_loss: 0.4903 - val_accuracy: 0.8410 - 69s/epoch - 37ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 0.6722 - accuracy: 0.7788 - val_loss: 0.6021 - val_accuracy: 0.7980 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 54s - loss: 0.6532 - accuracy: 0.7825 - val_loss: 0.6197 - val_accuracy: 0.7931 - 54s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 54s - loss: 0.6265 - accuracy: 0.7941 - val_loss: 0.7081 - val_accuracy: 0.7581 - 54s/epoch - 29ms/step
# processing fold 1
# Epoch 1/5
# 1877/1877 - 59s - loss: 0.7785 - accuracy: 0.7442 - val_loss: 0.2752 - val_accuracy: 0.9292 - 59s/epoch - 31ms/step
# Epoch 2/5
# 1877/1877 - 54s - loss: 0.6859 - accuracy: 0.7771 - val_loss: 0.3449 - val_accuracy: 0.9024 - 54s/epoch - 29ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 0.6505 - accuracy: 0.7861 - val_loss: 0.4094 - val_accuracy: 0.8723 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 0.6204 - accuracy: 0.7986 - val_loss: 0.4825 - val_accuracy: 0.8433 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 0.5988 - accuracy: 0.8007 - val_loss: 0.5804 - val_accuracy: 0.8109 - 56s/epoch - 30ms/step
# processing fold 2
# Epoch 1/5
# 1877/1877 - 62s - loss: 0.7274 - accuracy: 0.7642 - val_loss: 0.2258 - val_accuracy: 0.9431 - 62s/epoch - 33ms/step
# Epoch 2/5
# 1877/1877 - 58s - loss: 0.6524 - accuracy: 0.7872 - val_loss: 0.2813 - val_accuracy: 0.9139 - 58s/epoch - 31ms/step
# Epoch 3/5
# 1877/1877 - 81s - loss: 0.6194 - accuracy: 0.7970 - val_loss: 0.3349 - val_accuracy: 0.8975 - 81s/epoch - 43ms/step
# Epoch 4/5
# 1877/1877 - 60s - loss: 0.5905 - accuracy: 0.8030 - val_loss: 0.4042 - val_accuracy: 0.8666 - 60s/epoch - 32ms/step
# Epoch 5/5
# 1877/1877 - 61s - loss: 0.5596 - accuracy: 0.8135 - val_loss: 0.4453 - val_accuracy: 0.8540 - 61s/epoch - 33ms/step
# processing fold 3
# Epoch 1/5
# 1877/1877 - 59s - loss: 0.6848 - accuracy: 0.7780 - val_loss: 0.1871 - val_accuracy: 0.9522 - 59s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 59s - loss: 0.6331 - accuracy: 0.7932 - val_loss: 0.2481 - val_accuracy: 0.9343 - 59s/epoch - 32ms/step
# Epoch 3/5
# 1877/1877 - 59s - loss: 0.5710 - accuracy: 0.8126 - val_loss: 0.2869 - val_accuracy: 0.9152 - 59s/epoch - 31ms/step
# Epoch 4/5
# 1877/1877 - 64s - loss: 0.5478 - accuracy: 0.8205 - val_loss: 0.3326 - val_accuracy: 0.8923 - 64s/epoch - 34ms/step
# Epoch 5/5
# 1877/1877 - 61s - loss: 0.5288 - accuracy: 0.8220 - val_loss: 0.4063 - val_accuracy: 0.8657 - 61s/epoch - 33ms/step
# processing fold 4
# Epoch 1/5
# 1877/1877 - 73s - loss: 0.6392 - accuracy: 0.7886 - val_loss: 0.1542 - val_accuracy: 0.9640 - 73s/epoch - 39ms/step
# Epoch 2/5
# 1877/1877 - 55s - loss: 0.5747 - accuracy: 0.8117 - val_loss: 0.1943 - val_accuracy: 0.9486 - 55s/epoch - 29ms/step
# Epoch 3/5
# 1877/1877 - 58s - loss: 0.5503 - accuracy: 0.8182 - val_loss: 0.2373 - val_accuracy: 0.9275 - 58s/epoch - 31ms/step
# Epoch 4/5
# 1877/1877 - 58s - loss: 0.5280 - accuracy: 0.8239 - val_loss: 0.2801 - val_accuracy: 0.9158 - 58s/epoch - 31ms/step
# Epoch 5/5
# 1877/1877 - 59s - loss: 0.5147 - accuracy: 0.8290 - val_loss: 0.3604 - val_accuracy: 0.8840 - 59s/epoch - 31ms/step
# processing fold 0
# Epoch 1/5
# 1877/1877 - 64s - loss: 0.5922 - accuracy: 0.8093 - val_loss: 0.2226 - val_accuracy: 0.9361 - 64s/epoch - 34ms/step
# Epoch 2/5
# 1877/1877 - 70s - loss: 0.5279 - accuracy: 0.8254 - val_loss: 0.2578 - val_accuracy: 0.9222 - 70s/epoch - 38ms/step
# Epoch 3/5
# 1877/1877 - 66s - loss: 0.5102 - accuracy: 0.8328 - val_loss: 0.2994 - val_accuracy: 0.9058 - 66s/epoch - 35ms/step
# Epoch 4/5
# 1877/1877 - 60s - loss: 0.4926 - accuracy: 0.8407 - val_loss: 0.3664 - val_accuracy: 0.8755 - 60s/epoch - 32ms/step
# Epoch 5/5
# 1877/1877 - 66s - loss: 0.4703 - accuracy: 0.8453 - val_loss: 0.4417 - val_accuracy: 0.8440 - 66s/epoch - 35ms/step
# processing fold 1
# Epoch 1/5
# 1877/1877 - 84s - loss: 0.6045 - accuracy: 0.8042 - val_loss: 0.1285 - val_accuracy: 0.9723 - 84s/epoch - 45ms/step
# Epoch 2/5
# 1877/1877 - 70s - loss: 0.5183 - accuracy: 0.8275 - val_loss: 0.1692 - val_accuracy: 0.9537 - 70s/epoch - 37ms/step
# Epoch 3/5
# 1877/1877 - 73s - loss: 0.4926 - accuracy: 0.8383 - val_loss: 0.2192 - val_accuracy: 0.9343 - 73s/epoch - 39ms/step
# Epoch 4/5
# 1877/1877 - 79s - loss: 0.4785 - accuracy: 0.8411 - val_loss: 0.2599 - val_accuracy: 0.9175 - 79s/epoch - 42ms/step
# Epoch 5/5
# 1877/1877 - 68s - loss: 0.4537 - accuracy: 0.8521 - val_loss: 0.3338 - val_accuracy: 0.8864 - 68s/epoch - 36ms/step
# processing fold 2
# Epoch 1/5
# 1877/1877 - 71s - loss: 0.5560 - accuracy: 0.8189 - val_loss: 0.1138 - val_accuracy: 0.9755 - 71s/epoch - 38ms/step
# Epoch 2/5
# 1877/1877 - 77s - loss: 0.5103 - accuracy: 0.8319 - val_loss: 0.1489 - val_accuracy: 0.9621 - 77s/epoch - 41ms/step
# Epoch 3/5
# 1877/1877 - 67s - loss: 0.4679 - accuracy: 0.8454 - val_loss: 0.1972 - val_accuracy: 0.9420 - 67s/epoch - 36ms/step
# Epoch 4/5
# 1877/1877 - 81s - loss: 0.4515 - accuracy: 0.8497 - val_loss: 0.2573 - val_accuracy: 0.9160 - 81s/epoch - 43ms/step
# Epoch 5/5
# 1877/1877 - 73s - loss: 0.4333 - accuracy: 0.8596 - val_loss: 0.2784 - val_accuracy: 0.9062 - 73s/epoch - 39ms/step
# processing fold 3
# Epoch 1/5
# 1877/1877 - 69s - loss: 0.5473 - accuracy: 0.8265 - val_loss: 0.1006 - val_accuracy: 0.9774 - 69s/epoch - 37ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 0.4884 - accuracy: 0.8416 - val_loss: 0.1335 - val_accuracy: 0.9699 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 0.4611 - accuracy: 0.8490 - val_loss: 0.1648 - val_accuracy: 0.9540 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 68s - loss: 0.4346 - accuracy: 0.8555 - val_loss: 0.2047 - val_accuracy: 0.9339 - 68s/epoch - 36ms/step
# Epoch 5/5
# 1877/1877 - 62s - loss: 0.4402 - accuracy: 0.8583 - val_loss: 0.2517 - val_accuracy: 0.9192 - 62s/epoch - 33ms/step
# processing fold 4
# Epoch 1/5
# 1877/1877 - 115s - loss: 0.5268 - accuracy: 0.8302 - val_loss: 0.0864 - val_accuracy: 0.9851 - 115s/epoch - 61ms/step
# Epoch 2/5
# 1877/1877 - 55s - loss: 0.4605 - accuracy: 0.8503 - val_loss: 0.1268 - val_accuracy: 0.9682 - 55s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 62s - loss: 0.4504 - accuracy: 0.8519 - val_loss: 0.1445 - val_accuracy: 0.9593 - 62s/epoch - 33ms/step
# Epoch 4/5
# 1877/1877 - 69s - loss: 0.4364 - accuracy: 0.8570 - val_loss: 0.1912 - val_accuracy: 0.9444 - 69s/epoch - 37ms/step
# Epoch 5/5
# 1877/1877 - 57s - loss: 0.4033 - accuracy: 0.8676 - val_loss: 0.2344 - val_accuracy: 0.9220 - 57s/epoch - 30ms/step
# processing fold 0
# Epoch 1/5
# 1877/1877 - 65s - loss: 0.4873 - accuracy: 0.8438 - val_loss: 0.1194 - val_accuracy: 0.9708 - 65s/epoch - 35ms/step
# Epoch 2/5
# 1877/1877 - 86s - loss: 0.4299 - accuracy: 0.8605 - val_loss: 0.1569 - val_accuracy: 0.9533 - 86s/epoch - 46ms/step
# Epoch 3/5
# 1877/1877 - 63s - loss: 0.4138 - accuracy: 0.8669 - val_loss: 0.1882 - val_accuracy: 0.9422 - 63s/epoch - 33ms/step
# Epoch 4/5
# 1877/1877 - 54s - loss: 0.3978 - accuracy: 0.8710 - val_loss: 0.2688 - val_accuracy: 0.9135 - 54s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 59s - loss: 0.3983 - accuracy: 0.8671 - val_loss: 0.2847 - val_accuracy: 0.9056 - 59s/epoch - 32ms/step
# processing fold 1
# Epoch 1/5
# 1877/1877 - 62s - loss: 0.5073 - accuracy: 0.8375 - val_loss: 0.0834 - val_accuracy: 0.9829 - 62s/epoch - 33ms/step
# Epoch 2/5
# 1877/1877 - 58s - loss: 0.4314 - accuracy: 0.8593 - val_loss: 0.1214 - val_accuracy: 0.9680 - 58s/epoch - 31ms/step
# Epoch 3/5
# 1877/1877 - 64s - loss: 0.4166 - accuracy: 0.8617 - val_loss: 0.1487 - val_accuracy: 0.9572 - 64s/epoch - 34ms/step
# Epoch 4/5
# 1877/1877 - 65s - loss: 0.4110 - accuracy: 0.8653 - val_loss: 0.1756 - val_accuracy: 0.9480 - 65s/epoch - 35ms/step
# Epoch 5/5
# 1877/1877 - 61s - loss: 0.3718 - accuracy: 0.8797 - val_loss: 0.2234 - val_accuracy: 0.9305 - 61s/epoch - 33ms/step
# processing fold 2
# Epoch 1/5
# 1877/1877 - 65s - loss: 0.4874 - accuracy: 0.8429 - val_loss: 0.0672 - val_accuracy: 0.9887 - 65s/epoch - 35ms/step
# Epoch 2/5
# 1877/1877 - 67s - loss: 0.4163 - accuracy: 0.8634 - val_loss: 0.1019 - val_accuracy: 0.9729 - 67s/epoch - 36ms/step
# Epoch 3/5
# 1877/1877 - 64s - loss: 0.4096 - accuracy: 0.8669 - val_loss: 0.1335 - val_accuracy: 0.9616 - 64s/epoch - 34ms/step
# Epoch 4/5
# 1877/1877 - 62s - loss: 0.3919 - accuracy: 0.8707 - val_loss: 0.1763 - val_accuracy: 0.9495 - 62s/epoch - 33ms/step
# Epoch 5/5
# 1877/1877 - 57s - loss: 0.3807 - accuracy: 0.8784 - val_loss: 0.2116 - val_accuracy: 0.9322 - 57s/epoch - 30ms/step
# processing fold 3
# Epoch 1/5
# 1877/1877 - 64s - loss: 0.4657 - accuracy: 0.8503 - val_loss: 0.0602 - val_accuracy: 0.9898 - 64s/epoch - 34ms/step
# Epoch 2/5
# 1877/1877 - 80s - loss: 0.4093 - accuracy: 0.8668 - val_loss: 0.1024 - val_accuracy: 0.9721 - 80s/epoch - 43ms/step
# Epoch 3/5
# 1877/1877 - 65s - loss: 0.3957 - accuracy: 0.8715 - val_loss: 0.1186 - val_accuracy: 0.9685 - 65s/epoch - 34ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 0.3806 - accuracy: 0.8770 - val_loss: 0.1657 - val_accuracy: 0.9514 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 0.3768 - accuracy: 0.8782 - val_loss: 0.2125 - val_accuracy: 0.9343 - 56s/epoch - 30ms/step
# processing fold 4
# Epoch 1/5
# 1877/1877 - 61s - loss: 0.4488 - accuracy: 0.8556 - val_loss: 0.0601 - val_accuracy: 0.9876 - 61s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 0.4078 - accuracy: 0.8671 - val_loss: 0.0800 - val_accuracy: 0.9825 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 0.3909 - accuracy: 0.8727 - val_loss: 0.1139 - val_accuracy: 0.9727 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 0.3726 - accuracy: 0.8784 - val_loss: 0.1371 - val_accuracy: 0.9589 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 0.3544 - accuracy: 0.8846 - val_loss: 0.1904 - val_accuracy: 0.9407 - 55s/epoch - 29ms/step

# %%
plot_loss(all_loss_3, all_loss_history_3)

# %%
plot_acc(all_acc_3, all_acc_history_3)

# %%
print("Average Loss:", np.mean(all_val_loss_3))
print("Average Accuracy:", np.mean(all_val_acc_3))
# Out:
# Average Loss: 0.5251037381589413
# Average Accuracy: 0.8255921095609665

# %% [markdown]
# From the graphs plotted above, we can see that the training accuracy is now below the averge validation accuracy which suggest undefitting.
#
# Upon adding dropouts of 0.1, the overfitting model became underfitting. As the aim of the project is to create a model that stands on the line between overfitting and underfitting, we need to reduce the underfitting by using a dropout rate that is smaller than 0.1.

# %% [markdown]
# #### Build Model with Dropout=0.07

# %%
### DROP OUT = 0.07 ###

from tensorflow.keras.layers import Dropout

# Initialising the model 
lstm_model_2 = Sequential()

# Defining model: add layers 
lstm_model_2.add(Embedding(
    max_words,
    EMBEDDING_VECTOR_LENGTH,
    input_length=max_len,
    weights=[embedding_matrix],
    trainable=True,
)) #glove embedding

lstm_model_2.add(Dropout(0.07)) #dropout layer with 0.07 rate
lstm_model_2.add(LSTM(128, input_shape=(max_len, EMBEDDING_VECTOR_LENGTH), return_sequences=True))
lstm_model_2.add(LSTM(64))
lstm_model_2.add(Dense(64, activation='relu'))
lstm_model_2.add(Dropout(0.07))
lstm_model_2.add(Dense(16, activation='softmax'))

# Compile model
lstm_model_2.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

print(lstm_model_2.summary())
# Out:
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_18 (Embedding)    (None, 40, 50)            125000
#
#  dropout_2 (Dropout)         (None, 40, 50)            0
#
#  lstm_41 (LSTM)              (None, 40, 128)           91648
#
#  lstm_42 (LSTM)              (None, 64)                49408
#
#  dense_37 (Dense)            (None, 64)                4160
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_38 (Dense)            (None, 16)                1040
#
# =================================================================
# Total params: 271,256
# Trainable params: 271,256
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# #### Train the Model with Dropout = 0.07

# %%
import numpy as np 
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_absolute_error

K=4
num_val_samples = len(X_train_resampled)//K
num_epochs = 5

all_val_acc_4 = []
all_val_loss_4 = []

all_acc_4 = []
all_loss_4 = []
all_acc_history_4 = []
all_loss_history_4 = []

N_iterations=4
N_folds=5
        
for i in range(N_iterations):
    skf = StratifiedKFold(n_splits=N_folds, shuffle=True)
    
    for j, (train_index, val_index) in enumerate(skf.split(X_train_resampled, y_train_resampled)):
        print('processing fold', j)
        
        partial_train_data = X_train_resampled[train_index]
        val_data = X_train_resampled[val_index]
        
        partial_train_targets = y_train_resampled[train_index]
        val_targets = y_train_resampled[val_index]
        
        # One-hot encode the target labels
        partial_train_targets = to_categorical(partial_train_targets, num_classes=16)
        val_targets = to_categorical(val_targets, num_classes=16)
        
        # Train the model 
        lstm_model_2.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
        results_4 = lstm_model_2.fit(partial_train_data, partial_train_targets, epochs=num_epochs, batch_size=10, verbose=2, validation_data = (val_data, val_targets))
        
        # Evaluate the model on the validation data: loss and accuracy 
        val_loss, val_acc = lstm_model_2.evaluate(val_data, val_targets, verbose=0)
        all_val_acc_4.append(val_acc)
        all_val_loss_4.append(val_loss)
        
        acc = results_4.history['accuracy']
        all_acc_4.append(acc)
        acc_history = results_4.history['val_accuracy']
        all_acc_history_4.append(acc_history)
        
        loss = results_4.history['loss']
        all_loss_4.append(loss)
        loss_history = results_4.history['val_loss']
        all_loss_history_4.append(loss_history)
# Out:
# processing fold 0
# Epoch 1/5
# 1877/1877 - 71s - loss: 2.7634 - accuracy: 0.0699 - val_loss: 2.6928 - val_accuracy: 0.1002 - 71s/epoch - 38ms/step
# Epoch 2/5
# 1877/1877 - 66s - loss: 2.6563 - accuracy: 0.1070 - val_loss: 2.6211 - val_accuracy: 0.1117 - 66s/epoch - 35ms/step
# Epoch 3/5
# 1877/1877 - 69s - loss: 2.5939 - accuracy: 0.1160 - val_loss: 2.6282 - val_accuracy: 0.1138 - 69s/epoch - 37ms/step
# Epoch 4/5
# 1877/1877 - 70s - loss: 2.5512 - accuracy: 0.1303 - val_loss: 2.5971 - val_accuracy: 0.1281 - 70s/epoch - 37ms/step
# Epoch 5/5
# 1877/1877 - 69s - loss: 2.5116 - accuracy: 0.1455 - val_loss: 2.6065 - val_accuracy: 0.1296 - 69s/epoch - 37ms/step
# processing fold 1
# Epoch 1/5
# 1877/1877 - 66s - loss: 2.5038 - accuracy: 0.1545 - val_loss: 2.5013 - val_accuracy: 0.1537 - 66s/epoch - 35ms/step
# Epoch 2/5
# 1877/1877 - 57s - loss: 2.4547 - accuracy: 0.1700 - val_loss: 2.4840 - val_accuracy: 0.1644 - 57s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 74s - loss: 2.3794 - accuracy: 0.1990 - val_loss: 2.5040 - val_accuracy: 0.1652 - 74s/epoch - 39ms/step
# Epoch 4/5
# 1877/1877 - 91s - loss: 2.2919 - accuracy: 0.2266 - val_loss: 2.5185 - val_accuracy: 0.1633 - 91s/epoch - 48ms/step
# Epoch 5/5
# 1877/1877 - 65s - loss: 2.1917 - accuracy: 0.2652 - val_loss: 2.5994 - val_accuracy: 0.1582 - 65s/epoch - 34ms/step
# processing fold 2
# Epoch 1/5
# 1877/1877 - 65s - loss: 2.2210 - accuracy: 0.2653 - val_loss: 2.0677 - val_accuracy: 0.3144 - 65s/epoch - 35ms/step
# Epoch 2/5
# 1877/1877 - 65s - loss: 2.0957 - accuracy: 0.3015 - val_loss: 2.0842 - val_accuracy: 0.2989 - 65s/epoch - 35ms/step
# Epoch 3/5
# 1877/1877 - 67s - loss: 1.9585 - accuracy: 0.3452 - val_loss: 2.1759 - val_accuracy: 0.2746 - 67s/epoch - 35ms/step
# Epoch 4/5
# 1877/1877 - 60s - loss: 1.8210 - accuracy: 0.3890 - val_loss: 2.2787 - val_accuracy: 0.2663 - 60s/epoch - 32ms/step
# Epoch 5/5
# 1877/1877 - 66s - loss: 1.6904 - accuracy: 0.4359 - val_loss: 2.3767 - val_accuracy: 0.2473 - 66s/epoch - 35ms/step
# processing fold 3
# Epoch 1/5
# 1877/1877 - 72s - loss: 1.8190 - accuracy: 0.4045 - val_loss: 1.4175 - val_accuracy: 0.5536 - 72s/epoch - 38ms/step
# Epoch 2/5
# 1877/1877 - 63s - loss: 1.6529 - accuracy: 0.4504 - val_loss: 1.4744 - val_accuracy: 0.5204 - 63s/epoch - 33ms/step
# Epoch 3/5
# 1877/1877 - 72s - loss: 1.5291 - accuracy: 0.4894 - val_loss: 1.5278 - val_accuracy: 0.4856 - 72s/epoch - 38ms/step
# Epoch 4/5
# 1877/1877 - 74s - loss: 1.4051 - accuracy: 0.5283 - val_loss: 1.6249 - val_accuracy: 0.4577 - 74s/epoch - 40ms/step
# Epoch 5/5
# 1877/1877 - 69s - loss: 1.3004 - accuracy: 0.5615 - val_loss: 1.7272 - val_accuracy: 0.4321 - 69s/epoch - 37ms/step
# processing fold 4
# Epoch 1/5
# 1877/1877 - 59s - loss: 1.4237 - accuracy: 0.5318 - val_loss: 0.9554 - val_accuracy: 0.7178 - 59s/epoch - 31ms/step
# Epoch 2/5
# 1877/1877 - 55s - loss: 1.2720 - accuracy: 0.5791 - val_loss: 1.0551 - val_accuracy: 0.6540 - 55s/epoch - 29ms/step
# Epoch 3/5
# 1877/1877 - 80s - loss: 1.1790 - accuracy: 0.6080 - val_loss: 1.1070 - val_accuracy: 0.6252 - 80s/epoch - 42ms/step
# Epoch 4/5
# 1877/1877 - 77s - loss: 1.0856 - accuracy: 0.6406 - val_loss: 1.2118 - val_accuracy: 0.5950 - 77s/epoch - 41ms/step
# Epoch 5/5
# 1877/1877 - 69s - loss: 1.0226 - accuracy: 0.6581 - val_loss: 1.3282 - val_accuracy: 0.5551 - 69s/epoch - 37ms/step
# processing fold 0
# Epoch 1/5
# 1877/1877 - 77s - loss: 1.0927 - accuracy: 0.6437 - val_loss: 0.8759 - val_accuracy: 0.7099 - 77s/epoch - 41ms/step
# Epoch 2/5
# 1877/1877 - 67s - loss: 0.9702 - accuracy: 0.6761 - val_loss: 0.9780 - val_accuracy: 0.6756 - 67s/epoch - 36ms/step
# Epoch 3/5
# 1877/1877 - 71s - loss: 0.8989 - accuracy: 0.7034 - val_loss: 1.0828 - val_accuracy: 0.6390 - 71s/epoch - 38ms/step
# Epoch 4/5
# 1877/1877 - 61s - loss: 0.8381 - accuracy: 0.7150 - val_loss: 1.2076 - val_accuracy: 0.6070 - 61s/epoch - 33ms/step
# Epoch 5/5
# 1877/1877 - 60s - loss: 0.7946 - accuracy: 0.7328 - val_loss: 1.3048 - val_accuracy: 0.5848 - 60s/epoch - 32ms/step
# processing fold 1
# Epoch 1/5
# 1877/1877 - 75s - loss: 0.9919 - accuracy: 0.6807 - val_loss: 0.5258 - val_accuracy: 0.8408 - 75s/epoch - 40ms/step
# Epoch 2/5
# 1877/1877 - 98s - loss: 0.8467 - accuracy: 0.7200 - val_loss: 0.6110 - val_accuracy: 0.8041 - 98s/epoch - 52ms/step
# Epoch 3/5
# 1877/1877 - 58s - loss: 0.7750 - accuracy: 0.7435 - val_loss: 0.7078 - val_accuracy: 0.7636 - 58s/epoch - 31ms/step
# Epoch 4/5
# 1877/1877 - 98s - loss: 0.7304 - accuracy: 0.7577 - val_loss: 0.8104 - val_accuracy: 0.7256 - 98s/epoch - 52ms/step
# Epoch 5/5
# 1877/1877 - 74s - loss: 0.6954 - accuracy: 0.7634 - val_loss: 0.8916 - val_accuracy: 0.7003 - 74s/epoch - 39ms/step
# processing fold 2
# Epoch 1/5
# 1877/1877 - 91s - loss: 0.8533 - accuracy: 0.7243 - val_loss: 0.3716 - val_accuracy: 0.8979 - 91s/epoch - 49ms/step
# Epoch 2/5
# 1877/1877 - 83s - loss: 0.7238 - accuracy: 0.7620 - val_loss: 0.4474 - val_accuracy: 0.8548 - 83s/epoch - 44ms/step
# Epoch 3/5
# 1877/1877 - 69s - loss: 0.6786 - accuracy: 0.7733 - val_loss: 0.5609 - val_accuracy: 0.8160 - 69s/epoch - 37ms/step
# Epoch 4/5
# 1877/1877 - 74s - loss: 0.6441 - accuracy: 0.7860 - val_loss: 0.6486 - val_accuracy: 0.7900 - 74s/epoch - 39ms/step
# Epoch 5/5
# 1877/1877 - 60s - loss: 0.6145 - accuracy: 0.7975 - val_loss: 0.7296 - val_accuracy: 0.7506 - 60s/epoch - 32ms/step
# processing fold 3
# Epoch 1/5
# 1877/1877 - 73s - loss: 0.7469 - accuracy: 0.7541 - val_loss: 0.3003 - val_accuracy: 0.9147 - 73s/epoch - 39ms/step
# Epoch 2/5
# 1877/1877 - 70s - loss: 0.6440 - accuracy: 0.7860 - val_loss: 0.3346 - val_accuracy: 0.8977 - 70s/epoch - 38ms/step
# Epoch 3/5
# 1877/1877 - 60s - loss: 0.5926 - accuracy: 0.8015 - val_loss: 0.4157 - val_accuracy: 0.8661 - 60s/epoch - 32ms/step
# Epoch 4/5
# 1877/1877 - 59s - loss: 0.5898 - accuracy: 0.8038 - val_loss: 0.4821 - val_accuracy: 0.8359 - 59s/epoch - 31ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 0.5375 - accuracy: 0.8206 - val_loss: 0.5844 - val_accuracy: 0.8013 - 55s/epoch - 29ms/step
# processing fold 4
# Epoch 1/5
# 1877/1877 - 61s - loss: 0.6780 - accuracy: 0.7775 - val_loss: 0.2150 - val_accuracy: 0.9456 - 61s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 0.5924 - accuracy: 0.8023 - val_loss: 0.2663 - val_accuracy: 0.9216 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 0.5382 - accuracy: 0.8208 - val_loss: 0.3505 - val_accuracy: 0.8868 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 57s - loss: 0.5385 - accuracy: 0.8224 - val_loss: 0.3956 - val_accuracy: 0.8685 - 57s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 0.5027 - accuracy: 0.8342 - val_loss: 0.4784 - val_accuracy: 0.8405 - 55s/epoch - 29ms/step
# processing fold 0
# Epoch 1/5
# 1877/1877 - 69s - loss: 0.5798 - accuracy: 0.8106 - val_loss: 0.2817 - val_accuracy: 0.9173 - 69s/epoch - 37ms/step
# Epoch 2/5
# 1877/1877 - 55s - loss: 0.5186 - accuracy: 0.8322 - val_loss: 0.3142 - val_accuracy: 0.9015 - 55s/epoch - 29ms/step
# Epoch 3/5
# 1877/1877 - 56s - loss: 0.4839 - accuracy: 0.8438 - val_loss: 0.4098 - val_accuracy: 0.8630 - 56s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 0.4769 - accuracy: 0.8409 - val_loss: 0.4772 - val_accuracy: 0.8425 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 66s - loss: 0.4561 - accuracy: 0.8507 - val_loss: 0.5499 - val_accuracy: 0.8205 - 66s/epoch - 35ms/step
# processing fold 1
# Epoch 1/5
# 1877/1877 - 67s - loss: 0.5994 - accuracy: 0.8056 - val_loss: 0.1957 - val_accuracy: 0.9497 - 67s/epoch - 36ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 0.4847 - accuracy: 0.8428 - val_loss: 0.2632 - val_accuracy: 0.9171 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 68s - loss: 0.4722 - accuracy: 0.8460 - val_loss: 0.3086 - val_accuracy: 0.8992 - 68s/epoch - 36ms/step
# Epoch 4/5
# 1877/1877 - 67s - loss: 0.4519 - accuracy: 0.8500 - val_loss: 0.3460 - val_accuracy: 0.8847 - 67s/epoch - 35ms/step
# Epoch 5/5
# 1877/1877 - 62s - loss: 0.4329 - accuracy: 0.8574 - val_loss: 0.4377 - val_accuracy: 0.8516 - 62s/epoch - 33ms/step
# processing fold 2
# Epoch 1/5
# 1877/1877 - 67s - loss: 0.5520 - accuracy: 0.8223 - val_loss: 0.1324 - val_accuracy: 0.9680 - 67s/epoch - 36ms/step
# Epoch 2/5
# 1877/1877 - 67s - loss: 0.4697 - accuracy: 0.8447 - val_loss: 0.1851 - val_accuracy: 0.9450 - 67s/epoch - 36ms/step
# Epoch 3/5
# 1877/1877 - 66s - loss: 0.4368 - accuracy: 0.8539 - val_loss: 0.2498 - val_accuracy: 0.9224 - 66s/epoch - 35ms/step
# Epoch 4/5
# 1877/1877 - 70s - loss: 0.4251 - accuracy: 0.8575 - val_loss: 0.2932 - val_accuracy: 0.9039 - 70s/epoch - 37ms/step
# Epoch 5/5
# 1877/1877 - 61s - loss: 0.4133 - accuracy: 0.8654 - val_loss: 0.3750 - val_accuracy: 0.8717 - 61s/epoch - 32ms/step
# processing fold 3
# Epoch 1/5
# 1877/1877 - 61s - loss: 0.5101 - accuracy: 0.8351 - val_loss: 0.1361 - val_accuracy: 0.9659 - 61s/epoch - 33ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 0.4466 - accuracy: 0.8528 - val_loss: 0.1695 - val_accuracy: 0.9531 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 58s - loss: 0.4116 - accuracy: 0.8651 - val_loss: 0.2302 - val_accuracy: 0.9265 - 58s/epoch - 31ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 0.4087 - accuracy: 0.8678 - val_loss: 0.2786 - val_accuracy: 0.9085 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 57s - loss: 0.4010 - accuracy: 0.8663 - val_loss: 0.3627 - val_accuracy: 0.8806 - 57s/epoch - 31ms/step
# processing fold 4
# Epoch 1/5
# 1877/1877 - 60s - loss: 0.4934 - accuracy: 0.8395 - val_loss: 0.1087 - val_accuracy: 0.9740 - 60s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 0.4270 - accuracy: 0.8621 - val_loss: 0.1569 - val_accuracy: 0.9589 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 56s - loss: 0.4033 - accuracy: 0.8673 - val_loss: 0.1919 - val_accuracy: 0.9427 - 56s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 57s - loss: 0.3877 - accuracy: 0.8713 - val_loss: 0.2493 - val_accuracy: 0.9196 - 57s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 0.3779 - accuracy: 0.8768 - val_loss: 0.3008 - val_accuracy: 0.8990 - 56s/epoch - 30ms/step
# processing fold 0
# Epoch 1/5
# 1877/1877 - 62s - loss: 0.4405 - accuracy: 0.8585 - val_loss: 0.1800 - val_accuracy: 0.9486 - 62s/epoch - 33ms/step
# Epoch 2/5
# 1877/1877 - 62s - loss: 0.4034 - accuracy: 0.8688 - val_loss: 0.2257 - val_accuracy: 0.9305 - 62s/epoch - 33ms/step
# Epoch 3/5
# 1877/1877 - 56s - loss: 0.3771 - accuracy: 0.8743 - val_loss: 0.2740 - val_accuracy: 0.9137 - 56s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 71s - loss: 0.3702 - accuracy: 0.8795 - val_loss: 0.3489 - val_accuracy: 0.8845 - 71s/epoch - 38ms/step
# Epoch 5/5
# 1877/1877 - 60s - loss: 0.3577 - accuracy: 0.8825 - val_loss: 0.4018 - val_accuracy: 0.8672 - 60s/epoch - 32ms/step
# processing fold 1
# Epoch 1/5
# 1877/1877 - 64s - loss: 0.4758 - accuracy: 0.8476 - val_loss: 0.1075 - val_accuracy: 0.9734 - 64s/epoch - 34ms/step
# Epoch 2/5
# 1877/1877 - 60s - loss: 0.3998 - accuracy: 0.8674 - val_loss: 0.1378 - val_accuracy: 0.9582 - 60s/epoch - 32ms/step
# Epoch 3/5
# 1877/1877 - 65s - loss: 0.3721 - accuracy: 0.8777 - val_loss: 0.1823 - val_accuracy: 0.9437 - 65s/epoch - 35ms/step
# Epoch 4/5
# 1877/1877 - 58s - loss: 0.3460 - accuracy: 0.8894 - val_loss: 0.2216 - val_accuracy: 0.9267 - 58s/epoch - 31ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 0.3522 - accuracy: 0.8861 - val_loss: 0.2656 - val_accuracy: 0.9139 - 56s/epoch - 30ms/step
# processing fold 2
# Epoch 1/5
# 1877/1877 - 61s - loss: 0.4499 - accuracy: 0.8543 - val_loss: 0.0887 - val_accuracy: 0.9819 - 61s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 55s - loss: 0.3655 - accuracy: 0.8787 - val_loss: 0.1295 - val_accuracy: 0.9627 - 55s/epoch - 29ms/step
# Epoch 3/5
# 1877/1877 - 56s - loss: 0.3709 - accuracy: 0.8814 - val_loss: 0.1805 - val_accuracy: 0.9469 - 56s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 0.3466 - accuracy: 0.8879 - val_loss: 0.2077 - val_accuracy: 0.9346 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 0.3379 - accuracy: 0.8908 - val_loss: 0.2588 - val_accuracy: 0.9147 - 55s/epoch - 29ms/step
# processing fold 3
# Epoch 1/5
# 1877/1877 - 60s - loss: 0.4366 - accuracy: 0.8578 - val_loss: 0.0976 - val_accuracy: 0.9748 - 60s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 0.3662 - accuracy: 0.8798 - val_loss: 0.1146 - val_accuracy: 0.9708 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 60s - loss: 0.3527 - accuracy: 0.8844 - val_loss: 0.1592 - val_accuracy: 0.9512 - 60s/epoch - 32ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 0.3426 - accuracy: 0.8909 - val_loss: 0.1780 - val_accuracy: 0.9467 - 55s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 57s - loss: 0.3231 - accuracy: 0.8955 - val_loss: 0.2402 - val_accuracy: 0.9184 - 57s/epoch - 30ms/step
# processing fold 4
# Epoch 1/5
# 1877/1877 - 60s - loss: 0.4111 - accuracy: 0.8674 - val_loss: 0.0676 - val_accuracy: 0.9864 - 60s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 0.3565 - accuracy: 0.8845 - val_loss: 0.0982 - val_accuracy: 0.9719 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 59s - loss: 0.3446 - accuracy: 0.8866 - val_loss: 0.1379 - val_accuracy: 0.9618 - 59s/epoch - 31ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 0.3363 - accuracy: 0.8901 - val_loss: 0.1739 - val_accuracy: 0.9439 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 54s - loss: 0.3275 - accuracy: 0.8925 - val_loss: 0.2047 - val_accuracy: 0.9326 - 54s/epoch - 29ms/step

# %%
plot_loss(all_loss_4, all_loss_history_4)

# %%
plot_acc(all_acc_4, all_acc_history_4)

# %%
print("Average Loss:", np.mean(all_val_loss_4))
print("Average Accuracy:", np.mean(all_val_acc_4))
# Out:
# Average Loss: 0.9011976100504399
# Average Accuracy: 0.7035024292767048

# %% [markdown]
# The average accuracy for Dropout=0.07 (0.704) is smaller than that of Dropout=0.1(0.826).
#
# The average loss of the former (0.901) is greater than the latter (0.525).
#
# However, from the plotted graphs, we can observe that we have achieved a model with a better fit where the training and validation curves are close to one another without overfitting when Dropout rate was lowered to 0.07.
#
# Hence, we can conclude that a smaller dropout values, dropout=0.07, is better than dropout=0.1 as the former is able to generalise better to unseen data.

# %% [markdown]
# ### 2. L1/L2 Regularizers + Batch Normalization
#
# To accelerate the training, we will be adding batch normalization layers after each layer of the neural network. Batch Normalization normalizes and adds noise to the activations of the previous layer, which helps prevent overfitting and makes training more robust.

# %% [markdown]
# #### Build the Model with L1/L2 Regularizers = 0.01

# %%
from keras.layers import BatchNormalization
from keras import regularizers
from keras.regularizers import l1_l2


# Initialising the model 
lstm_model_5 = Sequential()

# Defining model: add layers 
lstm_model_5.add(Embedding(
    max_words,
    EMBEDDING_VECTOR_LENGTH,
    input_length=max_len,
    weights=[embedding_matrix],
    trainable=True,
)) #glove embedding

lstm_model_5.add(BatchNormalization()) # BatchNormalization layer 
lstm_model_5.add(LSTM(128, input_shape=(max_len, EMBEDDING_VECTOR_LENGTH), return_sequences=True)) #LSTM layer
lstm_model_5.add(BatchNormalization())
lstm_model_5.add(LSTM(64, kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01)))
lstm_model_5.add(BatchNormalization())
lstm_model_5.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01))) 
lstm_model_5.add(BatchNormalization())
lstm_model_5.add(Dense(16, activation='softmax')) #dense layer - the last one

# Compile model
lstm_model_5.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

print(lstm_model_5.summary())
# Out:
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_25 (Embedding)    (None, 40, 50)            125000
#
#  batch_normalization_18 (Bat  (None, 40, 50)           200
#  chNormalization)
#
#  lstm_55 (LSTM)              (None, 40, 128)           91648
#
#  batch_normalization_19 (Bat  (None, 40, 128)          512
#  chNormalization)
#
#  lstm_56 (LSTM)              (None, 64)                49408
#
#  batch_normalization_20 (Bat  (None, 64)               256
#  chNormalization)
#
#  dense_45 (Dense)            (None, 64)                4160
#
#  batch_normalization_21 (Bat  (None, 64)               256
#  chNormalization)
#
#  dense_46 (Dense)            (None, 16)                1040
#
# =================================================================
# Total params: 272,480
# Trainable params: 271,868
# Non-trainable params: 612
# _________________________________________________________________
# None

# %% [markdown]
# #### Train the Model with L1/L2 Regularizers = 0.01

# %%
import numpy as np 
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_absolute_error

K=4
num_val_samples = len(X_train_resampled)//K
num_epochs = 5

all_val_acc_7 = []
all_val_loss_7 = []

all_acc_7 = []
all_loss_7 = []
all_acc_history_7 = []
all_loss_history_7 = []

N_iterations=4
N_folds=5
        
for i in range(N_iterations):
    skf = StratifiedKFold(n_splits=N_folds, shuffle=True)
    
    for j, (train_index, val_index) in enumerate(skf.split(X_train_resampled, y_train_resampled)):
        print('processing fold', j)
        
        partial_train_data = X_train_resampled[train_index]
        val_data = X_train_resampled[val_index]
        
        partial_train_targets = y_train_resampled[train_index]
        val_targets = y_train_resampled[val_index]
        
        # One-hot encode the target labels
        partial_train_targets = to_categorical(partial_train_targets, num_classes=16)
        val_targets = to_categorical(val_targets, num_classes=16)
        
        # Train the model 
        lstm_model_5.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
        results_7 = lstm_model_5.fit(partial_train_data, partial_train_targets, epochs=num_epochs, batch_size=10, verbose=2, validation_data = (val_data, val_targets))
        
        # Evaluate the model on the validation data: loss and accuracy 
        val_loss, val_acc = lstm_model_5.evaluate(val_data, val_targets, verbose=0)
        all_val_acc_7.append(val_acc)
        all_val_loss_7.append(val_loss)
        
        acc = results_7.history['accuracy']
        all_acc_7.append(acc)
        acc_history = results_7.history['val_accuracy']
        all_acc_history_7.append(acc_history)
        
        loss = results_7.history['loss']
        all_loss_7.append(loss)
        loss_history = results_7.history['val_loss']
        all_loss_history_7.append(loss_history)
# Out:
# processing fold 0
# Epoch 1/5
# 1877/1877 - 91s - loss: 5.8297 - accuracy: 0.0709 - val_loss: 3.5562 - val_accuracy: 0.0693 - 91s/epoch - 48ms/step
# Epoch 2/5
# 1877/1877 - 58s - loss: 3.1224 - accuracy: 0.0774 - val_loss: 2.8359 - val_accuracy: 0.0944 - 58s/epoch - 31ms/step
# Epoch 3/5
# 1877/1877 - 65s - loss: 2.7609 - accuracy: 0.1049 - val_loss: 2.9251 - val_accuracy: 0.0840 - 65s/epoch - 35ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 2.7685 - accuracy: 0.1107 - val_loss: 2.7992 - val_accuracy: 0.1093 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 60s - loss: 2.6877 - accuracy: 0.1190 - val_loss: 2.7784 - val_accuracy: 0.1083 - 60s/epoch - 32ms/step
# processing fold 1
# Epoch 1/5
# 1877/1877 - 63s - loss: 2.6675 - accuracy: 0.1186 - val_loss: 2.6199 - val_accuracy: 0.1264 - 63s/epoch - 34ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 2.6293 - accuracy: 0.1258 - val_loss: 2.7296 - val_accuracy: 0.1277 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 56s - loss: 2.6235 - accuracy: 0.1325 - val_loss: 2.6337 - val_accuracy: 0.1373 - 56s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 2.5365 - accuracy: 0.1402 - val_loss: 2.6496 - val_accuracy: 0.1200 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 2.4734 - accuracy: 0.1556 - val_loss: 2.7940 - val_accuracy: 0.1258 - 56s/epoch - 30ms/step
# processing fold 2
# Epoch 1/5
# 1877/1877 - 77s - loss: 2.5038 - accuracy: 0.1565 - val_loss: 2.4086 - val_accuracy: 0.1859 - 77s/epoch - 41ms/step
# Epoch 2/5
# 1877/1877 - 57s - loss: 2.4300 - accuracy: 0.1712 - val_loss: 2.4016 - val_accuracy: 0.1735 - 57s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 57s - loss: 2.3474 - accuracy: 0.1894 - val_loss: 2.4258 - val_accuracy: 0.1641 - 57s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 57s - loss: 2.2674 - accuracy: 0.2120 - val_loss: 2.5108 - val_accuracy: 0.1511 - 57s/epoch - 31ms/step
# Epoch 5/5
# 1877/1877 - 59s - loss: 2.1896 - accuracy: 0.2344 - val_loss: 2.5705 - val_accuracy: 0.1401 - 59s/epoch - 31ms/step
# processing fold 3
# Epoch 1/5
# 1877/1877 - 63s - loss: 2.2657 - accuracy: 0.2177 - val_loss: 2.0576 - val_accuracy: 0.2816 - 63s/epoch - 34ms/step
# Epoch 2/5
# 1877/1877 - 57s - loss: 2.1606 - accuracy: 0.2442 - val_loss: 2.0985 - val_accuracy: 0.2556 - 57s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 56s - loss: 2.0894 - accuracy: 0.2660 - val_loss: 2.2083 - val_accuracy: 0.2324 - 56s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 2.0118 - accuracy: 0.2854 - val_loss: 2.2725 - val_accuracy: 0.2042 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 59s - loss: 1.9436 - accuracy: 0.3076 - val_loss: 2.3913 - val_accuracy: 0.2046 - 59s/epoch - 31ms/step
# processing fold 4
# Epoch 1/5
# 1877/1877 - 64s - loss: 2.0427 - accuracy: 0.2807 - val_loss: 1.7986 - val_accuracy: 0.3652 - 64s/epoch - 34ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 1.9240 - accuracy: 0.3171 - val_loss: 1.8582 - val_accuracy: 0.3311 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 59s - loss: 1.8466 - accuracy: 0.3379 - val_loss: 1.8855 - val_accuracy: 0.3294 - 59s/epoch - 32ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 1.8164 - accuracy: 0.3463 - val_loss: 2.0145 - val_accuracy: 0.2906 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 1.7450 - accuracy: 0.3742 - val_loss: 2.0846 - val_accuracy: 0.2833 - 56s/epoch - 30ms/step
# processing fold 0
# Epoch 1/5
# 1877/1877 - 62s - loss: 1.8075 - accuracy: 0.3554 - val_loss: 1.8197 - val_accuracy: 0.3704 - 62s/epoch - 33ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 1.7274 - accuracy: 0.3808 - val_loss: 1.7307 - val_accuracy: 0.3851 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 56s - loss: 1.6624 - accuracy: 0.4007 - val_loss: 1.9215 - val_accuracy: 0.3244 - 56s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 1.6105 - accuracy: 0.4154 - val_loss: 2.1091 - val_accuracy: 0.3225 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 1.5820 - accuracy: 0.4265 - val_loss: 1.9595 - val_accuracy: 0.3344 - 56s/epoch - 30ms/step
# processing fold 1
# Epoch 1/5
# 1877/1877 - 85s - loss: 1.7125 - accuracy: 0.3966 - val_loss: 1.4851 - val_accuracy: 0.4922 - 85s/epoch - 45ms/step
# Epoch 2/5
# 1877/1877 - 82s - loss: 1.6144 - accuracy: 0.4203 - val_loss: 1.4713 - val_accuracy: 0.4549 - 82s/epoch - 44ms/step
# Epoch 3/5
# 1877/1877 - 64s - loss: 1.5683 - accuracy: 0.4318 - val_loss: 1.6709 - val_accuracy: 0.4038 - 64s/epoch - 34ms/step
# Epoch 4/5
# 1877/1877 - 79s - loss: 1.5138 - accuracy: 0.4495 - val_loss: 1.6561 - val_accuracy: 0.4172 - 79s/epoch - 42ms/step
# Epoch 5/5
# 1877/1877 - 59s - loss: 1.5197 - accuracy: 0.4517 - val_loss: 1.7691 - val_accuracy: 0.3671 - 59s/epoch - 31ms/step
# processing fold 2
# Epoch 1/5
# 1877/1877 - 78s - loss: 1.6076 - accuracy: 0.4261 - val_loss: 1.3039 - val_accuracy: 0.5575 - 78s/epoch - 42ms/step
# Epoch 2/5
# 1877/1877 - 77s - loss: 1.5119 - accuracy: 0.4519 - val_loss: 1.3482 - val_accuracy: 0.5197 - 77s/epoch - 41ms/step
# Epoch 3/5
# 1877/1877 - 66s - loss: 1.4596 - accuracy: 0.4771 - val_loss: 1.6483 - val_accuracy: 0.4411 - 66s/epoch - 35ms/step
# Epoch 4/5
# 1877/1877 - 71s - loss: 1.4328 - accuracy: 0.4803 - val_loss: 1.5916 - val_accuracy: 0.4451 - 71s/epoch - 38ms/step
# Epoch 5/5
# 1877/1877 - 75s - loss: 1.4212 - accuracy: 0.4908 - val_loss: 1.5457 - val_accuracy: 0.4353 - 75s/epoch - 40ms/step
# processing fold 3
# Epoch 1/5
# 1877/1877 - 72s - loss: 1.5223 - accuracy: 0.4556 - val_loss: 1.2713 - val_accuracy: 0.5528 - 72s/epoch - 39ms/step
# Epoch 2/5
# 1877/1877 - 90s - loss: 1.4281 - accuracy: 0.4903 - val_loss: 1.3228 - val_accuracy: 0.5025 - 90s/epoch - 48ms/step
# Epoch 3/5
# 1877/1877 - 62s - loss: 1.4025 - accuracy: 0.4926 - val_loss: 1.3401 - val_accuracy: 0.5210 - 62s/epoch - 33ms/step
# Epoch 4/5
# 1877/1877 - 63s - loss: 1.3995 - accuracy: 0.4967 - val_loss: 1.4876 - val_accuracy: 0.4583 - 63s/epoch - 34ms/step
# Epoch 5/5
# 1877/1877 - 60s - loss: 1.3460 - accuracy: 0.5134 - val_loss: 1.8685 - val_accuracy: 0.3771 - 60s/epoch - 32ms/step
# processing fold 4
# Epoch 1/5
# 1877/1877 - 74s - loss: 1.4535 - accuracy: 0.4800 - val_loss: 1.1745 - val_accuracy: 0.5800 - 74s/epoch - 39ms/step
# Epoch 2/5
# 1877/1877 - 69s - loss: 1.3684 - accuracy: 0.5083 - val_loss: 1.1875 - val_accuracy: 0.5615 - 69s/epoch - 37ms/step
# Epoch 3/5
# 1877/1877 - 79s - loss: 1.3266 - accuracy: 0.5159 - val_loss: 1.2473 - val_accuracy: 0.5519 - 79s/epoch - 42ms/step
# Epoch 4/5
# 1877/1877 - 86s - loss: 1.3247 - accuracy: 0.5235 - val_loss: 1.3953 - val_accuracy: 0.4980 - 86s/epoch - 46ms/step
# Epoch 5/5
# 1877/1877 - 85s - loss: 1.3516 - accuracy: 0.5213 - val_loss: 1.3705 - val_accuracy: 0.4995 - 85s/epoch - 45ms/step
# processing fold 0
# Epoch 1/5
# 1877/1877 - 93s - loss: 1.3759 - accuracy: 0.5070 - val_loss: 1.2524 - val_accuracy: 0.5752 - 93s/epoch - 49ms/step
# Epoch 2/5
# 1877/1877 - 67s - loss: 1.3055 - accuracy: 0.5293 - val_loss: 1.3372 - val_accuracy: 0.4964 - 67s/epoch - 36ms/step
# Epoch 3/5
# 1877/1877 - 70s - loss: 1.2952 - accuracy: 0.5363 - val_loss: 1.4821 - val_accuracy: 0.4840 - 70s/epoch - 37ms/step
# Epoch 4/5
# 1877/1877 - 73s - loss: 1.3030 - accuracy: 0.5333 - val_loss: 1.4323 - val_accuracy: 0.4921 - 73s/epoch - 39ms/step
# Epoch 5/5
# 1877/1877 - 76s - loss: 1.2598 - accuracy: 0.5466 - val_loss: 1.4665 - val_accuracy: 0.4763 - 76s/epoch - 41ms/step
# processing fold 1
# Epoch 1/5
# 1877/1877 - 87s - loss: 1.3814 - accuracy: 0.5089 - val_loss: 1.2565 - val_accuracy: 0.5444 - 87s/epoch - 47ms/step
# Epoch 2/5
# 1877/1877 - 86s - loss: 1.3093 - accuracy: 0.5246 - val_loss: 1.2229 - val_accuracy: 0.5438 - 86s/epoch - 46ms/step
# Epoch 3/5
# 1877/1877 - 66s - loss: 1.2833 - accuracy: 0.5462 - val_loss: 1.2172 - val_accuracy: 0.5809 - 66s/epoch - 35ms/step
# Epoch 4/5
# 1877/1877 - 74s - loss: 1.2845 - accuracy: 0.5445 - val_loss: 1.2753 - val_accuracy: 0.5583 - 74s/epoch - 39ms/step
# Epoch 5/5
# 1877/1877 - 86s - loss: 1.2486 - accuracy: 0.5622 - val_loss: 1.3807 - val_accuracy: 0.5195 - 86s/epoch - 46ms/step
# processing fold 2
# Epoch 1/5
# 1877/1877 - 70s - loss: 1.3535 - accuracy: 0.5261 - val_loss: 1.1254 - val_accuracy: 0.5926 - 70s/epoch - 37ms/step
# Epoch 2/5
# 1877/1877 - 102s - loss: 1.3027 - accuracy: 0.5355 - val_loss: 1.1175 - val_accuracy: 0.5937 - 102s/epoch - 54ms/step
# Epoch 3/5
# 1877/1877 - 84s - loss: 1.2491 - accuracy: 0.5533 - val_loss: 1.2092 - val_accuracy: 0.5766 - 84s/epoch - 45ms/step
# Epoch 4/5
# 1877/1877 - 78s - loss: 1.2409 - accuracy: 0.5574 - val_loss: 1.2865 - val_accuracy: 0.5453 - 78s/epoch - 41ms/step
# Epoch 5/5
# 1877/1877 - 74s - loss: 1.2375 - accuracy: 0.5585 - val_loss: 1.3978 - val_accuracy: 0.4871 - 74s/epoch - 40ms/step
# processing fold 3
# Epoch 1/5
# 1877/1877 - 97s - loss: 1.3214 - accuracy: 0.5365 - val_loss: 1.0378 - val_accuracy: 0.6500 - 97s/epoch - 52ms/step
# Epoch 2/5
# 1877/1877 - 72s - loss: 1.2445 - accuracy: 0.5571 - val_loss: 1.1053 - val_accuracy: 0.5773 - 72s/epoch - 39ms/step
# Epoch 3/5
# 1877/1877 - 75s - loss: 1.2359 - accuracy: 0.5631 - val_loss: 1.2073 - val_accuracy: 0.5609 - 75s/epoch - 40ms/step
# Epoch 4/5
# 1877/1877 - 76s - loss: 1.2206 - accuracy: 0.5692 - val_loss: 1.3172 - val_accuracy: 0.5496 - 76s/epoch - 40ms/step
# Epoch 5/5
# 1877/1877 - 67s - loss: 1.2144 - accuracy: 0.5703 - val_loss: 1.3215 - val_accuracy: 0.5022 - 67s/epoch - 36ms/step
# processing fold 4
# Epoch 1/5
# 1877/1877 - 68s - loss: 1.3074 - accuracy: 0.5425 - val_loss: 1.0118 - val_accuracy: 0.6566 - 68s/epoch - 36ms/step
# Epoch 2/5
# 1877/1877 - 63s - loss: 1.2135 - accuracy: 0.5761 - val_loss: 0.9915 - val_accuracy: 0.6504 - 63s/epoch - 33ms/step
# Epoch 3/5
# 1877/1877 - 62s - loss: 1.2028 - accuracy: 0.5789 - val_loss: 1.1273 - val_accuracy: 0.6182 - 62s/epoch - 33ms/step
# Epoch 4/5
# 1877/1877 - 63s - loss: 1.1911 - accuracy: 0.5821 - val_loss: 1.1550 - val_accuracy: 0.5911 - 63s/epoch - 33ms/step
# Epoch 5/5
# 1877/1877 - 62s - loss: 1.1756 - accuracy: 0.5811 - val_loss: 1.2301 - val_accuracy: 0.5361 - 62s/epoch - 33ms/step
# processing fold 0
# Epoch 1/5
# 1877/1877 - 67s - loss: 1.2369 - accuracy: 0.5669 - val_loss: 1.1264 - val_accuracy: 0.5757 - 67s/epoch - 36ms/step
# Epoch 2/5
# 1877/1877 - 61s - loss: 1.1944 - accuracy: 0.5782 - val_loss: 1.0614 - val_accuracy: 0.6275 - 61s/epoch - 33ms/step
# Epoch 3/5
# 1877/1877 - 62s - loss: 1.1678 - accuracy: 0.5865 - val_loss: 1.1387 - val_accuracy: 0.6044 - 62s/epoch - 33ms/step
# Epoch 4/5
# 1877/1877 - 61s - loss: 1.1789 - accuracy: 0.5900 - val_loss: 1.2615 - val_accuracy: 0.5550 - 61s/epoch - 33ms/step
# Epoch 5/5
# 1877/1877 - 183s - loss: 1.1587 - accuracy: 0.5910 - val_loss: 1.2828 - val_accuracy: 0.5554 - 183s/epoch - 98ms/step
# processing fold 1
# Epoch 1/5
# 1877/1877 - 81s - loss: 1.2567 - accuracy: 0.5558 - val_loss: 1.1058 - val_accuracy: 0.5653 - 81s/epoch - 43ms/step
# Epoch 2/5
# 1877/1877 - 58s - loss: 1.1877 - accuracy: 0.5850 - val_loss: 1.0393 - val_accuracy: 0.6389 - 58s/epoch - 31ms/step
# Epoch 3/5
# 1877/1877 - 57s - loss: 1.1586 - accuracy: 0.5964 - val_loss: 1.2791 - val_accuracy: 0.5602 - 57s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 63s - loss: 1.1448 - accuracy: 0.6011 - val_loss: 1.1045 - val_accuracy: 0.6080 - 63s/epoch - 33ms/step
# Epoch 5/5
# 1877/1877 - 68s - loss: 1.1435 - accuracy: 0.5979 - val_loss: 1.1802 - val_accuracy: 0.5730 - 68s/epoch - 36ms/step
# processing fold 2
# Epoch 1/5
# 1877/1877 - 76s - loss: 1.2237 - accuracy: 0.5748 - val_loss: 0.9884 - val_accuracy: 0.6455 - 76s/epoch - 41ms/step
# Epoch 2/5
# 1877/1877 - 63s - loss: 1.1642 - accuracy: 0.5886 - val_loss: 1.0398 - val_accuracy: 0.6323 - 63s/epoch - 33ms/step
# Epoch 3/5
# 1877/1877 - 68s - loss: 1.1481 - accuracy: 0.5991 - val_loss: 1.1157 - val_accuracy: 0.5980 - 68s/epoch - 36ms/step
# Epoch 4/5
# 1877/1877 - 67s - loss: 1.1369 - accuracy: 0.6062 - val_loss: 1.1738 - val_accuracy: 0.5990 - 67s/epoch - 36ms/step
# Epoch 5/5
# 1877/1877 - 65s - loss: 1.1283 - accuracy: 0.6029 - val_loss: 1.1451 - val_accuracy: 0.5852 - 65s/epoch - 34ms/step
# processing fold 3
# Epoch 1/5
# 1877/1877 - 67s - loss: 1.2180 - accuracy: 0.5728 - val_loss: 0.9887 - val_accuracy: 0.6391 - 67s/epoch - 36ms/step
# Epoch 2/5
# 1877/1877 - 59s - loss: 1.1400 - accuracy: 0.6051 - val_loss: 0.8911 - val_accuracy: 0.6956 - 59s/epoch - 31ms/step
# Epoch 3/5
# 1877/1877 - 59s - loss: 1.1158 - accuracy: 0.6099 - val_loss: 0.9851 - val_accuracy: 0.6657 - 59s/epoch - 32ms/step
# Epoch 4/5
# 1877/1877 - 58s - loss: 1.1321 - accuracy: 0.6017 - val_loss: 1.2763 - val_accuracy: 0.5112 - 58s/epoch - 31ms/step
# Epoch 5/5
# 1877/1877 - 58s - loss: 1.1176 - accuracy: 0.6127 - val_loss: 1.1742 - val_accuracy: 0.5694 - 58s/epoch - 31ms/step
# processing fold 4
# Epoch 1/5
# 1877/1877 - 82s - loss: 1.1870 - accuracy: 0.5847 - val_loss: 0.8801 - val_accuracy: 0.7118 - 82s/epoch - 43ms/step
# Epoch 2/5
# 1877/1877 - 58s - loss: 1.1375 - accuracy: 0.6028 - val_loss: 1.0312 - val_accuracy: 0.6425 - 58s/epoch - 31ms/step
# Epoch 3/5
# 1877/1877 - 62s - loss: 1.1140 - accuracy: 0.6194 - val_loss: 1.0575 - val_accuracy: 0.6272 - 62s/epoch - 33ms/step
# Epoch 4/5
# 1877/1877 - 59s - loss: 1.1228 - accuracy: 0.6104 - val_loss: 1.1019 - val_accuracy: 0.6118 - 59s/epoch - 32ms/step
# Epoch 5/5
# 1877/1877 - 59s - loss: 1.1103 - accuracy: 0.6133 - val_loss: 1.0834 - val_accuracy: 0.6250 - 59s/epoch - 32ms/step

# %%
plot_loss(all_loss_7, all_loss_history_7)

# %%
plot_acc(all_acc_7, all_acc_history_7)

# %%
print("Average Loss:", np.mean(all_val_loss_7))
print("Average Accuracy:", np.mean(all_val_acc_7))
# Out:
# Average Loss: 1.6897206604480743
# Average Accuracy: 0.415236896276474

# %% [markdown]
# #### Build the Model with L1/L2 Regularizers = 0.07

# %%
from keras.layers import BatchNormalization
from keras import regularizers
from keras.regularizers import l1_l2


# Initialising the model 
lstm_model_3 = Sequential()

# Defining model: add layers 
lstm_model_3.add(Embedding(
    max_words,
    EMBEDDING_VECTOR_LENGTH,
    input_length=max_len,
    weights=[embedding_matrix],
    trainable=True,
)) #glove embedding

lstm_model_3.add(BatchNormalization()) # BatchNormalization layer 
lstm_model_3.add(LSTM(128, input_shape=(max_len, EMBEDDING_VECTOR_LENGTH), return_sequences=True)) #LSTM layer
lstm_model_3.add(BatchNormalization())
lstm_model_3.add(LSTM(64, kernel_regularizer=regularizers.l1_l2(l1=0.07, l2=0.07)))
lstm_model_3.add(BatchNormalization())
lstm_model_3.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l1_l2(l1=0.07, l2=0.07))) 
lstm_model_3.add(BatchNormalization())
lstm_model_3.add(Dense(16, activation='softmax')) #dense layer - the last one

# Compile model
lstm_model_3.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

print(lstm_model_3.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 40, 50)            125000
#
#  batch_normalization_4 (Batc  (None, 40, 50)           200
#  hNormalization)
#
#  lstm_2 (LSTM)               (None, 40, 128)           91648
#
#  batch_normalization_5 (Batc  (None, 40, 128)          512
#  hNormalization)
#
#  lstm_3 (LSTM)               (None, 64)                49408
#
#  batch_normalization_6 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  batch_normalization_7 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_3 (Dense)             (None, 16)                1040
#
# =================================================================
# Total params: 272,480
# Trainable params: 271,868
# Non-trainable params: 612
# _________________________________________________________________
# None

# %%
import numpy as np 
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_absolute_error

K=4
num_val_samples = len(X_train_resampled)//K
num_epochs = 5

all_val_acc_5 = []
all_val_loss_5 = []

all_acc_5 = []
all_loss_5 = []
all_acc_history_5 = []
all_loss_history_5 = []

N_iterations=4
N_folds=5
        
for i in range(N_iterations):
    skf = StratifiedKFold(n_splits=N_folds, shuffle=True)
    
    for j, (train_index, val_index) in enumerate(skf.split(X_train_resampled, y_train_resampled)):
        print('processing fold', j)
        
        partial_train_data = X_train_resampled[train_index]
        val_data = X_train_resampled[val_index]
        
        partial_train_targets = y_train_resampled[train_index]
        val_targets = y_train_resampled[val_index]
        
        # One-hot encode the target labels
        partial_train_targets = to_categorical(partial_train_targets, num_classes=16)
        val_targets = to_categorical(val_targets, num_classes=16)
        
        # Train the model 
        lstm_model_3.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
        results_5 = lstm_model_3.fit(partial_train_data, partial_train_targets, epochs=num_epochs, batch_size=10, verbose=2, validation_data = (val_data, val_targets))
        
        # Evaluate the model on the validation data: loss and accuracy 
        val_loss, val_acc = lstm_model_3.evaluate(val_data, val_targets, verbose=0)
        all_val_acc_5.append(val_acc)
        all_val_loss_5.append(val_loss)
        
        acc = results_5.history['accuracy']
        all_acc_5.append(acc)
        acc_history = results_5.history['val_accuracy']
        all_acc_history_5.append(acc_history)
        
        loss = results_5.history['loss']
        all_loss_5.append(loss)
        loss_history = results_5.history['val_loss']
        all_loss_history_5.append(loss_history)
# Out:
# processing fold 0
# Epoch 1/5
# 1877/1877 - 71s - loss: 2.5364 - accuracy: 0.2005 - val_loss: 2.5975 - val_accuracy: 0.2008 - 71s/epoch - 38ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 2.5013 - accuracy: 0.2005 - val_loss: 2.3490 - val_accuracy: 0.2127 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 54s - loss: 2.4677 - accuracy: 0.2143 - val_loss: 2.6379 - val_accuracy: 0.1652 - 54s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 54s - loss: 2.4205 - accuracy: 0.2180 - val_loss: 2.4199 - val_accuracy: 0.2377 - 54s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 53s - loss: 2.3919 - accuracy: 0.2256 - val_loss: 2.1738 - val_accuracy: 0.2579 - 53s/epoch - 28ms/step
# processing fold 1
# Epoch 1/5
# 1877/1877 - 60s - loss: 2.4580 - accuracy: 0.2159 - val_loss: 2.5052 - val_accuracy: 0.1904 - 60s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 55s - loss: 2.4018 - accuracy: 0.2248 - val_loss: 2.4109 - val_accuracy: 0.2179 - 55s/epoch - 29ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 2.3452 - accuracy: 0.2341 - val_loss: 2.6274 - val_accuracy: 0.2087 - 55s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 2.3229 - accuracy: 0.2385 - val_loss: 2.6881 - val_accuracy: 0.1861 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 2.3034 - accuracy: 0.2441 - val_loss: 2.2577 - val_accuracy: 0.2364 - 55s/epoch - 30ms/step
# processing fold 2
# Epoch 1/5
# 1877/1877 - 61s - loss: 2.3469 - accuracy: 0.2331 - val_loss: 2.1368 - val_accuracy: 0.3068 - 61s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 55s - loss: 2.2951 - accuracy: 0.2485 - val_loss: 1.9932 - val_accuracy: 0.3146 - 55s/epoch - 29ms/step
# Epoch 3/5
# 1877/1877 - 57s - loss: 2.2695 - accuracy: 0.2520 - val_loss: 2.4934 - val_accuracy: 0.1993 - 57s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 2.2634 - accuracy: 0.2572 - val_loss: 2.5214 - val_accuracy: 0.2345 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 2.2339 - accuracy: 0.2622 - val_loss: 2.2270 - val_accuracy: 0.2347 - 56s/epoch - 30ms/step
# processing fold 3
# Epoch 1/5
# 1877/1877 - 60s - loss: 2.2821 - accuracy: 0.2515 - val_loss: 2.4317 - val_accuracy: 0.1371 - 60s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 2.2394 - accuracy: 0.2603 - val_loss: 2.1480 - val_accuracy: 0.1957 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 2.2133 - accuracy: 0.2682 - val_loss: 2.5375 - val_accuracy: 0.2000 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 2.2198 - accuracy: 0.2718 - val_loss: 2.2428 - val_accuracy: 0.3159 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 2.1811 - accuracy: 0.2764 - val_loss: 1.9132 - val_accuracy: 0.2978 - 55s/epoch - 30ms/step
# processing fold 4
# Epoch 1/5
# 1877/1877 - 60s - loss: 2.2305 - accuracy: 0.2664 - val_loss: 2.2340 - val_accuracy: 0.2349 - 60s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 2.1844 - accuracy: 0.2800 - val_loss: 1.7997 - val_accuracy: 0.3217 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 2.1696 - accuracy: 0.2844 - val_loss: 2.1825 - val_accuracy: 0.3624 - 55s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 2.1670 - accuracy: 0.2800 - val_loss: 2.3429 - val_accuracy: 0.2884 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 2.1585 - accuracy: 0.2949 - val_loss: 1.8523 - val_accuracy: 0.3089 - 56s/epoch - 30ms/step
# processing fold 0
# Epoch 1/5
# 1877/1877 - 59s - loss: 2.1794 - accuracy: 0.2792 - val_loss: 2.1738 - val_accuracy: 0.2685 - 59s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 55s - loss: 2.1654 - accuracy: 0.2853 - val_loss: 2.4133 - val_accuracy: 0.1673 - 55s/epoch - 29ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 2.1380 - accuracy: 0.2923 - val_loss: 2.4081 - val_accuracy: 0.2660 - 55s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 2.1230 - accuracy: 0.2986 - val_loss: 2.9757 - val_accuracy: 0.1238 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 2.1065 - accuracy: 0.3042 - val_loss: 3.4753 - val_accuracy: 0.1017 - 56s/epoch - 30ms/step
# processing fold 1
# Epoch 1/5
# 1877/1877 - 60s - loss: 2.1719 - accuracy: 0.2895 - val_loss: 2.1082 - val_accuracy: 0.2771 - 60s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 55s - loss: 2.1382 - accuracy: 0.3014 - val_loss: 2.9349 - val_accuracy: 0.1271 - 55s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 2.1035 - accuracy: 0.3121 - val_loss: 2.1811 - val_accuracy: 0.3777 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 2.1025 - accuracy: 0.3052 - val_loss: 2.2835 - val_accuracy: 0.3245 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 2.0969 - accuracy: 0.3100 - val_loss: 1.8038 - val_accuracy: 0.3281 - 56s/epoch - 30ms/step
# processing fold 2
# Epoch 1/5
# 1877/1877 - 61s - loss: 2.1512 - accuracy: 0.2955 - val_loss: 2.0494 - val_accuracy: 0.3456 - 61s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 55s - loss: 2.1016 - accuracy: 0.3116 - val_loss: 1.8270 - val_accuracy: 0.3149 - 55s/epoch - 29ms/step
# Epoch 3/5
# 1877/1877 - 56s - loss: 2.0946 - accuracy: 0.3140 - val_loss: 2.7720 - val_accuracy: 0.1889 - 56s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 2.0912 - accuracy: 0.3164 - val_loss: 2.2874 - val_accuracy: 0.3053 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 2.0872 - accuracy: 0.3184 - val_loss: 2.1511 - val_accuracy: 0.2140 - 56s/epoch - 30ms/step
# processing fold 3
# Epoch 1/5
# 1877/1877 - 61s - loss: 2.1144 - accuracy: 0.3082 - val_loss: 2.1109 - val_accuracy: 0.2466 - 61s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 2.0950 - accuracy: 0.3193 - val_loss: 2.0108 - val_accuracy: 0.2345 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 2.0677 - accuracy: 0.3236 - val_loss: 2.1161 - val_accuracy: 0.3844 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 2.0621 - accuracy: 0.3259 - val_loss: 2.3300 - val_accuracy: 0.3330 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 57s - loss: 2.0674 - accuracy: 0.3254 - val_loss: 2.1727 - val_accuracy: 0.1940 - 57s/epoch - 30ms/step
# processing fold 4
# Epoch 1/5
# 1877/1877 - 61s - loss: 2.1072 - accuracy: 0.3100 - val_loss: 1.9882 - val_accuracy: 0.3038 - 61s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 2.0667 - accuracy: 0.3197 - val_loss: 1.8543 - val_accuracy: 0.3294 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 56s - loss: 2.0698 - accuracy: 0.3209 - val_loss: 2.4291 - val_accuracy: 0.2356 - 56s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 2.0891 - accuracy: 0.3223 - val_loss: 2.4043 - val_accuracy: 0.3093 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 2.0746 - accuracy: 0.3212 - val_loss: 2.0400 - val_accuracy: 0.2362 - 56s/epoch - 30ms/step
# processing fold 0
# Epoch 1/5
# 1877/1877 - 62s - loss: 2.0826 - accuracy: 0.3169 - val_loss: 1.8805 - val_accuracy: 0.4154 - 62s/epoch - 33ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 2.0735 - accuracy: 0.3265 - val_loss: 1.8196 - val_accuracy: 0.3135 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 56s - loss: 2.0604 - accuracy: 0.3278 - val_loss: 2.2573 - val_accuracy: 0.3046 - 56s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 2.0442 - accuracy: 0.3306 - val_loss: 2.1704 - val_accuracy: 0.3866 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 2.0578 - accuracy: 0.3270 - val_loss: 2.1538 - val_accuracy: 0.2140 - 56s/epoch - 30ms/step
# processing fold 1
# Epoch 1/5
# 1877/1877 - 60s - loss: 2.0890 - accuracy: 0.3216 - val_loss: 2.0607 - val_accuracy: 0.2878 - 60s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 2.0594 - accuracy: 0.3230 - val_loss: 2.0333 - val_accuracy: 0.2825 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 2.0451 - accuracy: 0.3266 - val_loss: 2.3290 - val_accuracy: 0.3087 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 2.0439 - accuracy: 0.3340 - val_loss: 2.8127 - val_accuracy: 0.2402 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 2.0498 - accuracy: 0.3291 - val_loss: 1.8457 - val_accuracy: 0.3560 - 56s/epoch - 30ms/step
# processing fold 2
# Epoch 1/5
# 1877/1877 - 62s - loss: 2.0658 - accuracy: 0.3230 - val_loss: 1.9603 - val_accuracy: 0.3085 - 62s/epoch - 33ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 2.0407 - accuracy: 0.3313 - val_loss: 2.2716 - val_accuracy: 0.1780 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 56s - loss: 2.0188 - accuracy: 0.3387 - val_loss: 2.1249 - val_accuracy: 0.2965 - 56s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 2.0292 - accuracy: 0.3378 - val_loss: 2.4652 - val_accuracy: 0.2311 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 2.0354 - accuracy: 0.3332 - val_loss: 1.8050 - val_accuracy: 0.3566 - 56s/epoch - 30ms/step
# processing fold 3
# Epoch 1/5
# 1877/1877 - 60s - loss: 2.0786 - accuracy: 0.3203 - val_loss: 2.1312 - val_accuracy: 0.2686 - 60s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 2.0428 - accuracy: 0.3344 - val_loss: 2.3711 - val_accuracy: 0.1460 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 2.0134 - accuracy: 0.3375 - val_loss: 2.9935 - val_accuracy: 0.1405 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 2.0256 - accuracy: 0.3331 - val_loss: 2.0388 - val_accuracy: 0.3752 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 2.0302 - accuracy: 0.3398 - val_loss: 1.9393 - val_accuracy: 0.3072 - 55s/epoch - 29ms/step
# processing fold 4
# Epoch 1/5
# 1877/1877 - 60s - loss: 2.0657 - accuracy: 0.3249 - val_loss: 1.9331 - val_accuracy: 0.3848 - 60s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 57s - loss: 2.0498 - accuracy: 0.3308 - val_loss: 2.2365 - val_accuracy: 0.2010 - 57s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 56s - loss: 2.0043 - accuracy: 0.3394 - val_loss: 2.2253 - val_accuracy: 0.2891 - 56s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 2.0165 - accuracy: 0.3407 - val_loss: 2.6318 - val_accuracy: 0.1963 - 55s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 2.0101 - accuracy: 0.3394 - val_loss: 3.5108 - val_accuracy: 0.1305 - 56s/epoch - 30ms/step
# processing fold 0
# Epoch 1/5
# 1877/1877 - 60s - loss: 2.0471 - accuracy: 0.3330 - val_loss: 1.9898 - val_accuracy: 0.3702 - 60s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 2.0095 - accuracy: 0.3488 - val_loss: 2.1444 - val_accuracy: 0.2170 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 56s - loss: 2.0127 - accuracy: 0.3384 - val_loss: 2.1817 - val_accuracy: 0.3026 - 56s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 2.0008 - accuracy: 0.3456 - val_loss: 2.1927 - val_accuracy: 0.3523 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 2.0040 - accuracy: 0.3439 - val_loss: 1.7277 - val_accuracy: 0.3698 - 56s/epoch - 30ms/step
# processing fold 1
# Epoch 1/5
# 1877/1877 - 60s - loss: 2.0359 - accuracy: 0.3340 - val_loss: 1.8248 - val_accuracy: 0.4396 - 60s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 2.0062 - accuracy: 0.3448 - val_loss: 2.4741 - val_accuracy: 0.1260 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 70s - loss: 2.0143 - accuracy: 0.3383 - val_loss: 2.4696 - val_accuracy: 0.2223 - 70s/epoch - 37ms/step
# Epoch 4/5
# 1877/1877 - 58s - loss: 1.9899 - accuracy: 0.3478 - val_loss: 2.0701 - val_accuracy: 0.4174 - 58s/epoch - 31ms/step
# Epoch 5/5
# 1877/1877 - 57s - loss: 2.0119 - accuracy: 0.3450 - val_loss: 1.7088 - val_accuracy: 0.3731 - 57s/epoch - 30ms/step
# processing fold 2
# Epoch 1/5
# 1877/1877 - 61s - loss: 2.0320 - accuracy: 0.3328 - val_loss: 2.2808 - val_accuracy: 0.1814 - 61s/epoch - 33ms/step
# Epoch 2/5
# 1877/1877 - 57s - loss: 1.9921 - accuracy: 0.3451 - val_loss: 1.6034 - val_accuracy: 0.4121 - 57s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 57s - loss: 1.9876 - accuracy: 0.3497 - val_loss: 2.3510 - val_accuracy: 0.3036 - 57s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 59s - loss: 2.0032 - accuracy: 0.3413 - val_loss: 2.1511 - val_accuracy: 0.3632 - 59s/epoch - 31ms/step
# Epoch 5/5
# 1877/1877 - 58s - loss: 1.9983 - accuracy: 0.3455 - val_loss: 2.3596 - val_accuracy: 0.1369 - 58s/epoch - 31ms/step
# processing fold 3
# Epoch 1/5
# 1877/1877 - 60s - loss: 2.0397 - accuracy: 0.3366 - val_loss: 2.0781 - val_accuracy: 0.2631 - 60s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 58s - loss: 2.0136 - accuracy: 0.3428 - val_loss: 1.5788 - val_accuracy: 0.4419 - 58s/epoch - 31ms/step
# Epoch 3/5
# 1877/1877 - 56s - loss: 2.0116 - accuracy: 0.3436 - val_loss: 2.2719 - val_accuracy: 0.2923 - 56s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 2.0138 - accuracy: 0.3434 - val_loss: 4.1200 - val_accuracy: 0.0765 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 1.9843 - accuracy: 0.3569 - val_loss: 2.2054 - val_accuracy: 0.2720 - 56s/epoch - 30ms/step
# processing fold 4
# Epoch 1/5
# 1877/1877 - 64s - loss: 2.0327 - accuracy: 0.3389 - val_loss: 1.8425 - val_accuracy: 0.4035 - 64s/epoch - 34ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 2.0186 - accuracy: 0.3415 - val_loss: 2.0263 - val_accuracy: 0.2850 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 57s - loss: 1.9969 - accuracy: 0.3498 - val_loss: 2.1018 - val_accuracy: 0.3641 - 57s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 1.9590 - accuracy: 0.3551 - val_loss: 2.0735 - val_accuracy: 0.4046 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 1.9688 - accuracy: 0.3570 - val_loss: 1.6634 - val_accuracy: 0.3861 - 55s/epoch - 30ms/step

# %%
print("Average Loss:", np.mean(all_val_loss_5))
print("Average Accuracy:", np.mean(all_val_acc_5))#
# Out:
# Average Loss: 2.1695820569992064
# Average Accuracy: 0.26218423061072826

# %% [markdown]
# #### L1/L2 = 0.005

# %%
from keras.layers import BatchNormalization
from keras import regularizers
from keras.regularizers import l1_l2


# Initialising the model 
lstm_model_3 = Sequential()

# Defining model: add layers 
lstm_model_3.add(Embedding(
    max_words,
    EMBEDDING_VECTOR_LENGTH,
    input_length=max_len,
    weights=[embedding_matrix],
    trainable=True,
)) #glove embedding

lstm_model_3.add(BatchNormalization()) # BatchNormalization layer 
lstm_model_3.add(LSTM(128, input_shape=(max_len, EMBEDDING_VECTOR_LENGTH), return_sequences=True)) #LSTM layer
lstm_model_3.add(BatchNormalization())
lstm_model_3.add(LSTM(64, kernel_regularizer=regularizers.l1_l2(l1=0.005, l2=0.005)))
lstm_model_3.add(BatchNormalization())
lstm_model_3.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l1_l2(l1=0.005, l2=0.005))) 
lstm_model_3.add(BatchNormalization())
lstm_model_3.add(Dense(16, activation='softmax')) #dense layer - the last one

# Compile model
lstm_model_3.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

print(lstm_model_3.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 40, 50)            125000
#
#  batch_normalization_8 (Batc  (None, 40, 50)           200
#  hNormalization)
#
#  lstm_4 (LSTM)               (None, 40, 128)           91648
#
#  batch_normalization_9 (Batc  (None, 40, 128)          512
#  hNormalization)
#
#  lstm_5 (LSTM)               (None, 64)                49408
#
#  batch_normalization_10 (Bat  (None, 64)               256
#  chNormalization)
#
#  dense_4 (Dense)             (None, 64)                4160
#
#  batch_normalization_11 (Bat  (None, 64)               256
#  chNormalization)
#
#  dense_5 (Dense)             (None, 16)                1040
#
# =================================================================
# Total params: 272,480
# Trainable params: 271,868
# Non-trainable params: 612
# _________________________________________________________________
# None

# %%
import numpy as np 
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_absolute_error

K=4
num_val_samples = len(X_train_resampled)//K
num_epochs = 5

all_val_acc_5 = []
all_val_loss_5 = []

all_acc_5 = []
all_loss_5 = []
all_acc_history_5 = []
all_loss_history_5 = []

N_iterations=4
N_folds=5
        
for i in range(N_iterations):
    skf = StratifiedKFold(n_splits=N_folds, shuffle=True)
    
    for j, (train_index, val_index) in enumerate(skf.split(X_train_resampled, y_train_resampled)):
        print('processing fold', j)
        
        partial_train_data = X_train_resampled[train_index]
        val_data = X_train_resampled[val_index]
        
        partial_train_targets = y_train_resampled[train_index]
        val_targets = y_train_resampled[val_index]
        
        # One-hot encode the target labels
        partial_train_targets = to_categorical(partial_train_targets, num_classes=16)
        val_targets = to_categorical(val_targets, num_classes=16)
        
        # Train the model 
        lstm_model_3.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
        results_5 = lstm_model_3.fit(partial_train_data, partial_train_targets, epochs=num_epochs, batch_size=10, verbose=2, validation_data = (val_data, val_targets))
        
        # Evaluate the model on the validation data: loss and accuracy 
        val_loss, val_acc = lstm_model_3.evaluate(val_data, val_targets, verbose=0)
        all_val_acc_5.append(val_acc)
        all_val_loss_5.append(val_loss)
        
        acc = results_5.history['accuracy']
        all_acc_5.append(acc)
        acc_history = results_5.history['val_accuracy']
        all_acc_history_5.append(acc_history)
        
        loss = results_5.history['loss']
        all_loss_5.append(loss)
        loss_history = results_5.history['val_loss']
        all_loss_history_5.append(loss_history)
# Out:
# processing fold 0
# Epoch 1/5
# 1877/1877 - 86s - loss: 5.1941 - accuracy: 0.0732 - val_loss: 3.1361 - val_accuracy: 0.0616 - 86s/epoch - 46ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 3.6994 - accuracy: 0.0735 - val_loss: 3.4188 - val_accuracy: 0.0763 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 2.9516 - accuracy: 0.0924 - val_loss: 2.8271 - val_accuracy: 0.0951 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 2.7750 - accuracy: 0.1040 - val_loss: 2.7831 - val_accuracy: 0.1115 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 2.7364 - accuracy: 0.1138 - val_loss: 2.8043 - val_accuracy: 0.0951 - 55s/epoch - 29ms/step
# processing fold 1
# Epoch 1/5
# 1877/1877 - 60s - loss: 2.6803 - accuracy: 0.1253 - val_loss: 2.6645 - val_accuracy: 0.1266 - 60s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 55s - loss: 2.6456 - accuracy: 0.1370 - val_loss: 2.6495 - val_accuracy: 0.1334 - 55s/epoch - 29ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 2.5917 - accuracy: 0.1509 - val_loss: 2.6679 - val_accuracy: 0.1354 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 2.5455 - accuracy: 0.1647 - val_loss: 2.7416 - val_accuracy: 0.1384 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 2.4834 - accuracy: 0.1806 - val_loss: 2.7145 - val_accuracy: 0.1290 - 55s/epoch - 29ms/step
# processing fold 2
# Epoch 1/5
# 1877/1877 - 60s - loss: 2.4927 - accuracy: 0.1792 - val_loss: 2.3727 - val_accuracy: 0.2046 - 60s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 54s - loss: 2.4149 - accuracy: 0.2025 - val_loss: 2.4110 - val_accuracy: 0.1921 - 54s/epoch - 29ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 2.3346 - accuracy: 0.2244 - val_loss: 2.4406 - val_accuracy: 0.1872 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 54s - loss: 2.2516 - accuracy: 0.2508 - val_loss: 2.5507 - val_accuracy: 0.1936 - 54s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 2.1545 - accuracy: 0.2760 - val_loss: 2.5323 - val_accuracy: 0.1791 - 55s/epoch - 29ms/step
# processing fold 3
# Epoch 1/5
# 1877/1877 - 60s - loss: 2.2223 - accuracy: 0.2646 - val_loss: 2.0271 - val_accuracy: 0.3061 - 60s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 55s - loss: 2.1029 - accuracy: 0.2970 - val_loss: 2.1318 - val_accuracy: 0.2912 - 55s/epoch - 29ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 2.0047 - accuracy: 0.3258 - val_loss: 2.3364 - val_accuracy: 0.2315 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 1.9090 - accuracy: 0.3535 - val_loss: 2.1636 - val_accuracy: 0.2803 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 1.8168 - accuracy: 0.3868 - val_loss: 2.2716 - val_accuracy: 0.2543 - 55s/epoch - 29ms/step
# processing fold 4
# Epoch 1/5
# 1877/1877 - 59s - loss: 1.9253 - accuracy: 0.3599 - val_loss: 1.6260 - val_accuracy: 0.4336 - 59s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 55s - loss: 1.7916 - accuracy: 0.3998 - val_loss: 1.6442 - val_accuracy: 0.4419 - 55s/epoch - 29ms/step
# Epoch 3/5
# 1877/1877 - 54s - loss: 1.6936 - accuracy: 0.4290 - val_loss: 1.7212 - val_accuracy: 0.4176 - 54s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 1.5997 - accuracy: 0.4545 - val_loss: 1.8155 - val_accuracy: 0.3850 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 1.5248 - accuracy: 0.4853 - val_loss: 1.9798 - val_accuracy: 0.3694 - 55s/epoch - 29ms/step
# processing fold 0
# Epoch 1/5
# 1877/1877 - 60s - loss: 1.5955 - accuracy: 0.4763 - val_loss: 1.4574 - val_accuracy: 0.5119 - 60s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 55s - loss: 1.4672 - accuracy: 0.5096 - val_loss: 1.5663 - val_accuracy: 0.4780 - 55s/epoch - 29ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 1.3915 - accuracy: 0.5353 - val_loss: 1.8070 - val_accuracy: 0.4226 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 1.3277 - accuracy: 0.5559 - val_loss: 1.8030 - val_accuracy: 0.4062 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 1.2629 - accuracy: 0.5784 - val_loss: 1.9870 - val_accuracy: 0.3838 - 55s/epoch - 29ms/step
# processing fold 1
# Epoch 1/5
# 1877/1877 - 59s - loss: 1.4549 - accuracy: 0.5274 - val_loss: 1.0796 - val_accuracy: 0.6583 - 59s/epoch - 31ms/step
# Epoch 2/5
# 1877/1877 - 55s - loss: 1.2990 - accuracy: 0.5717 - val_loss: 1.2734 - val_accuracy: 0.5609 - 55s/epoch - 29ms/step
# Epoch 3/5
# 1877/1877 - 54s - loss: 1.2179 - accuracy: 0.5959 - val_loss: 1.3548 - val_accuracy: 0.5451 - 54s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 1.1647 - accuracy: 0.6125 - val_loss: 1.3381 - val_accuracy: 0.5589 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 54s - loss: 1.1091 - accuracy: 0.6346 - val_loss: 1.4668 - val_accuracy: 0.5169 - 54s/epoch - 29ms/step
# processing fold 2
# Epoch 1/5
# 1877/1877 - 70s - loss: 1.2597 - accuracy: 0.5951 - val_loss: 0.9107 - val_accuracy: 0.7256 - 70s/epoch - 37ms/step
# Epoch 2/5
# 1877/1877 - 58s - loss: 1.1340 - accuracy: 0.6308 - val_loss: 0.9831 - val_accuracy: 0.6807 - 58s/epoch - 31ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 1.0818 - accuracy: 0.6480 - val_loss: 1.0582 - val_accuracy: 0.6619 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 1.0284 - accuracy: 0.6653 - val_loss: 1.2154 - val_accuracy: 0.6001 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 1.0040 - accuracy: 0.6756 - val_loss: 1.3293 - val_accuracy: 0.5719 - 55s/epoch - 29ms/step
# processing fold 3
# Epoch 1/5
# 1877/1877 - 60s - loss: 1.1263 - accuracy: 0.6369 - val_loss: 0.8474 - val_accuracy: 0.7218 - 60s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 55s - loss: 0.9986 - accuracy: 0.6828 - val_loss: 1.0070 - val_accuracy: 0.6463 - 55s/epoch - 29ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 0.9848 - accuracy: 0.6814 - val_loss: 0.8966 - val_accuracy: 0.7092 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 0.9198 - accuracy: 0.7059 - val_loss: 0.9323 - val_accuracy: 0.6952 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 0.8911 - accuracy: 0.7131 - val_loss: 1.0425 - val_accuracy: 0.6596 - 56s/epoch - 30ms/step
# processing fold 4
# Epoch 1/5
# 1877/1877 - 59s - loss: 1.0091 - accuracy: 0.6757 - val_loss: 0.6099 - val_accuracy: 0.8373 - 59s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 0.9323 - accuracy: 0.6999 - val_loss: 0.7147 - val_accuracy: 0.7843 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 54s - loss: 0.8893 - accuracy: 0.7180 - val_loss: 0.7782 - val_accuracy: 0.7627 - 54s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 0.8619 - accuracy: 0.7225 - val_loss: 0.8806 - val_accuracy: 0.7269 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 0.8429 - accuracy: 0.7358 - val_loss: 0.9435 - val_accuracy: 0.6992 - 55s/epoch - 29ms/step
# processing fold 0
# Epoch 1/5
# 1877/1877 - 60s - loss: 0.9006 - accuracy: 0.7154 - val_loss: 0.6586 - val_accuracy: 0.8105 - 60s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 55s - loss: 0.8340 - accuracy: 0.7384 - val_loss: 0.6730 - val_accuracy: 0.8037 - 55s/epoch - 29ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 0.8124 - accuracy: 0.7471 - val_loss: 0.9104 - val_accuracy: 0.6965 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 0.7866 - accuracy: 0.7526 - val_loss: 0.8813 - val_accuracy: 0.7206 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 0.7766 - accuracy: 0.7568 - val_loss: 0.9829 - val_accuracy: 0.6795 - 55s/epoch - 29ms/step
# processing fold 1
# Epoch 1/5
# 1877/1877 - 60s - loss: 0.8909 - accuracy: 0.7205 - val_loss: 0.5454 - val_accuracy: 0.8616 - 60s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 55s - loss: 0.8186 - accuracy: 0.7476 - val_loss: 0.7462 - val_accuracy: 0.7598 - 55s/epoch - 29ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 0.7736 - accuracy: 0.7638 - val_loss: 0.8013 - val_accuracy: 0.7465 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 0.7620 - accuracy: 0.7606 - val_loss: 0.7982 - val_accuracy: 0.7519 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 0.7429 - accuracy: 0.7688 - val_loss: 0.7385 - val_accuracy: 0.7725 - 55s/epoch - 29ms/step
# processing fold 2
# Epoch 1/5
# 1877/1877 - 60s - loss: 0.8513 - accuracy: 0.7372 - val_loss: 0.4650 - val_accuracy: 0.8945 - 60s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 55s - loss: 0.7638 - accuracy: 0.7647 - val_loss: 0.5325 - val_accuracy: 0.8538 - 55s/epoch - 29ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 0.7357 - accuracy: 0.7736 - val_loss: 0.7632 - val_accuracy: 0.7531 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 0.7090 - accuracy: 0.7835 - val_loss: 0.9010 - val_accuracy: 0.7092 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 0.6976 - accuracy: 0.7882 - val_loss: 0.8509 - val_accuracy: 0.7263 - 55s/epoch - 29ms/step
# processing fold 3
# Epoch 1/5
# 1877/1877 - 61s - loss: 0.7941 - accuracy: 0.7579 - val_loss: 0.4831 - val_accuracy: 0.8727 - 61s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 54s - loss: 0.7187 - accuracy: 0.7780 - val_loss: 0.6231 - val_accuracy: 0.8003 - 54s/epoch - 29ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 0.7194 - accuracy: 0.7783 - val_loss: 0.5839 - val_accuracy: 0.8269 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 0.6874 - accuracy: 0.7869 - val_loss: 0.5595 - val_accuracy: 0.8429 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 0.6736 - accuracy: 0.7918 - val_loss: 0.7116 - val_accuracy: 0.7800 - 55s/epoch - 29ms/step
# processing fold 4
# Epoch 1/5
# 1877/1877 - 60s - loss: 0.7749 - accuracy: 0.7604 - val_loss: 0.4057 - val_accuracy: 0.8975 - 60s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 55s - loss: 0.7130 - accuracy: 0.7784 - val_loss: 0.4591 - val_accuracy: 0.8806 - 55s/epoch - 29ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 0.6759 - accuracy: 0.7932 - val_loss: 0.5106 - val_accuracy: 0.8599 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 0.6699 - accuracy: 0.7965 - val_loss: 0.5631 - val_accuracy: 0.8331 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 0.6729 - accuracy: 0.7972 - val_loss: 0.5984 - val_accuracy: 0.8246 - 55s/epoch - 29ms/step
# processing fold 0
# Epoch 1/5
# 1877/1877 - 60s - loss: 0.7385 - accuracy: 0.7765 - val_loss: 0.5319 - val_accuracy: 0.8431 - 60s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 55s - loss: 0.6561 - accuracy: 0.7994 - val_loss: 0.4881 - val_accuracy: 0.8634 - 55s/epoch - 29ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 0.6333 - accuracy: 0.8095 - val_loss: 0.7092 - val_accuracy: 0.7751 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 0.6425 - accuracy: 0.8035 - val_loss: 0.6051 - val_accuracy: 0.8193 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 0.6283 - accuracy: 0.8131 - val_loss: 0.6220 - val_accuracy: 0.8233 - 55s/epoch - 29ms/step
# processing fold 1
# Epoch 1/5
# 1877/1877 - 60s - loss: 0.7354 - accuracy: 0.7832 - val_loss: 0.4167 - val_accuracy: 0.8985 - 60s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 55s - loss: 0.6424 - accuracy: 0.8054 - val_loss: 0.4888 - val_accuracy: 0.8482 - 55s/epoch - 29ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 0.6325 - accuracy: 0.8069 - val_loss: 0.5020 - val_accuracy: 0.8585 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 0.6365 - accuracy: 0.8084 - val_loss: 0.6549 - val_accuracy: 0.7966 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 0.6185 - accuracy: 0.8162 - val_loss: 0.5923 - val_accuracy: 0.8239 - 55s/epoch - 29ms/step
# processing fold 2
# Epoch 1/5
# 1877/1877 - 60s - loss: 0.6995 - accuracy: 0.7847 - val_loss: 0.3694 - val_accuracy: 0.9077 - 60s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 55s - loss: 0.6597 - accuracy: 0.8012 - val_loss: 0.4601 - val_accuracy: 0.8768 - 55s/epoch - 29ms/step
# Epoch 3/5
# 1877/1877 - 56s - loss: 0.6284 - accuracy: 0.8082 - val_loss: 0.4138 - val_accuracy: 0.8943 - 56s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 0.6083 - accuracy: 0.8185 - val_loss: 0.4862 - val_accuracy: 0.8585 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 0.6182 - accuracy: 0.8168 - val_loss: 0.5600 - val_accuracy: 0.8365 - 56s/epoch - 30ms/step
# processing fold 3
# Epoch 1/5
# 1877/1877 - 66s - loss: 0.6694 - accuracy: 0.7967 - val_loss: 0.2992 - val_accuracy: 0.9463 - 66s/epoch - 35ms/step
# Epoch 2/5
# 1877/1877 - 55s - loss: 0.6131 - accuracy: 0.8133 - val_loss: 0.3511 - val_accuracy: 0.9222 - 55s/epoch - 29ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 0.6175 - accuracy: 0.8171 - val_loss: 0.4926 - val_accuracy: 0.8508 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 0.5799 - accuracy: 0.8272 - val_loss: 0.7759 - val_accuracy: 0.7536 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 0.5926 - accuracy: 0.8253 - val_loss: 0.4881 - val_accuracy: 0.8544 - 55s/epoch - 29ms/step
# processing fold 4
# Epoch 1/5
# 1877/1877 - 60s - loss: 0.6716 - accuracy: 0.7990 - val_loss: 0.3966 - val_accuracy: 0.8962 - 60s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 55s - loss: 0.6117 - accuracy: 0.8140 - val_loss: 0.3974 - val_accuracy: 0.8966 - 55s/epoch - 29ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 0.5877 - accuracy: 0.8229 - val_loss: 0.3460 - val_accuracy: 0.9213 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 54s - loss: 0.5829 - accuracy: 0.8290 - val_loss: 0.4600 - val_accuracy: 0.8715 - 54s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 0.5851 - accuracy: 0.8278 - val_loss: 0.5025 - val_accuracy: 0.8476 - 55s/epoch - 29ms/step

# %%
print("Average Loss:", np.mean(all_val_loss_5))
print("Average Accuracy:", np.mean(all_val_acc_5))
# Out:
# Average Loss: 1.285940670967102
# Average Accuracy: 0.5913453251123428

# %%
plot_loss(all_loss_5, all_loss_history_5)

# %%
plot_acc(all_acc_5, all_acc_history_5)

# %% [markdown]
# #### L1/L2 = 0.001

# %%
from keras.layers import BatchNormalization
from keras import regularizers
from keras.regularizers import l1_l2


# Initialising the model 
lstm_model_4 = Sequential()

# Defining model: add layers 
lstm_model_4.add(Embedding(
    max_words,
    EMBEDDING_VECTOR_LENGTH,
    input_length=max_len,
    weights=[embedding_matrix],
    trainable=True,
)) #glove embedding

lstm_model_4.add(BatchNormalization()) # BatchNormalization layer 
lstm_model_4.add(LSTM(128, input_shape=(max_len, EMBEDDING_VECTOR_LENGTH), return_sequences=True)) #LSTM layer
lstm_model_4.add(BatchNormalization())
lstm_model_4.add(LSTM(64, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.001)))
lstm_model_4.add(BatchNormalization())
lstm_model_4.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.001))) 
lstm_model_4.add(BatchNormalization())
lstm_model_4.add(Dense(16, activation='softmax')) #dense layer - the last one

# Compile model
lstm_model_4.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

print(lstm_model_4.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 40, 50)            125000
#
#  batch_normalization_12 (Bat  (None, 40, 50)           200
#  chNormalization)
#
#  lstm_6 (LSTM)               (None, 40, 128)           91648
#
#  batch_normalization_13 (Bat  (None, 40, 128)          512
#  chNormalization)
#
#  lstm_7 (LSTM)               (None, 64)                49408
#
#  batch_normalization_14 (Bat  (None, 64)               256
#  chNormalization)
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  batch_normalization_15 (Bat  (None, 64)               256
#  chNormalization)
#
#  dense_7 (Dense)             (None, 16)                1040
#
# =================================================================
# Total params: 272,480
# Trainable params: 271,868
# Non-trainable params: 612
# _________________________________________________________________
# None

# %%
import numpy as np 
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_absolute_error

K=4
num_val_samples = len(X_train_resampled)//K
num_epochs = 5

all_val_acc_6 = []
all_val_loss_6 = []

all_acc_6 = []
all_loss_6 = []
all_acc_history_6 = []
all_loss_history_6 = []

N_iterations=4
N_folds=5
        
for i in range(N_iterations):
    skf = StratifiedKFold(n_splits=N_folds, shuffle=True)
    
    for j, (train_index, val_index) in enumerate(skf.split(X_train_resampled, y_train_resampled)):
        print('processing fold', j)
        
        partial_train_data = X_train_resampled[train_index]
        val_data = X_train_resampled[val_index]
        
        partial_train_targets = y_train_resampled[train_index]
        val_targets = y_train_resampled[val_index]
        
        # One-hot encode the target labels
        partial_train_targets = to_categorical(partial_train_targets, num_classes=16)
        val_targets = to_categorical(val_targets, num_classes=16)
        
        # Train the model 
        lstm_model_4.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
        results_6 = lstm_model_4.fit(partial_train_data, partial_train_targets, epochs=num_epochs, batch_size=10, verbose=2, validation_data = (val_data, val_targets))
        
        # Evaluate the model on the validation data: loss and accuracy 
        val_loss, val_acc = lstm_model_4.evaluate(val_data, val_targets, verbose=0)
        all_val_acc_6.append(val_acc)
        all_val_loss_6.append(val_loss)
        
        acc = results_6.history['accuracy']
        all_acc_6.append(acc)
        acc_history = results_6.history['val_accuracy']
        all_acc_history_6.append(acc_history)
        
        loss = results_6.history['loss']
        all_loss_6.append(loss)
        loss_history = results_6.history['val_loss']
        all_loss_history_6.append(loss_history)
# Out:
# processing fold 0
# Epoch 1/5
# 1877/1877 - 90s - loss: 4.2552 - accuracy: 0.0697 - val_loss: 3.3008 - val_accuracy: 0.0914 - 90s/epoch - 48ms/step
# Epoch 2/5
# 1877/1877 - 63s - loss: 3.0685 - accuracy: 0.0923 - val_loss: 2.9570 - val_accuracy: 0.0908 - 63s/epoch - 34ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 2.8306 - accuracy: 0.1017 - val_loss: 2.7768 - val_accuracy: 0.1006 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 57s - loss: 2.7719 - accuracy: 0.1073 - val_loss: 2.7351 - val_accuracy: 0.1104 - 57s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 59s - loss: 2.7387 - accuracy: 0.1140 - val_loss: 2.8037 - val_accuracy: 0.0765 - 59s/epoch - 31ms/step
# processing fold 1
# Epoch 1/5
# 1877/1877 - 63s - loss: 2.6982 - accuracy: 0.1247 - val_loss: 2.6322 - val_accuracy: 0.1428 - 63s/epoch - 33ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 2.6361 - accuracy: 0.1418 - val_loss: 2.6885 - val_accuracy: 0.1264 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 2.5784 - accuracy: 0.1573 - val_loss: 2.6774 - val_accuracy: 0.1307 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 2.5124 - accuracy: 0.1761 - val_loss: 2.6522 - val_accuracy: 0.1330 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 2.4379 - accuracy: 0.1995 - val_loss: 2.6673 - val_accuracy: 0.1347 - 55s/epoch - 29ms/step
# processing fold 2
# Epoch 1/5
# 1877/1877 - 62s - loss: 2.4459 - accuracy: 0.2040 - val_loss: 2.3138 - val_accuracy: 0.2334 - 62s/epoch - 33ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 2.3682 - accuracy: 0.2239 - val_loss: 2.3501 - val_accuracy: 0.2275 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 59s - loss: 2.2720 - accuracy: 0.2544 - val_loss: 2.3944 - val_accuracy: 0.2159 - 59s/epoch - 31ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 2.1645 - accuracy: 0.2900 - val_loss: 2.4706 - val_accuracy: 0.2125 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 2.0623 - accuracy: 0.3191 - val_loss: 2.5553 - val_accuracy: 0.2044 - 55s/epoch - 29ms/step
# processing fold 3
# Epoch 1/5
# 1877/1877 - 61s - loss: 2.1427 - accuracy: 0.3051 - val_loss: 1.8877 - val_accuracy: 0.3705 - 61s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 55s - loss: 2.0205 - accuracy: 0.3351 - val_loss: 1.9081 - val_accuracy: 0.3541 - 55s/epoch - 29ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 1.9111 - accuracy: 0.3682 - val_loss: 1.9851 - val_accuracy: 0.3419 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 1.8012 - accuracy: 0.4017 - val_loss: 2.0786 - val_accuracy: 0.3247 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 1.7019 - accuracy: 0.4360 - val_loss: 2.2080 - val_accuracy: 0.2982 - 55s/epoch - 29ms/step
# processing fold 4
# Epoch 1/5
# 1877/1877 - 64s - loss: 1.8311 - accuracy: 0.4030 - val_loss: 1.4397 - val_accuracy: 0.5338 - 64s/epoch - 34ms/step
# Epoch 2/5
# 1877/1877 - 57s - loss: 1.6933 - accuracy: 0.4478 - val_loss: 1.4994 - val_accuracy: 0.4786 - 57s/epoch - 31ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 1.6126 - accuracy: 0.4665 - val_loss: 1.6220 - val_accuracy: 0.4489 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 1.5214 - accuracy: 0.5013 - val_loss: 1.7068 - val_accuracy: 0.4232 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 1.4314 - accuracy: 0.5291 - val_loss: 1.8293 - val_accuracy: 0.4040 - 55s/epoch - 29ms/step
# processing fold 0
# Epoch 1/5
# 1877/1877 - 61s - loss: 1.4957 - accuracy: 0.5084 - val_loss: 1.3718 - val_accuracy: 0.5548 - 61s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 1.3826 - accuracy: 0.5448 - val_loss: 1.5077 - val_accuracy: 0.5162 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 58s - loss: 1.3098 - accuracy: 0.5648 - val_loss: 1.6199 - val_accuracy: 0.4855 - 58s/epoch - 31ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 1.2487 - accuracy: 0.5859 - val_loss: 1.6751 - val_accuracy: 0.4717 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 1.2002 - accuracy: 0.6105 - val_loss: 1.7834 - val_accuracy: 0.4574 - 55s/epoch - 29ms/step
# processing fold 1
# Epoch 1/5
# 1877/1877 - 60s - loss: 1.3715 - accuracy: 0.5623 - val_loss: 1.0255 - val_accuracy: 0.6692 - 60s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 55s - loss: 1.2323 - accuracy: 0.6033 - val_loss: 1.1072 - val_accuracy: 0.6431 - 55s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 1.1789 - accuracy: 0.6225 - val_loss: 1.2154 - val_accuracy: 0.6084 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 1.1183 - accuracy: 0.6424 - val_loss: 1.3141 - val_accuracy: 0.5724 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 58s - loss: 1.0663 - accuracy: 0.6597 - val_loss: 1.4006 - val_accuracy: 0.5381 - 58s/epoch - 31ms/step
# processing fold 2
# Epoch 1/5
# 1877/1877 - 60s - loss: 1.2051 - accuracy: 0.6192 - val_loss: 0.8625 - val_accuracy: 0.7299 - 60s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 55s - loss: 1.0964 - accuracy: 0.6469 - val_loss: 0.9188 - val_accuracy: 0.7088 - 55s/epoch - 29ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 1.0446 - accuracy: 0.6694 - val_loss: 0.9704 - val_accuracy: 0.6896 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 1.0079 - accuracy: 0.6813 - val_loss: 1.1638 - val_accuracy: 0.6310 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 0.9669 - accuracy: 0.6886 - val_loss: 1.2135 - val_accuracy: 0.6112 - 55s/epoch - 29ms/step
# processing fold 3
# Epoch 1/5
# 1877/1877 - 63s - loss: 1.1023 - accuracy: 0.6561 - val_loss: 0.7297 - val_accuracy: 0.7794 - 63s/epoch - 34ms/step
# Epoch 2/5
# 1877/1877 - 57s - loss: 0.9946 - accuracy: 0.6859 - val_loss: 0.8137 - val_accuracy: 0.7570 - 57s/epoch - 31ms/step
# Epoch 3/5
# 1877/1877 - 54s - loss: 0.9350 - accuracy: 0.7082 - val_loss: 0.8679 - val_accuracy: 0.7271 - 54s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 0.9122 - accuracy: 0.7163 - val_loss: 0.9480 - val_accuracy: 0.7041 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 0.8827 - accuracy: 0.7254 - val_loss: 1.0447 - val_accuracy: 0.6719 - 55s/epoch - 29ms/step
# processing fold 4
# Epoch 1/5
# 1877/1877 - 60s - loss: 0.9944 - accuracy: 0.6919 - val_loss: 0.6043 - val_accuracy: 0.8373 - 60s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 0.8904 - accuracy: 0.7249 - val_loss: 0.6930 - val_accuracy: 0.8000 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 59s - loss: 0.8735 - accuracy: 0.7330 - val_loss: 0.7746 - val_accuracy: 0.7600 - 59s/epoch - 31ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 0.8356 - accuracy: 0.7481 - val_loss: 0.8468 - val_accuracy: 0.7395 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 54s - loss: 0.7966 - accuracy: 0.7575 - val_loss: 0.9420 - val_accuracy: 0.7116 - 54s/epoch - 29ms/step
# processing fold 0
# Epoch 1/5
# 1877/1877 - 73s - loss: 0.8965 - accuracy: 0.7321 - val_loss: 0.6865 - val_accuracy: 0.7997 - 73s/epoch - 39ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 0.8009 - accuracy: 0.7594 - val_loss: 0.7698 - val_accuracy: 0.7715 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 0.7664 - accuracy: 0.7690 - val_loss: 0.8281 - val_accuracy: 0.7513 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 0.7468 - accuracy: 0.7795 - val_loss: 0.9591 - val_accuracy: 0.7087 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 57s - loss: 0.7361 - accuracy: 0.7831 - val_loss: 1.0422 - val_accuracy: 0.6824 - 57s/epoch - 30ms/step
# processing fold 1
# Epoch 1/5
# 1877/1877 - 66s - loss: 0.8922 - accuracy: 0.7369 - val_loss: 0.5248 - val_accuracy: 0.8623 - 66s/epoch - 35ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 0.7496 - accuracy: 0.7819 - val_loss: 0.6131 - val_accuracy: 0.8258 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 56s - loss: 0.7479 - accuracy: 0.7831 - val_loss: 0.6689 - val_accuracy: 0.8022 - 56s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 0.7395 - accuracy: 0.7902 - val_loss: 0.8191 - val_accuracy: 0.7536 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 0.7017 - accuracy: 0.8015 - val_loss: 0.9292 - val_accuracy: 0.7150 - 55s/epoch - 29ms/step
# processing fold 2
# Epoch 1/5
# 1877/1877 - 61s - loss: 0.8285 - accuracy: 0.7589 - val_loss: 0.4988 - val_accuracy: 0.8727 - 61s/epoch - 33ms/step
# Epoch 2/5
# 1877/1877 - 55s - loss: 0.7337 - accuracy: 0.7880 - val_loss: 0.5615 - val_accuracy: 0.8459 - 55s/epoch - 29ms/step
# Epoch 3/5
# 1877/1877 - 56s - loss: 0.7144 - accuracy: 0.7926 - val_loss: 0.6337 - val_accuracy: 0.8209 - 56s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 0.6752 - accuracy: 0.8097 - val_loss: 0.6997 - val_accuracy: 0.7947 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 55s - loss: 0.6695 - accuracy: 0.8129 - val_loss: 0.8022 - val_accuracy: 0.7617 - 55s/epoch - 29ms/step
# processing fold 3
# Epoch 1/5
# 1877/1877 - 62s - loss: 0.7772 - accuracy: 0.7787 - val_loss: 0.4613 - val_accuracy: 0.8836 - 62s/epoch - 33ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 0.6953 - accuracy: 0.8047 - val_loss: 0.5100 - val_accuracy: 0.8676 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 55s - loss: 0.6629 - accuracy: 0.8125 - val_loss: 0.5939 - val_accuracy: 0.8382 - 55s/epoch - 29ms/step
# Epoch 4/5
# 1877/1877 - 55s - loss: 0.6497 - accuracy: 0.8173 - val_loss: 0.6664 - val_accuracy: 0.8167 - 55s/epoch - 29ms/step
# Epoch 5/5
# 1877/1877 - 58s - loss: 0.6399 - accuracy: 0.8217 - val_loss: 0.7871 - val_accuracy: 0.7696 - 58s/epoch - 31ms/step
# processing fold 4
# Epoch 1/5
# 1877/1877 - 61s - loss: 0.7390 - accuracy: 0.7897 - val_loss: 0.4147 - val_accuracy: 0.8987 - 61s/epoch - 33ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 0.6566 - accuracy: 0.8194 - val_loss: 0.4920 - val_accuracy: 0.8751 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 56s - loss: 0.6388 - accuracy: 0.8257 - val_loss: 0.5323 - val_accuracy: 0.8638 - 56s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 0.6197 - accuracy: 0.8313 - val_loss: 0.6185 - val_accuracy: 0.8303 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 0.5836 - accuracy: 0.8427 - val_loss: 0.6688 - val_accuracy: 0.8094 - 56s/epoch - 30ms/step
# processing fold 0
# Epoch 1/5
# 1877/1877 - 60s - loss: 0.6947 - accuracy: 0.8062 - val_loss: 0.5085 - val_accuracy: 0.8713 - 60s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 0.6336 - accuracy: 0.8293 - val_loss: 0.6367 - val_accuracy: 0.8225 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 56s - loss: 0.6215 - accuracy: 0.8342 - val_loss: 0.6805 - val_accuracy: 0.8135 - 56s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 0.5897 - accuracy: 0.8410 - val_loss: 0.7216 - val_accuracy: 0.8001 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 0.5784 - accuracy: 0.8492 - val_loss: 0.7640 - val_accuracy: 0.7783 - 56s/epoch - 30ms/step
# processing fold 1
# Epoch 1/5
# 1877/1877 - 60s - loss: 0.7026 - accuracy: 0.8172 - val_loss: 0.3886 - val_accuracy: 0.9105 - 60s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 0.6126 - accuracy: 0.8359 - val_loss: 0.4967 - val_accuracy: 0.8757 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 56s - loss: 0.5846 - accuracy: 0.8460 - val_loss: 0.5686 - val_accuracy: 0.8469 - 56s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 0.5793 - accuracy: 0.8513 - val_loss: 0.6215 - val_accuracy: 0.8269 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 0.5700 - accuracy: 0.8546 - val_loss: 0.7058 - val_accuracy: 0.8062 - 56s/epoch - 30ms/step
# processing fold 2
# Epoch 1/5
# 1877/1877 - 61s - loss: 0.6953 - accuracy: 0.8142 - val_loss: 0.3630 - val_accuracy: 0.9243 - 61s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 0.5786 - accuracy: 0.8516 - val_loss: 0.4640 - val_accuracy: 0.8911 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 56s - loss: 0.5849 - accuracy: 0.8469 - val_loss: 0.5504 - val_accuracy: 0.8531 - 56s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 0.5747 - accuracy: 0.8485 - val_loss: 0.5682 - val_accuracy: 0.8506 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 0.5161 - accuracy: 0.8686 - val_loss: 0.6707 - val_accuracy: 0.8171 - 56s/epoch - 30ms/step
# processing fold 3
# Epoch 1/5
# 1877/1877 - 60s - loss: 0.6590 - accuracy: 0.8278 - val_loss: 0.3917 - val_accuracy: 0.9128 - 60s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 0.5716 - accuracy: 0.8516 - val_loss: 0.4268 - val_accuracy: 0.9013 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 56s - loss: 0.5551 - accuracy: 0.8614 - val_loss: 0.5681 - val_accuracy: 0.8521 - 56s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 0.5545 - accuracy: 0.8601 - val_loss: 0.5679 - val_accuracy: 0.8491 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 0.5331 - accuracy: 0.8625 - val_loss: 0.6317 - val_accuracy: 0.8316 - 56s/epoch - 30ms/step
# processing fold 4
# Epoch 1/5
# 1877/1877 - 60s - loss: 0.6506 - accuracy: 0.8321 - val_loss: 0.3242 - val_accuracy: 0.9390 - 60s/epoch - 32ms/step
# Epoch 2/5
# 1877/1877 - 55s - loss: 0.5399 - accuracy: 0.8632 - val_loss: 0.3667 - val_accuracy: 0.9198 - 55s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 56s - loss: 0.5374 - accuracy: 0.8668 - val_loss: 0.4772 - val_accuracy: 0.8928 - 56s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 0.5342 - accuracy: 0.8653 - val_loss: 0.5392 - val_accuracy: 0.8621 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 0.5305 - accuracy: 0.8694 - val_loss: 0.5672 - val_accuracy: 0.8429 - 56s/epoch - 30ms/step

# %%
print("Average Loss:", np.mean(all_val_loss_6))
print("Average Accuracy:", np.mean(all_val_acc_6))
# Out:
# Average Loss: 1.3008329063653945
# Average Accuracy: 0.5961096316576004

# %%
plot_loss(all_loss_6, all_loss_history_6)

# %%
plot_acc(all_acc_6, all_acc_history_6)

# %% [markdown]
# # Final LSTM Model
#
# Now that we have explored 3 different regularization methods - Dropout, L1/L2 Regularizers and Batch Normalisation and also determined the most optimal hyperparameter settings, we will develop our final model.
#
# The final model will first be trained with a partial training set before being trained on the complete set.

# %% [markdown]
# #### Building the final LSTM Model

# %%
from tensorflow.keras.layers import Dropout, BatchNormalization

# Initialising the model 
final_lstm = Sequential()

# Defining model: add layers 
final_lstm.add(Embedding(
    max_words,
    EMBEDDING_VECTOR_LENGTH,
    input_length=max_len,
    weights=[embedding_matrix],
    trainable=True,
)) #glove embedding

final_lstm.add(BatchNormalization()) # BatchNormalization layer 
final_lstm.add(LSTM(128, input_shape=(max_len, EMBEDDING_VECTOR_LENGTH), return_sequences=True)) #LSTM layer
final_lstm.add(BatchNormalization())
final_lstm.add(Dropout(0.07))
final_lstm.add(LSTM(64, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.001))) # Additional dense layer
final_lstm.add(BatchNormalization())
final_lstm.add(Dropout(0.07))
final_lstm.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.001))) # Additional dense layer
final_lstm.add(BatchNormalization())
final_lstm.add(Dense(16, activation='softmax')) #dense layer - the last one

# Compile model
final_lstm.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

print(final_lstm.summary())
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 40, 50)            125000
#
#  batch_normalization_16 (Bat  (None, 40, 50)           200
#  chNormalization)
#
#  lstm_8 (LSTM)               (None, 40, 128)           91648
#
#  batch_normalization_17 (Bat  (None, 40, 128)          512
#  chNormalization)
#
#  dropout (Dropout)           (None, 40, 128)           0
#
#  lstm_9 (LSTM)               (None, 64)                49408
#
#  batch_normalization_18 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 64)                4160
#
#  batch_normalization_19 (Bat  (None, 64)               256
#  chNormalization)
#
#  dense_9 (Dense)             (None, 16)                1040
#
# =================================================================
# Total params: 272,480
# Trainable params: 271,868
# Non-trainable params: 612
# _________________________________________________________________
# None

# %%
import numpy as np 
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_absolute_error

K=4
num_val_samples = len(X_train_resampled)//K
num_epochs = 5

#new!
all_val_acc_p = []
all_val_loss_p = []

all_acc_p = []
all_loss_p = []
all_acc_history_p = []
all_loss_history_p = []

N_iterations=4
N_folds=5
        
for i in range(N_iterations):
    skf = StratifiedKFold(n_splits=N_folds, shuffle=True)
    
    for j, (train_index, val_index) in enumerate(skf.split(X_train_resampled, y_train_resampled)):
        print('processing fold', j)
        
        partial_train_data = X_train_resampled[train_index]
        val_data = X_train_resampled[val_index]
        
        partial_train_targets = y_train_resampled[train_index]
        val_targets = y_train_resampled[val_index]
        
        # One-hot encode the target labels
        partial_train_targets = to_categorical(partial_train_targets, num_classes=16)
        val_targets = to_categorical(val_targets, num_classes=16)
        
        # Train the model 
        final_lstm.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
        results_p = final_lstm.fit(partial_train_data, partial_train_targets, epochs=num_epochs, batch_size=10, verbose=2, validation_data = (val_data, val_targets))
        
        # Evaluate the model on the validation data: loss and accuracy 
        val_loss, val_acc = final_lstm.evaluate(val_data, val_targets, verbose=0)
        all_val_acc_p.append(val_acc)
        all_val_loss_p.append(val_loss)
        
        acc = results_p.history['accuracy']
        all_acc_p.append(acc)
        acc_history = results_p.history['val_accuracy']
        all_acc_history_p.append(acc_history)
        
        loss = results_p.history['loss']
        all_loss_p.append(loss)
        loss_history = results_p.history['val_loss']
        all_loss_history_p.append(loss_history)
# Out:
# processing fold 0
# Epoch 1/5
# 1877/1877 - 78s - loss: 3.2128 - accuracy: 0.0883 - val_loss: 3.1283 - val_accuracy: 0.0639 - 78s/epoch - 42ms/step
# Epoch 2/5
# 1877/1877 - 68s - loss: 2.9036 - accuracy: 0.0937 - val_loss: 2.8092 - val_accuracy: 0.0980 - 68s/epoch - 36ms/step
# Epoch 3/5
# 1877/1877 - 57s - loss: 2.7762 - accuracy: 0.1059 - val_loss: 2.7743 - val_accuracy: 0.1194 - 57s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 2.7509 - accuracy: 0.1133 - val_loss: 2.7753 - val_accuracy: 0.0910 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 2.7205 - accuracy: 0.1209 - val_loss: 2.7258 - val_accuracy: 0.1132 - 56s/epoch - 30ms/step
# processing fold 1
# Epoch 1/5
# 1877/1877 - 64s - loss: 2.6941 - accuracy: 0.1298 - val_loss: 2.6997 - val_accuracy: 0.1207 - 64s/epoch - 34ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 2.6417 - accuracy: 0.1418 - val_loss: 2.6632 - val_accuracy: 0.1194 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 56s - loss: 2.5999 - accuracy: 0.1566 - val_loss: 2.6643 - val_accuracy: 0.1477 - 56s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 2.5516 - accuracy: 0.1713 - val_loss: 2.6760 - val_accuracy: 0.1441 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 2.4843 - accuracy: 0.1898 - val_loss: 2.7191 - val_accuracy: 0.1369 - 56s/epoch - 30ms/step
# processing fold 2
# Epoch 1/5
# 1877/1877 - 62s - loss: 2.4990 - accuracy: 0.1900 - val_loss: 2.3639 - val_accuracy: 0.2279 - 62s/epoch - 33ms/step
# Epoch 2/5
# 1877/1877 - 60s - loss: 2.4271 - accuracy: 0.2160 - val_loss: 2.4241 - val_accuracy: 0.2051 - 60s/epoch - 32ms/step
# Epoch 3/5
# 1877/1877 - 59s - loss: 2.3472 - accuracy: 0.2390 - val_loss: 2.4295 - val_accuracy: 0.2168 - 59s/epoch - 32ms/step
# Epoch 4/5
# 1877/1877 - 57s - loss: 2.2630 - accuracy: 0.2660 - val_loss: 2.4987 - val_accuracy: 0.1987 - 57s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 2.1764 - accuracy: 0.2938 - val_loss: 2.5520 - val_accuracy: 0.2089 - 56s/epoch - 30ms/step
# processing fold 3
# Epoch 1/5
# 1877/1877 - 63s - loss: 2.2481 - accuracy: 0.2804 - val_loss: 1.9464 - val_accuracy: 0.3675 - 63s/epoch - 33ms/step
# Epoch 2/5
# 1877/1877 - 57s - loss: 2.1547 - accuracy: 0.3090 - val_loss: 2.0205 - val_accuracy: 0.3343 - 57s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 56s - loss: 2.0564 - accuracy: 0.3370 - val_loss: 2.0498 - val_accuracy: 0.3298 - 56s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 1.9788 - accuracy: 0.3606 - val_loss: 2.1345 - val_accuracy: 0.3161 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 1.8834 - accuracy: 0.3924 - val_loss: 2.2498 - val_accuracy: 0.2871 - 56s/epoch - 30ms/step
# processing fold 4
# Epoch 1/5
# 1877/1877 - 61s - loss: 1.9737 - accuracy: 0.3702 - val_loss: 1.6326 - val_accuracy: 0.4718 - 61s/epoch - 33ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 1.8686 - accuracy: 0.3953 - val_loss: 1.7445 - val_accuracy: 0.4327 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 56s - loss: 1.7779 - accuracy: 0.4292 - val_loss: 1.7373 - val_accuracy: 0.4364 - 56s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 1.7059 - accuracy: 0.4543 - val_loss: 1.8868 - val_accuracy: 0.4042 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 1.6324 - accuracy: 0.4805 - val_loss: 1.9525 - val_accuracy: 0.3918 - 56s/epoch - 30ms/step
# processing fold 0
# Epoch 1/5
# 1877/1877 - 86s - loss: 1.7099 - accuracy: 0.4540 - val_loss: 1.5092 - val_accuracy: 0.5192 - 86s/epoch - 46ms/step
# Epoch 2/5
# 1877/1877 - 60s - loss: 1.5934 - accuracy: 0.4962 - val_loss: 1.6229 - val_accuracy: 0.4680 - 60s/epoch - 32ms/step
# Epoch 3/5
# 1877/1877 - 57s - loss: 1.5365 - accuracy: 0.5106 - val_loss: 1.7164 - val_accuracy: 0.4644 - 57s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 1.4657 - accuracy: 0.5411 - val_loss: 1.8029 - val_accuracy: 0.4410 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 1.4022 - accuracy: 0.5582 - val_loss: 1.8648 - val_accuracy: 0.4286 - 56s/epoch - 30ms/step
# processing fold 1
# Epoch 1/5
# 1877/1877 - 63s - loss: 1.5635 - accuracy: 0.5227 - val_loss: 1.2242 - val_accuracy: 0.6188 - 63s/epoch - 34ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 1.4445 - accuracy: 0.5561 - val_loss: 1.2642 - val_accuracy: 0.5990 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 58s - loss: 1.3830 - accuracy: 0.5715 - val_loss: 1.3529 - val_accuracy: 0.5602 - 58s/epoch - 31ms/step
# Epoch 4/5
# 1877/1877 - 57s - loss: 1.3203 - accuracy: 0.5910 - val_loss: 1.4807 - val_accuracy: 0.5297 - 57s/epoch - 31ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 1.2710 - accuracy: 0.6126 - val_loss: 1.5674 - val_accuracy: 0.5208 - 56s/epoch - 30ms/step
# processing fold 2
# Epoch 1/5
# 1877/1877 - 64s - loss: 1.4007 - accuracy: 0.5739 - val_loss: 0.9982 - val_accuracy: 0.7054 - 64s/epoch - 34ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 1.2978 - accuracy: 0.6017 - val_loss: 1.1150 - val_accuracy: 0.6606 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 57s - loss: 1.2434 - accuracy: 0.6273 - val_loss: 1.1449 - val_accuracy: 0.6495 - 57s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 1.1949 - accuracy: 0.6407 - val_loss: 1.2429 - val_accuracy: 0.6178 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 1.1555 - accuracy: 0.6506 - val_loss: 1.3132 - val_accuracy: 0.5954 - 56s/epoch - 30ms/step
# processing fold 3
# Epoch 1/5
# 1877/1877 - 63s - loss: 1.2716 - accuracy: 0.6215 - val_loss: 0.9009 - val_accuracy: 0.7340 - 63s/epoch - 34ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 1.1606 - accuracy: 0.6572 - val_loss: 0.9424 - val_accuracy: 0.7210 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 57s - loss: 1.1163 - accuracy: 0.6712 - val_loss: 1.0185 - val_accuracy: 0.6986 - 57s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 57s - loss: 1.0751 - accuracy: 0.6834 - val_loss: 1.1077 - val_accuracy: 0.6719 - 57s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 1.0374 - accuracy: 0.6967 - val_loss: 1.2807 - val_accuracy: 0.6205 - 56s/epoch - 30ms/step
# processing fold 4
# Epoch 1/5
# 1877/1877 - 63s - loss: 1.1828 - accuracy: 0.6487 - val_loss: 0.7431 - val_accuracy: 0.8105 - 63s/epoch - 34ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 1.0695 - accuracy: 0.6903 - val_loss: 0.8292 - val_accuracy: 0.7681 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 56s - loss: 1.0259 - accuracy: 0.7038 - val_loss: 0.9166 - val_accuracy: 0.7320 - 56s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 1.0040 - accuracy: 0.7151 - val_loss: 1.0278 - val_accuracy: 0.7090 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 0.9704 - accuracy: 0.7219 - val_loss: 1.0789 - val_accuracy: 0.6828 - 56s/epoch - 30ms/step
# processing fold 0
# Epoch 1/5
# 1877/1877 - 62s - loss: 1.0465 - accuracy: 0.6978 - val_loss: 0.7990 - val_accuracy: 0.7837 - 62s/epoch - 33ms/step
# Epoch 2/5
# 1877/1877 - 56s - loss: 0.9791 - accuracy: 0.7214 - val_loss: 0.8879 - val_accuracy: 0.7530 - 56s/epoch - 30ms/step
# Epoch 3/5
# 1877/1877 - 58s - loss: 0.9270 - accuracy: 0.7358 - val_loss: 1.0167 - val_accuracy: 0.7063 - 58s/epoch - 31ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 0.9084 - accuracy: 0.7457 - val_loss: 1.1053 - val_accuracy: 0.6784 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 57s - loss: 0.8815 - accuracy: 0.7558 - val_loss: 1.2111 - val_accuracy: 0.6532 - 57s/epoch - 30ms/step
# processing fold 1
# Epoch 1/5
# 1877/1877 - 63s - loss: 1.0280 - accuracy: 0.7140 - val_loss: 0.6436 - val_accuracy: 0.8478 - 63s/epoch - 33ms/step
# Epoch 2/5
# 1877/1877 - 57s - loss: 0.9359 - accuracy: 0.7381 - val_loss: 0.7074 - val_accuracy: 0.8177 - 57s/epoch - 31ms/step
# Epoch 3/5
# 1877/1877 - 56s - loss: 0.8907 - accuracy: 0.7562 - val_loss: 0.8400 - val_accuracy: 0.7672 - 56s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 56s - loss: 0.8670 - accuracy: 0.7584 - val_loss: 0.9571 - val_accuracy: 0.7297 - 56s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 0.8447 - accuracy: 0.7720 - val_loss: 1.0197 - val_accuracy: 0.7165 - 56s/epoch - 30ms/step
# processing fold 2
# Epoch 1/5
# 1877/1877 - 62s - loss: 0.9844 - accuracy: 0.7321 - val_loss: 0.6110 - val_accuracy: 0.8563 - 62s/epoch - 33ms/step
# Epoch 2/5
# 1877/1877 - 59s - loss: 0.8927 - accuracy: 0.7585 - val_loss: 0.6665 - val_accuracy: 0.8224 - 59s/epoch - 32ms/step
# Epoch 3/5
# 1877/1877 - 57s - loss: 0.8540 - accuracy: 0.7696 - val_loss: 0.7598 - val_accuracy: 0.7883 - 57s/epoch - 30ms/step
# Epoch 4/5
# 1877/1877 - 57s - loss: 0.8279 - accuracy: 0.7783 - val_loss: 0.8298 - val_accuracy: 0.7730 - 57s/epoch - 30ms/step
# Epoch 5/5
# 1877/1877 - 56s - loss: 0.7974 - accuracy: 0.7911 - val_loss: 0.9507 - val_accuracy: 0.7348 - 56s/epoch - 30ms/step
# processing fold 3
# Epoch 1/5
# 1877/1877 - 63s - loss: 0.9281 - accuracy: 0.7490 - val_loss: 0.5341 - val_accuracy: 0.8828 - 63s/epoch - 34ms/step
# Epoch 2/5
# 1877/1877 - 61s - loss: 0.8325 - accuracy: 0.7814 - val_loss: 0.5928 - val_accuracy: 0.8585 - 61s/epoch - 33ms/step
# Epoch 3/5
# 1877/1877 - 58s - loss: 0.7940 - accuracy: 0.7892 - val_loss: 0.7361 - val_accuracy: 0.8039 - 58s/epoch - 31ms/step
# Epoch 4/5
# 1877/1877 - 58s - loss: 0.7961 - accuracy: 0.7953 - val_loss: 0.7406 - val_accuracy: 0.8045 - 58s/epoch - 31ms/step
# Epoch 5/5
# 1877/1877 - 58s - loss: 0.7668 - accuracy: 0.7985 - val_loss: 0.8682 - val_accuracy: 0.7580 - 58s/epoch - 31ms/step
# processing fold 4
# Epoch 1/5
# 1877/1877 - 63s - loss: 0.8901 - accuracy: 0.7631 - val_loss: 0.5379 - val_accuracy: 0.8819 - 63s/epoch - 34ms/step
# Epoch 2/5
# 1877/1877 - 58s - loss: 0.7993 - accuracy: 0.7868 - val_loss: 0.5736 - val_accuracy: 0.8700 - 58s/epoch - 31ms/step
# Epoch 3/5
# 1877/1877 - 58s - loss: 0.7740 - accuracy: 0.7974 - val_loss: 0.6404 - val_accuracy: 0.8376 - 58s/epoch - 31ms/step
# Epoch 4/5
# 1877/1877 - 59s - loss: 0.7605 - accuracy: 0.8037 - val_loss: 0.7224 - val_accuracy: 0.8133 - 59s/epoch - 32ms/step
# Epoch 5/5
# 1877/1877 - 58s - loss: 0.7371 - accuracy: 0.8100 - val_loss: 0.7870 - val_accuracy: 0.7887 - 58s/epoch - 31ms/step
# processing fold 0
# Epoch 1/5
# 1877/1877 - 63s - loss: 0.8214 - accuracy: 0.7865 - val_loss: 0.5714 - val_accuracy: 0.8649 - 63s/epoch - 34ms/step
# Epoch 2/5
# 1877/1877 - 58s - loss: 0.7400 - accuracy: 0.8073 - val_loss: 0.6470 - val_accuracy: 0.8404 - 58s/epoch - 31ms/step
# Epoch 3/5
# 1877/1877 - 63s - loss: 0.7282 - accuracy: 0.8138 - val_loss: 0.7107 - val_accuracy: 0.8176 - 63s/epoch - 34ms/step
# Epoch 4/5
# 1877/1877 - 58s - loss: 0.7162 - accuracy: 0.8215 - val_loss: 0.7942 - val_accuracy: 0.7918 - 58s/epoch - 31ms/step
# Epoch 5/5
# 1877/1877 - 58s - loss: 0.7071 - accuracy: 0.8251 - val_loss: 0.8663 - val_accuracy: 0.7662 - 58s/epoch - 31ms/step
# processing fold 1
# Epoch 1/5
# 1877/1877 - 64s - loss: 0.8296 - accuracy: 0.7871 - val_loss: 0.4904 - val_accuracy: 0.9015 - 64s/epoch - 34ms/step
# Epoch 2/5
# 1877/1877 - 58s - loss: 0.7324 - accuracy: 0.8111 - val_loss: 0.5144 - val_accuracy: 0.8842 - 58s/epoch - 31ms/step
# Epoch 3/5
# 1877/1877 - 58s - loss: 0.7180 - accuracy: 0.8175 - val_loss: 0.6398 - val_accuracy: 0.8437 - 58s/epoch - 31ms/step
# Epoch 4/5
# 1877/1877 - 59s - loss: 0.7084 - accuracy: 0.8231 - val_loss: 0.7362 - val_accuracy: 0.8092 - 59s/epoch - 31ms/step
# Epoch 5/5
# 1877/1877 - 85s - loss: 0.7013 - accuracy: 0.8259 - val_loss: 0.7983 - val_accuracy: 0.7962 - 85s/epoch - 45ms/step
# processing fold 2
# Epoch 1/5
# 1877/1877 - 86s - loss: 0.8101 - accuracy: 0.7924 - val_loss: 0.4713 - val_accuracy: 0.9073 - 86s/epoch - 46ms/step
# Epoch 2/5
# 1877/1877 - 69s - loss: 0.7355 - accuracy: 0.8136 - val_loss: 0.5129 - val_accuracy: 0.8898 - 69s/epoch - 37ms/step
# Epoch 3/5
# 1877/1877 - 79s - loss: 0.6950 - accuracy: 0.8289 - val_loss: 0.5799 - val_accuracy: 0.8651 - 79s/epoch - 42ms/step
# Epoch 4/5
# 1877/1877 - 79s - loss: 0.6955 - accuracy: 0.8275 - val_loss: 0.7538 - val_accuracy: 0.8052 - 79s/epoch - 42ms/step
# Epoch 5/5
# 1877/1877 - 92s - loss: 0.6663 - accuracy: 0.8344 - val_loss: 0.7696 - val_accuracy: 0.8058 - 92s/epoch - 49ms/step
# processing fold 3
# Epoch 1/5
# 1877/1877 - 153s - loss: 0.7829 - accuracy: 0.8013 - val_loss: 0.4583 - val_accuracy: 0.9098 - 153s/epoch - 81ms/step
# Epoch 2/5
# 1877/1877 - 123s - loss: 0.6914 - accuracy: 0.8242 - val_loss: 0.4936 - val_accuracy: 0.8936 - 123s/epoch - 65ms/step
# Epoch 3/5
# 1877/1877 - 110s - loss: 0.6665 - accuracy: 0.8341 - val_loss: 0.5583 - val_accuracy: 0.8744 - 110s/epoch - 59ms/step
# Epoch 4/5
# 1877/1877 - 73s - loss: 0.6662 - accuracy: 0.8337 - val_loss: 0.6571 - val_accuracy: 0.8440 - 73s/epoch - 39ms/step
# Epoch 5/5
# 1877/1877 - 62s - loss: 0.6621 - accuracy: 0.8357 - val_loss: 0.7094 - val_accuracy: 0.8231 - 62s/epoch - 33ms/step
# processing fold 4
# Epoch 1/5
# 1877/1877 - 74s - loss: 0.7657 - accuracy: 0.8069 - val_loss: 0.3984 - val_accuracy: 0.9252 - 74s/epoch - 39ms/step
# Epoch 2/5
# 1877/1877 - 91s - loss: 0.6625 - accuracy: 0.8356 - val_loss: 0.4659 - val_accuracy: 0.9041 - 91s/epoch - 48ms/step
# Epoch 3/5
# 1877/1877 - 93s - loss: 0.6642 - accuracy: 0.8368 - val_loss: 0.5287 - val_accuracy: 0.8787 - 93s/epoch - 50ms/step
# Epoch 4/5
# 1877/1877 - 73s - loss: 0.6468 - accuracy: 0.8441 - val_loss: 0.6212 - val_accuracy: 0.8486 - 73s/epoch - 39ms/step
# Epoch 5/5
# 1877/1877 - 60s - loss: 0.6474 - accuracy: 0.8426 - val_loss: 0.7074 - val_accuracy: 0.8239 - 60s/epoch - 32ms/step

# %%
plot_loss(all_loss_p, all_loss_history_p)

# %%
plot_acc(all_acc_p, all_acc_history_p)

# %%
print("Average Loss:", np.mean(all_val_loss_p))
print("Average Accuracy:", np.mean(all_val_acc_p))
# Out:
# Average Loss: 1.39959936439991
# Average Accuracy: 0.5826267220079899

# %% [markdown]
# #### Training the final LSTM model with the COMPLETE training set

# %%
from tensorflow.keras.layers import Dropout, BatchNormalization

# Initialising the model 
final_lstm1 = Sequential()

# Defining model: add layers 
final_lstm1.add(Embedding(
    max_words,
    EMBEDDING_VECTOR_LENGTH,
    input_length=max_len,
    weights=[embedding_matrix],
    trainable=True,
)) #glove embedding

final_lstm1.add(BatchNormalization()) # BatchNormalization layer 
final_lstm1.add(LSTM(128, input_shape=(max_len, EMBEDDING_VECTOR_LENGTH), return_sequences=True)) #LSTM layer
final_lstm1.add(BatchNormalization())
final_lstm1.add(Dropout(0.07))
final_lstm1.add(LSTM(64, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.001))) # Additional dense layer
final_lstm1.add(BatchNormalization())
final_lstm1.add(Dropout(0.07))
final_lstm1.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.001))) # Additional dense layer
final_lstm1.add(BatchNormalization())
final_lstm1.add(Dense(16, activation='softmax')) #dense layer - the last one

# Compile model
final_lstm1.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

print(final_lstm1.summary())
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 40, 50)            125000
#
#  batch_normalization_20 (Bat  (None, 40, 50)           200
#  chNormalization)
#
#  lstm_10 (LSTM)              (None, 40, 128)           91648
#
#  batch_normalization_21 (Bat  (None, 40, 128)          512
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 40, 128)           0
#
#  lstm_11 (LSTM)              (None, 64)                49408
#
#  batch_normalization_22 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_10 (Dense)            (None, 64)                4160
#
#  batch_normalization_23 (Bat  (None, 64)               256
#  chNormalization)
#
#  dense_11 (Dense)            (None, 16)                1040
#
# =================================================================
# Total params: 272,480
# Trainable params: 271,868
# Non-trainable params: 612
# _________________________________________________________________
# None

# %%
import numpy as np 
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_absolute_error

K=4
num_val_samples = len(X_train_resampled)//K
num_epochs = 5
        
for i in range(N_iterations):
    skf = StratifiedKFold(n_splits=N_folds, shuffle=True)
    
    for j, (train_index, val_index) in enumerate(skf.split(X_train_resampled, y_train_resampled)):
        print('processing fold', j)
        
        partial_train_data = X_train_resampled[train_index]
        val_data = X_train_resampled[val_index]
        
        partial_train_targets = y_train_resampled[train_index]
        val_targets = y_train_resampled[val_index]
        
        # One-hot encode the target labels
        partial_train_targets = to_categorical(partial_train_targets, num_classes=16)
        val_targets = to_categorical(val_targets, num_classes=16)
        
        # Train the model 
        final_lstm1.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
        final_lstm1.fit(np.concatenate([partial_train_data, val_data]), np.concatenate([partial_train_targets, val_targets]), epochs=num_epochs, batch_size=128, verbose=2, validation_data = (val_data, val_targets))
# Out:
# processing fold 0
# Epoch 1/5
# 184/184 - 42s - loss: 5.1052 - accuracy: 0.0813 - val_loss: 4.3601 - val_accuracy: 0.0821 - 42s/epoch - 226ms/step
# Epoch 2/5
# 184/184 - 34s - loss: 3.8457 - accuracy: 0.1196 - val_loss: 3.4184 - val_accuracy: 0.1496 - 34s/epoch - 184ms/step
# Epoch 3/5
# 184/184 - 31s - loss: 3.2625 - accuracy: 0.1399 - val_loss: 3.0741 - val_accuracy: 0.1703 - 31s/epoch - 171ms/step
# Epoch 4/5
# 184/184 - 31s - loss: 3.0232 - accuracy: 0.1544 - val_loss: 2.8945 - val_accuracy: 0.1767 - 31s/epoch - 168ms/step
# Epoch 5/5
# 184/184 - 27s - loss: 2.8731 - accuracy: 0.1669 - val_loss: 2.7558 - val_accuracy: 0.1946 - 27s/epoch - 146ms/step
# processing fold 1
# Epoch 1/5
# 184/184 - 41s - loss: 2.7840 - accuracy: 0.1760 - val_loss: 2.7261 - val_accuracy: 0.1865 - 41s/epoch - 221ms/step
# Epoch 2/5
# 184/184 - 34s - loss: 2.6888 - accuracy: 0.1909 - val_loss: 2.6291 - val_accuracy: 0.2064 - 34s/epoch - 183ms/step
# Epoch 3/5
# 184/184 - 29s - loss: 2.6215 - accuracy: 0.2063 - val_loss: 2.5152 - val_accuracy: 0.2475 - 29s/epoch - 160ms/step
# Epoch 4/5
# 184/184 - 31s - loss: 2.5508 - accuracy: 0.2244 - val_loss: 2.4178 - val_accuracy: 0.2842 - 31s/epoch - 167ms/step
# Epoch 5/5
# 184/184 - 23s - loss: 2.4743 - accuracy: 0.2507 - val_loss: 2.3579 - val_accuracy: 0.2993 - 23s/epoch - 125ms/step
# processing fold 2
# Epoch 1/5
# 184/184 - 28s - loss: 2.3826 - accuracy: 0.2785 - val_loss: 2.1905 - val_accuracy: 0.3443 - 28s/epoch - 151ms/step
# Epoch 2/5
# 184/184 - 22s - loss: 2.2829 - accuracy: 0.3157 - val_loss: 2.0978 - val_accuracy: 0.3829 - 22s/epoch - 120ms/step
# Epoch 3/5
# 184/184 - 23s - loss: 2.1935 - accuracy: 0.3449 - val_loss: 1.9917 - val_accuracy: 0.4240 - 23s/epoch - 122ms/step
# Epoch 4/5
# 184/184 - 22s - loss: 2.1005 - accuracy: 0.3817 - val_loss: 1.8717 - val_accuracy: 0.4594 - 22s/epoch - 120ms/step
# Epoch 5/5
# 184/184 - 22s - loss: 2.0077 - accuracy: 0.4106 - val_loss: 1.8335 - val_accuracy: 0.4715 - 22s/epoch - 120ms/step
# processing fold 3
# Epoch 1/5
# 184/184 - 28s - loss: 1.9002 - accuracy: 0.4476 - val_loss: 1.6296 - val_accuracy: 0.5476 - 28s/epoch - 151ms/step
# Epoch 2/5
# 184/184 - 23s - loss: 1.7673 - accuracy: 0.4959 - val_loss: 1.5256 - val_accuracy: 0.5858 - 23s/epoch - 124ms/step
# Epoch 3/5
# 184/184 - 22s - loss: 1.6742 - accuracy: 0.5231 - val_loss: 1.4021 - val_accuracy: 0.6327 - 22s/epoch - 122ms/step
# Epoch 4/5
# 184/184 - 23s - loss: 1.5814 - accuracy: 0.5553 - val_loss: 1.3443 - val_accuracy: 0.6485 - 23s/epoch - 123ms/step
# Epoch 5/5
# 184/184 - 23s - loss: 1.4923 - accuracy: 0.5867 - val_loss: 1.2276 - val_accuracy: 0.6886 - 23s/epoch - 123ms/step
# processing fold 4
# Epoch 1/5
# 184/184 - 28s - loss: 1.4147 - accuracy: 0.6125 - val_loss: 1.0870 - val_accuracy: 0.7446 - 28s/epoch - 152ms/step
# Epoch 2/5
# 184/184 - 23s - loss: 1.2881 - accuracy: 0.6603 - val_loss: 1.0830 - val_accuracy: 0.7299 - 23s/epoch - 126ms/step
# Epoch 3/5
# 184/184 - 23s - loss: 1.2283 - accuracy: 0.6808 - val_loss: 0.9540 - val_accuracy: 0.7858 - 23s/epoch - 124ms/step
# Epoch 4/5
# 184/184 - 22s - loss: 1.1529 - accuracy: 0.7053 - val_loss: 0.9033 - val_accuracy: 0.8003 - 22s/epoch - 121ms/step
# Epoch 5/5
# 184/184 - 22s - loss: 1.0935 - accuracy: 0.7272 - val_loss: 0.8905 - val_accuracy: 0.7990 - 22s/epoch - 121ms/step
# processing fold 0
# Epoch 1/5
# 184/184 - 29s - loss: 1.0522 - accuracy: 0.7379 - val_loss: 0.7966 - val_accuracy: 0.8399 - 29s/epoch - 158ms/step
# Epoch 2/5
# 184/184 - 25s - loss: 0.9572 - accuracy: 0.7752 - val_loss: 0.7441 - val_accuracy: 0.8574 - 25s/epoch - 134ms/step
# Epoch 3/5
# 184/184 - 26s - loss: 0.9172 - accuracy: 0.7848 - val_loss: 0.7195 - val_accuracy: 0.8617 - 26s/epoch - 142ms/step
# Epoch 4/5
# 184/184 - 23s - loss: 0.8881 - accuracy: 0.7969 - val_loss: 0.7420 - val_accuracy: 0.8480 - 23s/epoch - 126ms/step
# Epoch 5/5
# 184/184 - 23s - loss: 0.8172 - accuracy: 0.8197 - val_loss: 0.6284 - val_accuracy: 0.8928 - 23s/epoch - 126ms/step
# processing fold 1
# Epoch 1/5
# 184/184 - 69s - loss: 0.8208 - accuracy: 0.8197 - val_loss: 0.5870 - val_accuracy: 0.9079 - 69s/epoch - 374ms/step
# Epoch 2/5
# 184/184 - 25s - loss: 0.7554 - accuracy: 0.8401 - val_loss: 0.5688 - val_accuracy: 0.9126 - 25s/epoch - 138ms/step
# Epoch 3/5
# 184/184 - 26s - loss: 0.7483 - accuracy: 0.8446 - val_loss: 0.5436 - val_accuracy: 0.9243 - 26s/epoch - 143ms/step
# Epoch 4/5
# 184/184 - 26s - loss: 0.7007 - accuracy: 0.8603 - val_loss: 0.5403 - val_accuracy: 0.9273 - 26s/epoch - 140ms/step
# Epoch 5/5
# 184/184 - 26s - loss: 0.6916 - accuracy: 0.8634 - val_loss: 0.4971 - val_accuracy: 0.9405 - 26s/epoch - 142ms/step
# processing fold 2
# Epoch 1/5
# 184/184 - 38s - loss: 0.6955 - accuracy: 0.8651 - val_loss: 0.4965 - val_accuracy: 0.9416 - 38s/epoch - 204ms/step
# Epoch 2/5
# 184/184 - 23s - loss: 0.6604 - accuracy: 0.8755 - val_loss: 0.4651 - val_accuracy: 0.9484 - 23s/epoch - 127ms/step
# Epoch 3/5
# 184/184 - 23s - loss: 0.6218 - accuracy: 0.8860 - val_loss: 0.4449 - val_accuracy: 0.9548 - 23s/epoch - 124ms/step
# Epoch 4/5
# 184/184 - 23s - loss: 0.6143 - accuracy: 0.8890 - val_loss: 0.4784 - val_accuracy: 0.9446 - 23s/epoch - 123ms/step
# Epoch 5/5
# 184/184 - 23s - loss: 0.5940 - accuracy: 0.8970 - val_loss: 0.4616 - val_accuracy: 0.9450 - 23s/epoch - 128ms/step
# processing fold 3
# Epoch 1/5
# 184/184 - 33s - loss: 0.6190 - accuracy: 0.8899 - val_loss: 0.4523 - val_accuracy: 0.9542 - 33s/epoch - 180ms/step
# Epoch 2/5
# 184/184 - 23s - loss: 0.5748 - accuracy: 0.9023 - val_loss: 0.4146 - val_accuracy: 0.9633 - 23s/epoch - 126ms/step
# Epoch 3/5
# 184/184 - 24s - loss: 0.5604 - accuracy: 0.9064 - val_loss: 0.4103 - val_accuracy: 0.9599 - 24s/epoch - 130ms/step
# Epoch 4/5
# 184/184 - 24s - loss: 0.5329 - accuracy: 0.9135 - val_loss: 0.3953 - val_accuracy: 0.9667 - 24s/epoch - 129ms/step
# Epoch 5/5
# 184/184 - 23s - loss: 0.5435 - accuracy: 0.9094 - val_loss: 0.4178 - val_accuracy: 0.9578 - 23s/epoch - 126ms/step
# processing fold 4
# Epoch 1/5
# 184/184 - 36s - loss: 0.5651 - accuracy: 0.9053 - val_loss: 0.4067 - val_accuracy: 0.9631 - 36s/epoch - 196ms/step
# Epoch 2/5
# 184/184 - 23s - loss: 0.5082 - accuracy: 0.9213 - val_loss: 0.3944 - val_accuracy: 0.9663 - 23s/epoch - 126ms/step
# Epoch 3/5
# 184/184 - 23s - loss: 0.5388 - accuracy: 0.9140 - val_loss: 0.3897 - val_accuracy: 0.9676 - 23s/epoch - 126ms/step
# Epoch 4/5
# 184/184 - 24s - loss: 0.5126 - accuracy: 0.9225 - val_loss: 0.3895 - val_accuracy: 0.9659 - 24s/epoch - 130ms/step
# Epoch 5/5
# 184/184 - 24s - loss: 0.5243 - accuracy: 0.9185 - val_loss: 0.3834 - val_accuracy: 0.9721 - 24s/epoch - 128ms/step
# processing fold 0
# Epoch 1/5
# 184/184 - 28s - loss: 0.5275 - accuracy: 0.9181 - val_loss: 0.3944 - val_accuracy: 0.9650 - 28s/epoch - 150ms/step
# Epoch 2/5
# 184/184 - 23s - loss: 0.4995 - accuracy: 0.9258 - val_loss: 0.3569 - val_accuracy: 0.9761 - 23s/epoch - 123ms/step
# Epoch 3/5
# 184/184 - 22s - loss: 0.4703 - accuracy: 0.9318 - val_loss: 0.3628 - val_accuracy: 0.9736 - 22s/epoch - 122ms/step
# Epoch 4/5
# 184/184 - 22s - loss: 0.4708 - accuracy: 0.9300 - val_loss: 0.3450 - val_accuracy: 0.9806 - 22s/epoch - 121ms/step
# Epoch 5/5
# 184/184 - 23s - loss: 0.4945 - accuracy: 0.9271 - val_loss: 0.3735 - val_accuracy: 0.9719 - 23s/epoch - 123ms/step
# processing fold 1
# Epoch 1/5
# 184/184 - 28s - loss: 0.4900 - accuracy: 0.9278 - val_loss: 0.3859 - val_accuracy: 0.9659 - 28s/epoch - 154ms/step
# Epoch 2/5
# 184/184 - 24s - loss: 0.4597 - accuracy: 0.9352 - val_loss: 0.3884 - val_accuracy: 0.9653 - 24s/epoch - 130ms/step
# Epoch 3/5
# 184/184 - 23s - loss: 0.4658 - accuracy: 0.9332 - val_loss: 0.3847 - val_accuracy: 0.9629 - 23s/epoch - 125ms/step
# Epoch 4/5
# 184/184 - 23s - loss: 0.4675 - accuracy: 0.9340 - val_loss: 0.3356 - val_accuracy: 0.9821 - 23s/epoch - 125ms/step
# Epoch 5/5
# 184/184 - 23s - loss: 0.4480 - accuracy: 0.9378 - val_loss: 0.3513 - val_accuracy: 0.9731 - 23s/epoch - 126ms/step
# processing fold 2
# Epoch 1/5
# 184/184 - 28s - loss: 0.4607 - accuracy: 0.9352 - val_loss: 0.3566 - val_accuracy: 0.9751 - 28s/epoch - 154ms/step
# Epoch 2/5
# 184/184 - 23s - loss: 0.4430 - accuracy: 0.9397 - val_loss: 0.3441 - val_accuracy: 0.9776 - 23s/epoch - 126ms/step
# Epoch 3/5
# 184/184 - 23s - loss: 0.4136 - accuracy: 0.9462 - val_loss: 0.3231 - val_accuracy: 0.9817 - 23s/epoch - 125ms/step
# Epoch 4/5
# 184/184 - 23s - loss: 0.4461 - accuracy: 0.9383 - val_loss: 0.3524 - val_accuracy: 0.9772 - 23s/epoch - 125ms/step
# Epoch 5/5
# 184/184 - 24s - loss: 0.4339 - accuracy: 0.9432 - val_loss: 0.3184 - val_accuracy: 0.9840 - 24s/epoch - 128ms/step
# processing fold 3
# Epoch 1/5
# 184/184 - 28s - loss: 0.4439 - accuracy: 0.9398 - val_loss: 0.3371 - val_accuracy: 0.9797 - 28s/epoch - 153ms/step
# Epoch 2/5
# 184/184 - 23s - loss: 0.4123 - accuracy: 0.9496 - val_loss: 0.3247 - val_accuracy: 0.9793 - 23s/epoch - 127ms/step
# Epoch 3/5
# 184/184 - 23s - loss: 0.3951 - accuracy: 0.9500 - val_loss: 0.3114 - val_accuracy: 0.9812 - 23s/epoch - 126ms/step
# Epoch 4/5
# 184/184 - 23s - loss: 0.4063 - accuracy: 0.9486 - val_loss: 0.3177 - val_accuracy: 0.9827 - 23s/epoch - 127ms/step
# Epoch 5/5
# 184/184 - 23s - loss: 0.4335 - accuracy: 0.9424 - val_loss: 0.3214 - val_accuracy: 0.9812 - 23s/epoch - 127ms/step
# processing fold 4
# Epoch 1/5
# 184/184 - 28s - loss: 0.4246 - accuracy: 0.9435 - val_loss: 0.3221 - val_accuracy: 0.9815 - 28s/epoch - 154ms/step
# Epoch 2/5
# 184/184 - 23s - loss: 0.3978 - accuracy: 0.9494 - val_loss: 0.3194 - val_accuracy: 0.9787 - 23s/epoch - 126ms/step
# Epoch 3/5
# 184/184 - 23s - loss: 0.4095 - accuracy: 0.9461 - val_loss: 0.3105 - val_accuracy: 0.9827 - 23s/epoch - 125ms/step
# Epoch 4/5
# 184/184 - 23s - loss: 0.3916 - accuracy: 0.9520 - val_loss: 0.3008 - val_accuracy: 0.9857 - 23s/epoch - 127ms/step
# Epoch 5/5
# 184/184 - 23s - loss: 0.3669 - accuracy: 0.9581 - val_loss: 0.2926 - val_accuracy: 0.9838 - 23s/epoch - 126ms/step
# processing fold 0
# Epoch 1/5
# 184/184 - 28s - loss: 0.4051 - accuracy: 0.9475 - val_loss: 0.3105 - val_accuracy: 0.9817 - 28s/epoch - 153ms/step
# Epoch 2/5
# 184/184 - 23s - loss: 0.3728 - accuracy: 0.9553 - val_loss: 0.3040 - val_accuracy: 0.9802 - 23s/epoch - 126ms/step
# Epoch 3/5
# 184/184 - 24s - loss: 0.3810 - accuracy: 0.9538 - val_loss: 0.3016 - val_accuracy: 0.9844 - 24s/epoch - 128ms/step
# Epoch 4/5
# 184/184 - 24s - loss: 0.4151 - accuracy: 0.9466 - val_loss: 0.3134 - val_accuracy: 0.9825 - 24s/epoch - 128ms/step
# Epoch 5/5
# 184/184 - 24s - loss: 0.3581 - accuracy: 0.9606 - val_loss: 0.2964 - val_accuracy: 0.9806 - 24s/epoch - 129ms/step
# processing fold 1
# Epoch 1/5
# 184/184 - 28s - loss: 0.3904 - accuracy: 0.9505 - val_loss: 0.3040 - val_accuracy: 0.9829 - 28s/epoch - 154ms/step
# Epoch 2/5
# 184/184 - 23s - loss: 0.3677 - accuracy: 0.9575 - val_loss: 0.2868 - val_accuracy: 0.9866 - 23s/epoch - 126ms/step
# Epoch 3/5
# 184/184 - 23s - loss: 0.3597 - accuracy: 0.9577 - val_loss: 0.2946 - val_accuracy: 0.9825 - 23s/epoch - 126ms/step
# Epoch 4/5
# 184/184 - 23s - loss: 0.3660 - accuracy: 0.9568 - val_loss: 0.2968 - val_accuracy: 0.9832 - 23s/epoch - 126ms/step
# Epoch 5/5
# 184/184 - 23s - loss: 0.3610 - accuracy: 0.9581 - val_loss: 0.2870 - val_accuracy: 0.9851 - 23s/epoch - 126ms/step
# processing fold 2
# Epoch 1/5
# 184/184 - 28s - loss: 0.3774 - accuracy: 0.9548 - val_loss: 0.2810 - val_accuracy: 0.9883 - 28s/epoch - 152ms/step
# Epoch 2/5
# 184/184 - 23s - loss: 0.3555 - accuracy: 0.9602 - val_loss: 0.3112 - val_accuracy: 0.9793 - 23s/epoch - 126ms/step
# Epoch 3/5
# 184/184 - 23s - loss: 0.3822 - accuracy: 0.9530 - val_loss: 0.2963 - val_accuracy: 0.9829 - 23s/epoch - 126ms/step
# Epoch 4/5
# 184/184 - 23s - loss: 0.3512 - accuracy: 0.9597 - val_loss: 0.2848 - val_accuracy: 0.9851 - 23s/epoch - 128ms/step
# Epoch 5/5
# 184/184 - 23s - loss: 0.3565 - accuracy: 0.9589 - val_loss: 0.2846 - val_accuracy: 0.9864 - 23s/epoch - 126ms/step
# processing fold 3
# Epoch 1/5
# 184/184 - 28s - loss: 0.3601 - accuracy: 0.9586 - val_loss: 0.2889 - val_accuracy: 0.9866 - 28s/epoch - 151ms/step
# Epoch 2/5
# 184/184 - 23s - loss: 0.3795 - accuracy: 0.9557 - val_loss: 0.2699 - val_accuracy: 0.9900 - 23s/epoch - 126ms/step
# Epoch 3/5
# 184/184 - 23s - loss: 0.3466 - accuracy: 0.9613 - val_loss: 0.2734 - val_accuracy: 0.9872 - 23s/epoch - 128ms/step
# Epoch 4/5
# 184/184 - 24s - loss: 0.3425 - accuracy: 0.9619 - val_loss: 0.2893 - val_accuracy: 0.9812 - 24s/epoch - 129ms/step
# Epoch 5/5
# 184/184 - 23s - loss: 0.3214 - accuracy: 0.9674 - val_loss: 0.2853 - val_accuracy: 0.9815 - 23s/epoch - 125ms/step
# processing fold 4
# Epoch 1/5
# 184/184 - 28s - loss: 0.3564 - accuracy: 0.9587 - val_loss: 0.2657 - val_accuracy: 0.9910 - 28s/epoch - 150ms/step
# Epoch 2/5
# 184/184 - 23s - loss: 0.3463 - accuracy: 0.9611 - val_loss: 0.2623 - val_accuracy: 0.9904 - 23s/epoch - 126ms/step
# Epoch 3/5
# 184/184 - 23s - loss: 0.3285 - accuracy: 0.9655 - val_loss: 0.2421 - val_accuracy: 0.9925 - 23s/epoch - 123ms/step
# Epoch 4/5
# 184/184 - 23s - loss: 0.3279 - accuracy: 0.9654 - val_loss: 0.2642 - val_accuracy: 0.9864 - 23s/epoch - 126ms/step
# Epoch 5/5
# 184/184 - 23s - loss: 0.3252 - accuracy: 0.9656 - val_loss: 0.2512 - val_accuracy: 0.9930 - 23s/epoch - 124ms/step

# %%
test_loss, test_acc = final_lstm1.evaluate(X_test_lstm_pad,
                                          y_test_lstm_onehot)
# Out:
# 55/55 [==============================] - 1s 22ms/step - loss: 9.4716 - accuracy: 0.1378

# %% [markdown]
# ## ACCURACY OF FINAL LSTM MODEL IS 13.8%

# %% [markdown]
# ### Save Final LSTM Model

# %%
final_lstm1.save('final_lstm.h5')

# %% [markdown]
# ### Trying the Hold-out method

# %%
from tensorflow.keras.layers import Dropout, BatchNormalization

# Initialising the model 
final_lstm = Sequential()

# Defining model: add layers 
final_lstm.add(Embedding(
    max_words,
    EMBEDDING_VECTOR_LENGTH,
    input_length=max_len,
    weights=[embedding_matrix],
    trainable=True,
)) #glove embedding

final_lstm.add(BatchNormalization()) # BatchNormalization layer 
final_lstm.add(LSTM(128, input_shape=(max_len, EMBEDDING_VECTOR_LENGTH), return_sequences=True)) #LSTM layer
final_lstm.add(BatchNormalization())
final_lstm.add(Dropout(0.07))
final_lstm.add(LSTM(64, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.001))) # Additional dense layer
final_lstm.add(BatchNormalization())
final_lstm.add(Dropout(0.07))
final_lstm.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.001))) # Additional dense layer
final_lstm.add(BatchNormalization())
final_lstm.add(Dense(16, activation='softmax')) #dense layer - the last one

# Compile model
final_lstm.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

print(final_lstm.summary())

# Splitting the data into training and validation sets using hold-out method
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical

X_train, X_val, y_train, y_val = train_test_split(X_train_resampled, y_train_resampled, test_size=0.2, random_state=0, stratify=y_train_resampled)

# One-hot encode the target labels
y_train_encoded = to_categorical(y_train, num_classes=16)
y_val_encoded = to_categorical(y_val, num_classes=16)

# Number of epochs
num_epochs = 30

# Train the model
final_lstm.fit(X_train, y_train_encoded, epochs=num_epochs, batch_size=128, verbose=2, validation_data=(X_val, y_val_encoded))
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_8 (Embedding)     (None, 40, 50)            125000
#
#  batch_normalization_32 (Bat  (None, 40, 50)           200
#  chNormalization)
#
#  lstm_16 (LSTM)              (None, 40, 128)           91648
#
#  batch_normalization_33 (Bat  (None, 40, 128)          512
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 40, 128)           0
#
#  lstm_17 (LSTM)              (None, 64)                49408
#
#  batch_normalization_34 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_9 (Dropout)         (None, 64)                0
#
#  dense_16 (Dense)            (None, 64)                4160
#
#  batch_normalization_35 (Bat  (None, 64)               256
#  chNormalization)
#
#  dense_17 (Dense)            (None, 16)                1040
#
# =================================================================
# Total params: 272,480
# Trainable params: 271,868
# Non-trainable params: 612
# _________________________________________________________________
# None
# Epoch 1/30
# 147/147 - 38s - loss: 5.2395 - accuracy: 0.0767 - val_loss: 4.5729 - val_accuracy: 0.0850 - 38s/epoch - 260ms/step
# Epoch 2/30
# 147/147 - 28s - loss: 4.0850 - accuracy: 0.1199 - val_loss: 3.7624 - val_accuracy: 0.0997 - 28s/epoch - 193ms/step
# Epoch 3/30
# 147/147 - 24s - loss: 3.4329 - accuracy: 0.1489 - val_loss: 3.3350 - val_accuracy: 0.1098 - 24s/epoch - 164ms/step
# Epoch 4/30
# 147/147 - 24s - loss: 3.1361 - accuracy: 0.1617 - val_loss: 3.1885 - val_accuracy: 0.1095 - 24s/epoch - 165ms/step
# Epoch 5/30
# 147/147 - 30s - loss: 2.9735 - accuracy: 0.1761 - val_loss: 3.0860 - val_accuracy: 0.1157 - 30s/epoch - 205ms/step
# Epoch 6/30
# 147/147 - 29s - loss: 2.8527 - accuracy: 0.1917 - val_loss: 3.0290 - val_accuracy: 0.1087 - 29s/epoch - 199ms/step
# Epoch 7/30
# 147/147 - 26s - loss: 2.7533 - accuracy: 0.2089 - val_loss: 2.9897 - val_accuracy: 0.1168 - 26s/epoch - 176ms/step
# Epoch 8/30
# 147/147 - 24s - loss: 2.6535 - accuracy: 0.2318 - val_loss: 3.0040 - val_accuracy: 0.1211 - 24s/epoch - 164ms/step
# Epoch 9/30
# 147/147 - 23s - loss: 2.5705 - accuracy: 0.2516 - val_loss: 3.0520 - val_accuracy: 0.1191 - 23s/epoch - 156ms/step
# Epoch 10/30
# 147/147 - 24s - loss: 2.4803 - accuracy: 0.2852 - val_loss: 3.0899 - val_accuracy: 0.1155 - 24s/epoch - 160ms/step
# Epoch 11/30
# 147/147 - 23s - loss: 2.3698 - accuracy: 0.3209 - val_loss: 3.1946 - val_accuracy: 0.1155 - 23s/epoch - 157ms/step
# Epoch 12/30
# 147/147 - 22s - loss: 2.2501 - accuracy: 0.3594 - val_loss: 3.3243 - val_accuracy: 0.1110 - 22s/epoch - 153ms/step
# Epoch 13/30
# 147/147 - 22s - loss: 2.1285 - accuracy: 0.4048 - val_loss: 3.4722 - val_accuracy: 0.1132 - 22s/epoch - 148ms/step
# Epoch 14/30
# 147/147 - 22s - loss: 2.0079 - accuracy: 0.4419 - val_loss: 3.6691 - val_accuracy: 0.1068 - 22s/epoch - 153ms/step
# Epoch 15/30
# 147/147 - 23s - loss: 1.8730 - accuracy: 0.4918 - val_loss: 3.7732 - val_accuracy: 0.1115 - 23s/epoch - 156ms/step
# Epoch 16/30
# 147/147 - 30s - loss: 1.7266 - accuracy: 0.5424 - val_loss: 3.9947 - val_accuracy: 0.1032 - 30s/epoch - 205ms/step
# Epoch 17/30
# 147/147 - 34s - loss: 1.6002 - accuracy: 0.5824 - val_loss: 4.2122 - val_accuracy: 0.1042 - 34s/epoch - 235ms/step
# Epoch 18/30
# 147/147 - 29s - loss: 1.4593 - accuracy: 0.6323 - val_loss: 4.5199 - val_accuracy: 0.1093 - 29s/epoch - 199ms/step
# Epoch 19/30
# 147/147 - 25s - loss: 1.3420 - accuracy: 0.6706 - val_loss: 4.7232 - val_accuracy: 0.1040 - 25s/epoch - 172ms/step
# Epoch 20/30
# 147/147 - 23s - loss: 1.2098 - accuracy: 0.7142 - val_loss: 4.9958 - val_accuracy: 0.1023 - 23s/epoch - 157ms/step
# Epoch 21/30
# 147/147 - 21s - loss: 1.1071 - accuracy: 0.7446 - val_loss: 5.2533 - val_accuracy: 0.1057 - 21s/epoch - 143ms/step
# Epoch 22/30
# 147/147 - 21s - loss: 1.0185 - accuracy: 0.7732 - val_loss: 5.4643 - val_accuracy: 0.0955 - 21s/epoch - 142ms/step
# Epoch 23/30
# 147/147 - 24s - loss: 0.9206 - accuracy: 0.8065 - val_loss: 5.7978 - val_accuracy: 0.0997 - 24s/epoch - 164ms/step
# Epoch 24/30
# 147/147 - 24s - loss: 0.8703 - accuracy: 0.8211 - val_loss: 5.9880 - val_accuracy: 0.1032 - 24s/epoch - 162ms/step
# Epoch 25/30
# 147/147 - 21s - loss: 0.7885 - accuracy: 0.8486 - val_loss: 6.2441 - val_accuracy: 0.0965 - 21s/epoch - 142ms/step
# Epoch 26/30
# 147/147 - 21s - loss: 0.7318 - accuracy: 0.8625 - val_loss: 6.5021 - val_accuracy: 0.1025 - 21s/epoch - 142ms/step
# Epoch 27/30
# 147/147 - 21s - loss: 0.7042 - accuracy: 0.8744 - val_loss: 6.7239 - val_accuracy: 0.1072 - 21s/epoch - 141ms/step
# Epoch 28/30
# 147/147 - 22s - loss: 0.6639 - accuracy: 0.8835 - val_loss: 6.9905 - val_accuracy: 0.1038 - 22s/epoch - 149ms/step
# Epoch 29/30
# 147/147 - 21s - loss: 0.6289 - accuracy: 0.8960 - val_loss: 7.0926 - val_accuracy: 0.1068 - 21s/epoch - 143ms/step
# Epoch 30/30
# 147/147 - 21s - loss: 0.5979 - accuracy: 0.9044 - val_loss: 7.3761 - val_accuracy: 0.1032 - 21s/epoch - 145ms/step

# %%
test_loss, test_acc = final_lstm.evaluate(X_test_lstm_pad,
                                          y_test_lstm_onehot)
# Out:
# 55/55 [==============================] - 1s 23ms/step - loss: 6.9430 - accuracy: 0.1527

# %% [markdown]
# Accuracy of the final LSTM model using the hold out method with 30 epochs is 15.3%
